# %%
# Import Libraries
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import string
import csv
import re

# %%
# Open CSV File & Cleaning
listwit = []
with open('tweetutf2.csv',encoding='utf-8') as data:
    reader = csv.reader(data)
    for row in reader:
        print(row)
#         row[0] = re.sub(r'\s\s+',' ', row[0])
#         row[0] = re.sub(r'http\S+', '', row[0]) #hapus link http
#         row[0] = re.sub(r'@\S+', '', row[0]) #hapus mention
#         row[0] = re.sub(r'Membalas', '', row[0]) #hapus membalas
#         row[0] = re.sub(r'RT', '', row[0]) #hapus RT
#         row[0] = re.sub(r"\.", '', row[0]) #hapus titik
#         row[0] = re.sub(r",", '', row[0]) #hapus koma
#         row[0] = re.sub(r":", '', row[0]) #hapus titik dua
#         row[0] = re.sub(r"\?", '', row[0]) #hapus tanda tanya
#         row[0] = re.sub(r"!", '', row[0]) #hapus tanda seru
#         row[0] = re.sub(r"#", '', row[0]) #hapus hashtag
#         row[0] = re.sub(r"\(", '', row[0]) #hapus (
#         row[0] = re.sub(r"\)", '', row[0]) #hapus )
#         row[0] = re.sub(r"\[", '', row[0]) #hapus [
#         row[0] = re.sub(r"\]", '', row[0]) #hapus ]
#         row[0] = re.sub(r"[^A-Za-z0-9().,<_>!?\'`]", ' ', row[0]) #hapus entah apa ini :v
#         row[0] = re.sub(r"\s{2,}", ' ', row[0]) #hapus entah apa ini :v (2)
#         listwit.append(row[0].split(';'))
# listwit
# Out:
# ['\ufeffINDOSAT;@indosatcare Kenapa kartu diregistrasi nggak bisa pak? Padahal nomor kk & ktp nya sudah benar? Sampai 5x gagal tolong di daftarkan segera demi kenyamanan pengguna kartu indosat. Terima kasih ']
# ['INDOSAT;indosat mantap djaja koneksinya  ngebut euy ']
# ['INDOSAT;Membalas @IndosatCare @IndosatCare mau nangis deh rasanya pdahl saya percaya betul dengan indosat soal koneksi di wil Karimun tp sudah 3 hari koneksi kacau balau ']
# ['INDOSAT;Sinyal Indosat asu ari musim hujan hadeuh ']
# ['TRI;Membalas @triindonesia Cek dm woi  layananan keluhan semua ga berfungsi... ']
# ['XL;Ini kenapa di bale endah sinyal XL tiba2 bagus yah? Pindah kali yah tower nya ke deket rumah.. *aneh liat hp sendiri ']
# ['TRI;Hotsale 8GB hanya gratis nelfon aja ga ada gratis sms nya tah min? @triindonesia ']
# ...
