# %%
# Import Libraries
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import string
import csv
import re

# %%
# Open CSV File
listwit = []
with open('tweetutf2.csv',encoding='utf-8') as data:
    reader = csv.reader(data)
    for row in reader:
        row[0] = re.sub(r'\s\s+',' ', row[0])
        listwit.append(row[0].split(';'))
listwit
# Out:
# [['\ufeffINDOSAT',
#   '@indosatcare Kenapa kartu diregistrasi nggak bisa pak? Padahal nomor kk & ktp nya sudah benar? Sampai 5x gagal'],
#  ['INDOSAT', 'indosat mantap djaja koneksinya '],
#  ['INDOSAT',
#   'Membalas @IndosatCare @IndosatCare mau nangis deh rasanya pdahl saya percaya betul dengan indosat soal koneksi di wil Karimun tp sudah 3 hari koneksi kacau balau '],
#  ['INDOSAT', 'Sinyal Indosat asu ari musim hujan'],
#  ['TRI', 'Membalas @triindonesia Cek dm woi '],
#  ['XL',
#   'Ini kenapa di bale endah sinyal XL tiba2 bagus yah? Pindah kali yah tower nya ke deket rumah.. *aneh liat hp sendiri '],
#  ['TRI',
#   'Hotsale 8GB hanya gratis nelfon aja ga ada gratis sms nya tah min? @triindonesia '],
#  ['TRI', 'Membalas @andikapram_ @IndosatCare dan 2 lainnya Hai kak Andika'],
#  ['TSEL',
#   'Membalas @tsel_malang @tsel_malang iya min. Udah bisa kok. Hihihi. Tengkyu yaaaa :) seneng banget pake telkomsel. Sinyal lancaaar {} '],
#  ['INDOSAT',
#   '"@IndosatCare 30 ribu saya beneran atau bohongan saya coba buat internet lngsung tanpa daftar paket internet dan alhamdulillah bisa buat internet trus saya buka halaman indosat.. Baru kebuka saya dpt sms dari indosat ""Kamu internetan dg tarif perKB'],
#  ['XL', 'Sinyal kencang XL mantabbbzz :D '],
#  ['INDOSAT',
#   '@IndosatCare tolong kasih penjelasan yg bisa saya terima dong.. kenapa 3 hari ini sinyal Indosat sangat mengecewakan di daerah Mampang Depok '],
#  ['INDOSAT',
#   'yang lagi mau liburan di The Jungle Bogor Indosat Super WIFI juga ada di sana looh'],
#  ['TRI',
#   'Membalas @rapdodge @triindonesia Saya juga cukup heran mengapa 4G 3 speednya bisa naik dirumah akan saya SS sisa paket saya'],
#  ['TRI', 'JIKALAU MASALAH SDM YG MENGAKIBATKAN KELUHAN SAYA TIDAK DIBALAS'],
#  ['TRI',
#   '@triindonesia operator 3 tolong yah sinyal nya jangan jelek terus tiap hari saya kecewa sekali dengan 3 sekarang.. padahal sdh 3tahun pakai '],
#  ['TSEL', 'Membalas @Telkomsel mantap jiwa nih min harga paketnya '],
#  ['INDOSAT', 'Terima kasih kepada sponsor yg sudah mendukung acara kita'],
#  ['XL',
#   '@myXL sinyal dimana2 cuma H+ padahal paket internet 4G. Makin mahal makin bobrok aja xl. Kecewa saiah ? '],
#  ['XL',
#   'Membalas @myXL @Feriza07 woy @myXLCare anjing bukan dikota jakarya saja semua kota. apa lo gak baca twett pengguna lain? makasar aja uda seminggu. sialan lo anjing kampret '],
#  ['TRI',
#   '"-____- RT @DianSaaputra: Aseek.. ""NICK0MINAJ: Kalo hujan dan malam tri pasti lemot @triindonesia .. Bangsat"" "'],
#  ['TRI', 'Frontal cuk :))RT @dwikyoutSIDers: Bangsat'],
#  ['TSEL', 'Memang terBAIK sakali iye teh TELKOMSEL '],
#  ['XL', 'Ya ampun'],
#  ['INDOSAT', 'Indosat sinyale koyo NGELEC.... Asu '],
#  ['TRI', '@triindonesia gimana nich'],
#  ['XL',
#   'Haloo.. @myXL @myXLCare bagaimana nasib keluhan saya tiket C19402752? Apakah masih di tanggapi atau di anggap angin lalu? Sejak Januari masih belum selesaikah? Cc : @YLKI_ID '],
#  ['XL', '"Makassar lg seru banget nih guys sore ini'],
#  ['INDOSAT', 'kecewa berat saiah dengan @XLcare'],
#  ['INDOSAT', '"@IndosatCare min'],
#  ['XL', '17th pakai XL'],
#  ['INDOSAT', 'Kebiasan pake indosat ngecek pulsa salah'],
#  ['XL',
#   'Sudah 2 bulan sejak Januari 2018 keluhan saya no tiket C19402752 tidak ada respon dan solusi @myXL @myXLCare Cc: @YLKI_ID '],
#  ['TSEL', '@Telkomsel sinyal jelek bgt sih'],
#  ['TRI', '@triindonesia maju tak gentar membela yang benar'],
#  ['TSEL',
#   'Membalas @Telkomsel Min mau nanya ni.. knp sim card telkomsel saya tdk bisa buat panggilan keluar sedangkan kemarin bisa . Sudah dua minggu koit min sdh berhasil registrasi pula gimana saran dan tanggapan anda mewakili telkomsel ? '],
#  ['INDOSAT',
#   'Setelah Telkomsel... Ini Indosat memakai jasa Felix Kwetiau org HTI ormas terlarang utk isi acara Ramadhan... Emangnya gak ada kah Ulama yg lain? Mohon klarifikasinya utk @IndosatCare @IndosatBusiness Apa benar flyer yg saya terima ini? *D. ?? '],
#  ['XL',
#   '@undzhira @myXLCare @myXL coba cek ke *123*4*3# zhir... #bukanorangdalemXL '],
#  ['TSEL', 'Di tahun Anjing Tanah ini'],
#  ['INDOSAT',
#   'Alhamdulillah kartu indosat pintar laris manis..bisa free call 1000 menit 1000 sms ke semua indosat dan 512 data... http://fb.me/5UnVZP7qR '],
#  ['XL', 'Sinyal xl kencang badai'],
#  ['TRI',
#   'Membalas @triindonesia saya sedang mempertanyakan informasi kuota yg berbeda antara bima dan web 3 saya pinta penjelasan '],
#  ['TRI',
#   '@triindonesia sinyal Tri di area Cikarang delta mas dan Jababeka hilang sinyal mulai jam 16.00 tadi Mohon perbaikannya. Terima kasih '],
#  ['TSEL', 'Sekarang udah jamannya 4G LTE'],
#  ['INDOSAT', 'makasih @indosatcare keluhanku sudah di tangani dengan cepat'],
#  ['INDOSAT', 'Sekarang pake indosat pasca bayar'],
#  ['XL',
#   'Ogah RT @febrysara: beralihalah ke xl..sinyal kencang dan lari pulsanya juga kencang RT@veliieii Indosat kampring!! '],
#  ['INDOSAT',
#   'di buat nangis sama jaringan indosat :/ gara* jaringan nya jelek nyangka nya mz dari dia ga di lz hampura sayank :* @egi_pribadi '],
#  ['XL', 'Membalas @adetruna nambahin wacana'],
#  ['TRI', 'Membalas @triindonesia Tolong perbaiki sinyal 3 di Aceh'],
#  ['TSEL',
#   '\\(´?`)/ keluarga telkomsel memang terbaik.. RT @MessyBae: @GalihSecos kayaknya aq jg akan kembali ke kartu AS qu...? '],
#  ['TSEL',
#   'Membalas @Telkomsel Saya mau nangis kejer rasanya mas. Kalau saya main mobile legend tuh tiba tiba jaringan terputus tanpa sebab. Tau gak telkomsel sering banget kayak gini. Padahal untuk streaming apapun itu lancar lancar aja. Mas saya udah 2x turun credit score mobile legend gara2 koneksi terputus '],
#  ['TRI', 'Kepada para pemenang Kuis #3BangkitIndonesia bisa dicek DM-nya ya'],
#  ['TSEL', 'mantap..sinyal 3G stabil skrg dirumah...thx telkomsel... '],
#  ['XL',
#   '@myXL kualitas sinyalnya makin hari makin ancur. tolong dong diperbaiki'],
#  ['TSEL',
#   '#Im3 ne Iklan Sampah.. Kreatif dikit Napa.. Ikut2an As Telkomsel.. Maluuuuuuu.. '],
#  ['TRI',
#   '"Ready pisan :)) RT @triindonesia: Sudah siap untuk kuis #3BangkitIndonesia? Tes suara dulu ah ',
#   ') "'],
#  ['TSEL',
#   'Membalas @Telkomsel Kalo kayak gini gimana coba aktifinnyaaaaa !!! Kasih tau dong caranyaaaaaa '],
#  ['TRI',
#   'Nah ini ! RT @triindonesia: Cari Tri Store terdekat di kota kamu? Klik link ini untuk informasi lengkapnya yaa :) http://bit.ly/1la0SLo '],
#  ['XL', '@mahendraekky_ @myXL @Telkomsel Pake antena PF Goceng brad'],
#  ['TSEL', 'Membalas @iwnkurniawn @Telkomsel Klo bisa nangis'],
#  ['TSEL',
#   'Gw yakin @Telkomsel ga bisa baca komen2 ini.. Lemot.. #TelkomselProRadikalis #TelkomselProRadikalis #TelkomselProRadikalis #TelkomselProRadikalis #TelkomselProRadikalis #TelkomselProRadikalis #TelkomselProRadikalis #TelkomselProRadikalisJoe® ? menambahkan'],
#  ['TSEL', 'monyeet koneksi sampah'],
#  ['TRI',
#   'Ir.Soekarno Hatta RT @triindonesia: Kuis #3BangkitIndonesia : Tebak tokoh yang ada di gambar ini! http://twitpic.com/9ifjt6 '],
#  ['TSEL', 'Membalas @Telkomsel @Telkomsel anyway'],
#  ['INDOSAT', 'Pengalaman gue sangat mantap pakek indosat '],
#  ['TSEL', '@Telkomsel min saya mau nanya'],
#  ['INDOSAT',
#   'Kumpul mahadelta dapet rejeki dari indosat lumayan 11gb free lancar abis. Terima kasih indosat '],
#  ['TRI', 'Membalas @triindonesia Baik'],
#  ['XL',
#   'Joss @Othonk_00uye: Makany klo beli no sklian bli sinyal. Ahhaha RT @stevaniefebrian: Plis xl jgn balak2 donk! Knp skr signal nya ababil sih '],
#  ['TSEL',
#   '@Telkomsel anjing lu!kalau gk suka mobile legend jangan dilenotin dong sinyalnya asu! AOV itu asu kyk telkomsel '],
#  ['XL',
#   '"Udah senin nih. upload foto"" pas weekend kmrn ayo pakai XL. Internet Super Cepat & Stabil #LovePalembang #Hotrod "'],
#  ['TRI',
#   'Lagu favoritku Kecewa karna org itu sukanya bikin hati org kecewa baper bgt lagunya @triindonesia @kampungseleb #KONSERROSSA3 '],
#  ['TRI', 'Merah sinyalnya'],
#  ['INDOSAT',
#   'nih provider @IndosatCare harus banyak belajar sama @Telkomsel keluhan cepat di tanggapi '],
#  ['INDOSAT',
#   'apakah ini kemajuan? apa indosat makin maju? dari kemarin-kemarin internetnya cepet terusssss selamat ! '],
#  ['TSEL', 'CS nya lelet dan lemot'],
#  ['XL',
#   'SUMPAH XL @myXL SAMPAH BANGET SINYALNYA. BENERIN DONG JARINGANNYA JANGAN CUMA BERANI NGASIH PROMO MURAH.???????? '],
#  ['XL',
#   'Indosat sinyal nya palang merah. Okeee. Xl lumayan lah ada dikit2... '],
#  ['TRI', '@triindonesia min '],
#  ['INDOSAT', 'Membalas @putrachndrg Terima kasih Indosat '],
#  ['XL',
#   'Membalas @DanielMilagross @DanielMilagross @XL123 memang gitu sinyal XL terkadang kencang tiba2 lambat.Sama ditempat q jga gitu.tapi jgn ganti kartu semuanya Sama. '],
#  ['TRI',
#   '"@triindonesia #089523359172 #Jl.PHH Musofa (Jln Suci dpn SMA YAS) ""knpa ya skarang sinyal tri EDGE 3 terus ga pernah H di area rumah saya?"" "'],
#  ['XL',
#   'Sama! Tolong kenapa ini XL di rumah yang biasanya streaming ga buffer ini buka twitter aja gabisa. Hadeh @myXLCare @myXL Kile. menambahkan'],
#  ['INDOSAT',
#   'Membalas @IndosatCare Anjing indosat goblok fakk maen moba aja leg nya minta di tampil kontol '],
#  ['INDOSAT',
#   'Asu @indosat jaringane kek tai percuma pket banyak tp nge lag gbsa ngapa2in sumpah payah jancuk '],
#  ['INDOSAT',
#   'Membalas @a_damnthing @InfoTwitwor dan 4 lainnya Iya nih kontol indosat pulsa gua dipotong 50k anjing babi'],
#  ['TSEL',
#   'satelit telkomsel meledak pa gimana hng #SEHUNxLV #LVCruise @weareoneEXO '],
#  ['INDOSAT',
#   'Pertama kalinya XL dibawa ke luar rumah. Signal internetnya bagus! bye bye Indosat. cukup lah ya bertahan 6 tahun. :) '],
#  ['INDOSAT',
#   'Membalas @TsamaraDKI Semua program infrastruktur warisan dari pemerintahaan sebelumnya... kita tunggu yg murni dari jokowi seperti listrik 35k megawatt'],
#  ['TSEL', 'Susah sama @Telkomsel smpai skrg cuma di tanya'],
#  ['TSEL', 'Kecewa sama pelayanan Telkomsel'],
#  ['XL', 'Membalas @myXL Makin lama makin jelek'],
#  ['INDOSAT',
#   'Membalas @IndosatCare waktu itu kartu udah hangus karena lupa isi pulsa'],
#  ['TRI', '@triindonesia harusnya lihat kualitasnya dulu baru naikkin harga'],
#  ['INDOSAT', '@IndosatCare halo indosat'],
#  ['XL',
#   'Membalas @myXL @XLCare ini xl knapa sih? gangguan mulu signal ada tapi no internet connection.. sampah '],
#  ['TRI',
#   'Oke thanks info.nya RT @triindonesia: @AnaasKhoironi informasi paket sms bisa km cek di http://bit.ly/1mbtTqC '],
#  ['XL',
#   'Membalas @myXL Saya tidak pilih semuanya. Karena saat ini jaringan internet XL mbyarpet alis MATI-HIDUP plus LELET. Sangat..sangat..sangat mengecewakan. Kecewa karena sudah terjadi sejak Sabtu kemarin'],
#  ['XL',
#   'Sudah hampir seminggu lebih sinyal 4G d daerah ku sangat lambat sekali apakah xl sedang ada ganguguan @myXL '],
#  ['INDOSAT', 'Membalas @IndosatCare saya akui indosat cukup bagus'],
#  ['XL',
#   'promosi awak iya? :p RT @DolyIrawan: Pake xl la. Hahha punyaku kencang RT @LiliPoel udah midnite gini pun sinyal tetep aja kacau '],
#  ['XL',
#   'Dibayar berapa nis buat ngeboong? Ekekekke RT @sinisoo: Makannya pakai XL sinyal kencang saat anda berada dimana saja (y)RT @ramadando '],
#  ['XL',
#   'Membalas @zazachan @myXL Iki nang Munggur kok mung oleh sinyal 3G mentok 1 bar 4G . Paketan mahal sinyal busuk'],
#  ['TSEL', 'Emang juga telkomsel cacat. '],
#  ['TRI',
#   '"Kasih pete bapaknya ""@triindonesia: Nih mimin ulang : Kuis #3BangkitIndonesia : Gimana caranya deketin anak presiden biar direstui?"" "'],
#  ['XL',
#   'Membalas @aditective @IndosatCare Kno dit? Selama masih d Indonesia jgn harap lebih sama dunia selular'],
#  ['XL', 'Sinyal XL di Bintaro kurang bagus yaa'],
#  ['TSEL',
#   '@Telkomsel ini jaringan kenapa 3g dan ilang2? Cacat banget koneksi '],
#  ['INDOSAT', 'Membalas @IndosatCare @wepeputri92 Dm gue gimana riza taek '],
#  ['INDOSAT', 'Paketan internet indosat bikin nangis... borosss yawooh '],
#  ['XL', '@XLCare min'],
#  ['TRI', '@triindonesia admin jancok'],
#  ['TRI', 'Sinyalnya gawat min'],
#  ['TSEL', 'Tekad sudah bulat'],
#  ['XL',
#   '@myXL apakah ada cara/situs/no yg bisa diakses untuk mengetes jaringan XL? Bermaksud membeli MiFi'],
#  ['TSEL',
#   'Gak boleh nyebut merk.. titik RT @KakaLebah: Internetnya telkomsel lemot...titik '],
#  ['INDOSAT',
#   'Membalas @IndosatCare sudah saya dm. cek segera. itu no hp saya. tolong matikan layanan prime joy yang saya tidak daftar itu. saya tidak terima pulsa saya terpotong tiap bulan hanya demi benefit prime dari indosat yang SAMA SEKALI TIDAK BERGUNA DAN TAK AKAN SAYA GUNAKAN. Thanks. '],
#  ['TRI',
#   'Membalas @triindonesia @triindonesia gambar aku pake baju perang dengan background kobaran api sambil bawa bendera . hehe #3BangkitIndonesia '],
#  ['TSEL', 'saya kecewa sama telkomsel (ketok palu) '],
#  ['XL',
#   'Cuaca cerah telah berganti di siang ini. Angin mulai kencang. tanda apa ya... Sinyal XL tetep lantjar jaya '],
#  ['XL',
#   'Saya sangat kecewa jaringan internet di daerah saya lemot.buka fb sama vidio fb lemot.buat maen game g stabil@myXL '],
#  ['XL', 'Membalas @dytun yaaa makanyaaa aku sedih'],
#  ['INDOSAT', '@IndosatCare Selamat malam'],
#  ['XL', 'Dulu rekomen @myXL soalnya internetnya cepet dan lancar'],
#  ['TRI',
#   'Membalas @triindonesia Bisa dibantu link url informasi tersebut... '],
#  ['INDOSAT',
#   'gmn dong gue mau nangis besok tuh gue mau bukber masa gue bukber dengan gaada kuota anjing bangsat lo indosat tolol @IndosatCare '],
#  ['TRI',
#   '@triindonesia tlg kalo kasih info itu yg jujur biar konsumen ga marah ga kesel'],
#  ['INDOSAT',
#   'Kecewa dg kualitas Indosat 00.07 kuota masih 14Gban. 00.30 kuota ludes gak jelas @IndosatCare '],
#  ['TSEL',
#   'Haha :p tapi da lelet pake telkomsel a @AldyAPekerti: @ndeyunie engga ah udh enak pake yang ini murah ??a??a??a??a '],
#  ['INDOSAT',
#   'Yah hehe pake XL lumayan bagus lho say :D RT @puspacitato: Tapi bb aku indosat. Gabisa ganti ke XL...hhe RT ... http://tmi.me/dJO84 '],
#  ['TRI',
#   'gimana cara ngilangin ini selamanya? saya beli kartu @triindonesia baru dan langsung berhasil registrasi tapi notifikasi ini nongol terus ganggu banget. '],
#  ['TRI',
#   'Membalas @anindyaafp @triindonesia Ga ada kendala katanya. Bener2 tai ni CS. Sinyal saya hilang2an jg dibilang ga ada kendala. Dan CS bales komplain waktu sinyalnya membaik. Ga punya otak ni CS '],
#  ['XL', 'Dear @myXLCare @myXL '],
#  ['TRI',
#   'Selamat pagi @triindonesia mohon informasi untuk Upgrade kartu 3 menjadi 4G lokasi Bekasi gerai tri ada dimana ya? '],
#  ['TRI', '@triindonesia min hp adik saya hilang'],
#  ['INDOSAT',
#   '@IndosatCare tolong cek no 6285812042746 knp ga ada balasan dr indosat ya Terima kasih Segera ditindak lanjuti '],
#  ['TRI', 'DM ga direspon'],
#  ['TSEL', '@Telkomsel Lurd cek poin gimana yah? '],
#  ['TRI', 'Marah dengan @IndosatCare'],
#  ['TSEL',
#   '@Telkomsel baru kali ini saya kecewa sekali dengan pelayanan caroline officer 188 (agent name tari) saya menanyakan ttg proses running paket data saya kenapa tdk berjalan seperti biasanya. '],
#  ['XL', '@myXLCare Jancuk'],
#  ['TSEL',
#   '#NabungBuatApa? Buat biaya mengumpulin orang untuk membersihkan sampah di pantai'],
#  ['TSEL', 'delapan tahun make telkomsel baru kali ini tukar poin'],
#  ['INDOSAT',
#   '@IndosatCare kenapa ya jaringan indosat belakangan ini suka hilang sinyal.. lama kelamaan bisa kecewa saya... dan 1 lagi'],
#  ['TRI',
#   'Membalas @swr4j @triindonesia paling kesel kalo udah lelet dan bilang tidak ada masalah hahahaha tai memang '],
#  ['TSEL', 'Sinyal @simPATI di tmpt saya sering mati2 udah 2 minggu ini'],
#  ['XL',
#   'Membalas @digembok Untung gw ga pernah pakai @Telkomsel selain mahal'],
#  ['TSEL', 'Membalas @KAEL_GENCY Telkom 0809999 dari Telkomsel mantap jiwa '],
#  ['INDOSAT',
#   'Membalas @fadhilhrp @Telkomsel Indosat juga lagi bermasalah.. alhamdulillah ternyata provider mahal juga bermasalah '],
#  ['INDOSAT', 'jaringan indosat lumayan bagus :3 '],
#  ['TSEL', 'Telkomsel memang terbaik ? '],
#  ['TRI', '@triindonesia min saya mau kasih saran nih'],
#  ['TRI', '"Sinyal tri ngebut RT @guz_widnyana Wifi mencret'],
#  ['INDOSAT',
#   '@IM3Ooredoo Maksud nya apa ya ? Ini karena sistem indosat yang trouble ataukah kesengajaan ? Tolong dikembalikan pulsa saya. Terima ka '],
#  ['XL',
#   'Membalas @myXL @Rahmadi_20 @myXLCare Nich provider bangsat isuny cm maling dan penipu konsumen. Provider zaman now. Maling bermodus provider xl bangsat '],
#  ['TSEL', '@Telkomsel Memang Macam Anjing Sinyalnya'],
#  ['TRI',
#   'Smart juga :) set jam download 100MB lewat BB RT @tasialalala: Sinyal tri pagi2 emang mantap jaya. '],
#  ['TRI',
#   'Promo sampe kpn nih??@triindonesia:PakeTri Blackberry berisi 3 voucher Blackberry Full service mingguan + 3 Bonus voucher yang sama. '],
#  ['TRI', 'Membalas @Mikihoushi @triindonesia Mungkin udh naik'],
#  ['TRI',
#   'gratis kok sms. .gratis tu pulsa 100.000 :)) RT @triindonesia: @kipz_1923 @orenucull11 Pake tri sms sekali gratis terus donk seharian'],
#  ['TRI', '@triindonesia Laek'],
#  ['XL',
#   'Kenapa ya nomor prabayar @Telkomsel itu ga bisa diaktifkan lagi seperti nomor @myXL atau @IndosatCare padahal baru lewat 1 hari dari masa tenggang..dipaksa pindah ke pascabayar..sistem @Telkomsel yang jadul atau karena merasa provider paling besar? @YLKI_ID '],
#  ['INDOSAT',
#   '#terluka #yang #baru #dipecat #maupinjemuang #eagkbisa #mau #ngutang #enggak #dikasih #boikotindosat #atau #nangis #ILCmembidikhabibrizieq '],
#  ['INDOSAT', 'RT LURD! Urgent'],
#  ['INDOSAT', 'ucweb indosat mantap! bisa new tab ! (norak)'],
#  ['INDOSAT', 'hallo indosat yang baik hati'],
#  ['TSEL', 'Telkomsel Absen Pesta RBT'],
#  ['TRI', '@triindonesia Min'],
#  ['TSEL',
#   '"Membalas @ferdy_doki telkomsel murah jg jok RT @ferdy_doki Gedor be RT ""@chandra_jmb: belum dtng dy RT @ferdy_doki Duku jg enak RT ""@chandra_jmb: lewat jendelo "'],
#  ['TSEL',
#   '@Telkomsel jancok banget ni kartu saya udah maketin paket flash eh tapi pulsa tetep kepotong !!! '],
#  ['INDOSAT',
#   'Dunia harus tau kalo skrng di rumahku udah ada sinyal 4g indosat ? Alhamdulillah packet yellowku wkwk '],
#  ['INDOSAT',
#   '@IndosatCare tolong informasinya segera. Saya belum pernah ikut paypro'],
#  ['XL', '?? sini kok sinyal XL kencang ?ªãª #Aneh '],
#  ['INDOSAT',
#   'sipooo RT @jejenieee: Oke makasih glo RT @ theodoregloria: lumayan RT @jejenieee: eh yang indosat sinyalnya bagus gak? '],
#  ['TRI', 'Better upload service'],
#  ['TRI', 'Buat kaum jomblo'],
#  ['INDOSAT',
#   'Indosat jan bulsit.. di paketke kok sik kenggo pulsa pokok.. paketane wutuh.. Asu asu '],
#  ['TSEL',
#   'Membalas @Telkomsel @Telkomsel yeee terbukaaa... terima kasih @Telkomsel .... engkau memang pelayanan terbaik.... '],
#  ['INDOSAT',
#   'Asu tnan seng jupuk hp qw. . . ch lek pnteng mz.o nek kne 082250519455 Sng n0 qw indosat ilang. . . '],
#  ['TSEL', 'Iya'],
#  ['XL',
#   'Pakai XL.. Dijamin cepat dan sinyal kuat! Haya! *iklan* hahaha RT @zakywira: Bbm masih aja pendingzzzzzzz '],
#  ['INDOSAT',
#   '@IndosatCare indosat jancok kaya gini masih gak cukup pulsanya jancok '],
#  ['TRI',
#   'Membalas @triindonesia @triindonesia tolong beri informasi yg jelas tentang gangguan nya'],
#  ['INDOSAT',
#   'Membalas @IndosatCare Kemrin waktu ke pantai parangtritis jogja'],
#  ['TSEL',
#   'Membalas @Telkomsel Saya mau regis tapi nik tidak ditemukan gimana tuh min '],
#  ['TRI',
#   'Tolong ya Perhatikan dengan Baik! No hp yang bermasalah ADALAH: 0895325979085 '],
#  ['INDOSAT', 'Membalas @musthari @musthari Hai Kak'],
#  ['TSEL', 'Membalas @Telkomsel @Telkomsel terimakasih kami sangat puas '],
#  ['INDOSAT',
#   'indosat lg ada masalah ya min? nomor saya tidak bisa terima sms masuk dan harus di copot simcardnya dulu baru smsnya masuk tolong di cek @IndosatCare '],
#  ['XL',
#   'Udah 2 hari. Masih juga gangguan. Ini xl ga mendengarkan keluhan pelanggannya ya? Kayanya udh banyak yg ngadu tpi kok ga lebih baik. Udah berkali kali reset signal @myXLCare @myXL '],
#  ['TSEL',
#   'Hash RT @HafiizhDP: PAKE XL DONG!!!!!ga pernah bs belaajar RT @sandhidwi: Telkomsel jancok 3 hari ini gsm mulu '],
#  ['INDOSAT',
#   'Membalas @INDOSAT_M3 @INDOSAT_M3 bnr2 ngak diperhatiin kualitas ISAT BB! sibuk Promo trus tp kualitas sinyal ancurrr!!!! kecewa bneran dh pelayanan INDOSAT!! '],
#  ['XL', 'Provider bangsat xl isiny cm maling@myXL '],
#  ['TRI', '@triindonesia ini kenapa koneksi nya tai banget dari siang '],
#  ['TRI',
#   'Membalas @triindonesia Masih gaada tindak lanjut? Udah 2 hari jaringan 4g hilang. Percuma kuota dikasih harga murah kalo pelayanan terutama kepada keluhan konsumen masih kek tai'],
#  ['TRI', '"Baji gau melulu -'],
#  ['TRI', '@triindonesia hai'],
#  ['TSEL',
#   'Mudah mudahan @Telkomsel bisa lebih baik dlm pelayanan pelanggan krn terus terang urusan sinyal dan coverage saya sangat puas dg Telkomsel. '],
#  ['INDOSAT',
#   'lumayan bagus wan RT @stalkerlove03: Rekomendasi dong... Jaringan indosat khususnya im3 bagus ga sih???? '],
#  ['INDOSAT',
#   '@IndosatCare halo indosat. ada pengaturan yang cocok gk buat hp advan i5c'],
#  ['TSEL',
#   'pakai telkomsel itu enak yaa gak pernah pending kalau bbman terus kalau telfonan sama smsan murah banget '],
#  ['TSEL',
#   'ak wes onok telkomsel tp halo ran RT @randyrantang: Ganti simpati wes :p RT @haryagembul: m3 jancok '],
#  ['XL',
#   '@myXL @myXLCare nyalahin customer belum regist padahal udah regis kok sampah ya anda. Problemnya ada di anda bagian IT anda yang tidak becus '],
#  ['TRI', '@triindonesia Jaringan cacat'],
#  ['XL', '@myXL jaringan nya cacat. Payah lah. '],
#  ['XL', 'Thanks XL download apapun sangat cepat '],
#  ['INDOSAT',
#   '@IndosatCare untuk yg kesekian kalinya pulsa saya hilang tiba-tiba. pulsa 3000 tinggal 800. mantap indosat diem-diem mencuri '],
#  ['TRI',
#   'Dear @triindonesia Sampai sekarang belum ada jawaban dr keluhan saya'],
#  ['XL', 'Tumben sinyal XL bagus '],
#  ['TSEL',
#   'Mau sampai kapan gangguan sinyal begini @Telkomsel? Semingguan tidak bisa dipakai buat main mobile legends. Saya kecewa. Beneran. '],
#  ['XL',
#   'ni laptop koneksinya malah dari tethering wifi hape cino. pake xl lumayan ngebut juga'],
#  ['XL',
#   'Fix ganti kartu sudah capek dengan XL keluhan gak ditanggapi sekali ditanggapi jawabannya ngelantur cc @myxl @myxlcare '],
#  ['XL', 'Mau tahu tips agar COD kamu lancar? Jawabannya'],
#  ['TSEL',
#   '"Penekanan pertama ad di kata ""murah"" RT @fuadyprabowo: @khalifradhian #indosat dganti opo enak""e? #telkomsel ? "'],
#  ['XL', '@myXL sampah banget koneksi internet XL ini bah. Sampah!!! '],
#  ['INDOSAT', 'tanggapan dari CS indosat cukup bagus lah menurut saya '],
#  ['TSEL',
#   'Membalas @Telkomsel @telkomsel owh itu aj ya. Oh ya makasih ya Paket TAU nya udh 3x ak pake itu. dan ak merasa sangat puas. semga pket TAU di adakn lg. '],
#  ['INDOSAT',
#   '@IndosatCare tolong baca DM saya. Saya urgent perlu bantuan. Nomor indosat saya sdh tdk aktif berhari hari. Terima kasih '],
#  ['XL', '@myXL sampah?...udh 3 hari sinyal leleeeeeet? '],
#  ['TRI',
#   '@IndosatCare gak bakalan kolaborasi sama @triindonesia nih? soalnya sinyal kalian sama-sama bapuk dan selalu tidak respon keluhan konsumen. '],
#  ['INDOSAT', '"Jadi'],
#  ['INDOSAT', 'mantap @candradhevista: @antoagustian pake indosat nih'],
#  ['TSEL',
#   '"tp katae plng enak telkomsel? RT @CHIZTYY Podo ae se jatuhe kabehRT @codyputri: lek paketan iku murah endi?? R ... ""http://bit.ly/jjrRJG"" "'],
#  ['TSEL', 'Membalas @tparadiva_ Baik'],
#  ['TRI',
#   '@triindonesia apa sih benefit yg kita terima sbg pelanggan 3 postpaid. Krn hampir 3thn ga dpt bonus apa2 '],
#  ['INDOSAT',
#   'Membalas @IndosatCare Mungkin sekitar 1 tahun aku pake provider Indosat. Sejauh ini cukup puas'],
#  ['TRI',
#   '"Knapa sinyal 3gnya main2 yah ""@triindonesia: Informasi detail mengenai #AON cek ke http://ow.ly/u2Vu6 "" "'],
#  ['TSEL', 'Em btw ini konek pake @Telkomsel ya'],
#  ['TRI',
#   '@triindonesia woy bangsat anjing ngentot babi kontol memek lu lelet tai anjing mahal sering di lletin lagi ahh ngentot awas lu ya '],
#  ['XL', 'Membalas @panda_why0069 Hai Krisnantyo'],
#  ['TRI', 'Kukud ja @triindonesia banyak keluhan tp gak di tanggapi'],
#  ['XL',
#   'Slamat datang di Manokwari! Sinyal XL? Lumayan bangetlah H. Rasa 4G kok hehe. Ga E n lost sinyal kyk sebelah. Yuk eksplor papua barat '],
#  ['TRI',
#   '"4batang jak 3G agik B) ""@dwishaa2: Pelosok""@risnu_arya04: Sinyal tri mantap! 2batang jak (y)"""" "'],
#  ['TSEL',
#   'Sms blast Telkomsel Sampah banget isinya. Udah bayar pulsa tetep aja di blast. Unethical! '],
#  ['TRI', 'Keluhan gua berharu hari gak di tanggapin'],
#  ['TSEL', '"Jaringan bb telkomsel napa ilang mulu.. Lemot cuy.. --"" "'],
#  ['TSEL',
#   'Kak...sinyal di daerah saya kok sekarang jelek sejak ada sinyal 4g...hp ahrus di lock 4g agar dapt sinyal 4g...kalo gak di lock cuma dpt sinyal H dan itu lemot...bantuannya kak....@Telkomsel '],
#  ['TRI',
#   'Membalas @triindonesia Nomor lama juga dong. Udah pake Tri 6tahun pas registrasi ulang gak dapet hadiah apapun '],
#  ['TRI', '@triindonesia siang'],
#  ['XL', '@myXL karena pasca bayar xl sudah lambat'],
#  ['TRI',
#   '"@triindonesia goblog! Jaringan lu udah sebulan lebih ngga bener""..jgn cm ngiklan doang..pikirin konsumen! "'],
#  ['XL',
#   '@myXL @myXLCare Tolong sekali lagi saya minta tanggung jawabnya yaa.. Saya tertarik beli'],
#  ['TSEL',
#   'Pada heboh paket BIS 3..namun telkomsel tetap juaranya..murah koq njaluk enak ! http://myloc.me/45GVi '],
#  ['INDOSAT',
#   '@noetoet ya beli aja perdananya murah ini.axis lumayan bagus kok.asal jangan kedap udara aja.hehe.perminggu 30rb'],
#  ['TSEL',
#   'Lagi-lagi TCash telkomsel @Telkomsel @TCASH_ID Mesin EDC nya error.. Kedua kali nya di Centre Point Medan. Ckckck.. Kecewa bngt. '],
#  ['TSEL',
#   '@Telkomsel mohon bantuan PUK untuk nomor 085104020545. Terimakasih '],
#  ['INDOSAT',
#   '"Satu kata ""telkomsel"" ??browsing cepet RT @nezzarerraldin: indosat sialaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaannnnn "'],
#  ['TRI',
#   'Membalas @triindonesia Kemarin lusa sy beli paket 5gb (1gb + 4gb 4G) 5rb. Setelah habis lalu sy beli yg 4G 12gb'],
#  ['TRI', 'Membalas @triindonesia Di selamatin doang'],
#  ['XL',
#   'Dear @myXL kenapa jaringanya selalu gangguan? Jadi ga berguna baru beli kartu perdana yang 21 gb tapi gakepake sama sekali gara* jaringanya lemot jelekkk parahh banget asli'],
#  ['TSEL',
#   'Sebagai konsumen @Telkomsel saya sangat kecewa dengan iklan ini kemana saya harus mengadu? '],
#  ['XL',
#   'Semoga XL xlalu menghadirkan pelayanan terbaik dan super cepat utk pelanggan setianya #JaringanXtraSuka '],
#  ['TRI', 'Semangat dong'],
#  ['TSEL', 'dear @Telkomsel kenapa kalo saya nonton film dari viu'],
#  ['INDOSAT', '@IndosatCare Malam. Nomor saya sudah tidak aktif sejak 27/4'],
#  ['TSEL',
#   'Seneng banget Arsenal jadi ke Indonesia... \\(´?`)/ ada promo khusus pelanggan Telkomsel lagi... \\(´?`)/ *jingkrakjingkrak* '],
#  ['TSEL', 'sinyal bagus ko tapi lemot yah? @Telkomsel '],
#  ['XL', 'Buat yang senang pelajaran Fisika atau Kimia'],
#  ['XL',
#   'XL sama Axis itu beda jauh. Axis cm 70rb full service sinyal bagus. Sedangkan XL 90rb full service tpi sama aja kyk ga pake paket full servc '],
#  ['TRI',
#   'RT @wulanrm: Terima kasih semua yg sudah kasih info ttg provider Tri. Kesimpulannya'],
#  ['TRI',
#   'Membalas @blogdokter @Telkomsel @triindonesia Saya langganan paket tri 32 GB sebulan cuma 60 ribu '],
#  ['XL',
#   'Membalas @myXL Banyak gangguannya dah gitu slow respon lagi hadeeeh nyesel dah ini beli perdana malah mahal lagi ? '],
#  ['XL',
#   'Bikin boros batere bro. RT @agungmyusuf_1: disini HSPA+ mas hihi RT @RendyTalun: Sinyal HSDPA XL joss gandos men.. '],
#  ['TRI', '"Tri gaada sinyal--"" mantap yah!!! "'],
#  ['INDOSAT', 'Membalas @krysjsoow @audimorissa_ itu smartfreen'],
#  ['INDOSAT', 'Sore min'],
#  ['TSEL', '@Telkomsel Rekan mohon bantuan Respon DM. Tks '],
#  ['INDOSAT', 'SAMPAH INDOSAT @2000 minyat we ah aja ke 0817844444 '],
#  ['INDOSAT',
#   '"butuh trik perpanjang masa aktif indosat :""( moso TP 200ewu...minim masa aktif 90 hari.. :""( nangis nangis "'],
#  ['XL',
#   'Musti banyak2 sabar ngadepin xl ini yaa.. Udah banyak keluhan dari pelanggan klen.. tolong bagusinlaah bodaat..!!!! @XLAxiata_Tbk @myXLCare @myXL @myXL_Sumatera '],
#  ['TRI', '@triindonesia mas sinyal nya kyk tai kucing mas '],
#  ['TRI', '@triindonesia 3 bangsat nih'],
#  ['INDOSAT', 'Streaming putus2 ni wooeee'],
#  ['XL',
#   'Ceritanya tadi mau nanya @myXL @myXLCare kenapa 2 minggu ini XL ilang di HP'],
#  ['INDOSAT', 'Membalas @IndosatCare @Sarjono98531540 Dah pasrahin aja'],
#  ['XL',
#   'sinyal xl dirumah gue BAGUS DEH! sampe pengen demo saking sinyalnya bagus '],
#  ['INDOSAT',
#   '"Membalas @abangardhie Rp 1000/Gb How Dare Are You ???? ..... BTW koq tau aku pake Paket Rakyat Jelantah ? hahaha hati hati Paket Yellow ..habis kuota atau habis waktu ... pulsa reguler akan dihajar habis dalam satu kerdipan mata. Papa memang Jahat... jawab Indosat : ""murah mau selamat...."" "'],
#  ['TRI', 'Beberapa orang ngetwit galau biar dapat simpati'],
#  ['TRI',
#   'Haha sinyal kuat ege RT @amiraslwt: pea-_- RT @DhiansyahA: Kartu kredit'],
#  ['TRI',
#   '@triindonesia ehh bangsat perasaan gw beli paket kuota yg reguler internet! Knp gw kudu jadi pindahin mode 3G-4G en sebaliknya terus kek /1 '],
#  ['XL',
#   'Lancar menterjemahkan semua jurnal berbahasa Inggris dengan cepat. tinggal 1 jurnal lagi. Thanks XL'],
#  ['XL', 'Membalas @myXL Maaf'],
#  ['TRI',
#   '@triindonesia knp signal tri di cikarang utara bikin marah.lemottttt bgt n signal sering E. '],
#  ['INDOSAT', '"Indosat sinyalnya bikin pengen nangis :"" "'],
#  ['XL',
#   'Game keren yang bisa kamu dapetin dengan gratis adalah Batman Arkham Origins! Pengguna Android pasti senang banget nih.. #XLGames '],
#  ['XL', '@myXL dimana saya bisa menyampaikan keluhan terkait XL'],
#  ['XL', 'Halo @myXLCare mengap sinyal xl di tempat saya jadi lemot tiba2'],
#  ['TSEL',
#   '"Sangat"" puas dengan layanan call center TELKOMSEL. We love TELKOMSEL "'],
#  ['TRI',
#   'Kok semenjak aku ganti IM3 kamu gak pernah sms aku lagi? Kamu marah ya @triindonesia '],
#  ['INDOSAT',
#   'Membalas @AXISgsm Duh mahal ya! Indosat donk murah 30gb 30rb 30hr 24jam paket yellow '],
#  ['TRI',
#   '@triindonesia koneksi parah.. gk ada perkembangan. Percuma lapor. Kayak tai... '],
#  ['XL',
#   '"Kuat dan kencang :p RT @fightoriniervin: Kuat po kencang ? ""@idjank_ku: Kan pake XL'],
#  ['TSEL',
#   '"Telkomsel""@chanyeolwifes: Xl tahik banget cepet abis mana mahal lagi. pingin ganti yang murah sama enak buat paketan android. Ada saran?"" "'],
#  ['TRI', '@triindonesia Ka kartu sim saya ke blokir karna abis masa tenggang'],
#  ['INDOSAT', 'Astagfirulloh nangis gua indosat dirumah gua gini amat sih '],
#  ['TSEL', '"Mosok""?? Hahaha:D RT @ReinhardBonek: Telkomsel jancok'],
#  ['TRI',
#   'Membalas @triindonesia tolong secepatnya keluhan pelanggan tri di tanggapi. '],
#  ['XL',
#   'Ini xl lagi kenapa si ? Gak jelas bgt koneksinya dari tadi SAMPAH @myXL @myXLCare '],
#  ['INDOSAT',
#   'Mantap 49 tahun Indosat Ooredoo #im3semaranginner #indosatooredoo49smg '],
#  ['INDOSAT',
#   '@IndosatCare ping kegedean asu ngeleg mulu lemot mulu kapan majunya indosat malah semakin blangsak aja Tolo dasar '],
#  ['TSEL',
#   'Murah tau. Sama aja na RT @ratnsar: Muaaaahal RT @hallowanda: Ganti telkomsel aje RT @ratnsar: m3 enak si sms sama telfonnya gratis tp '],
#  ['TSEL',
#   '@Telkomsel kenapa cacat banget sih? Tiap jam 12 malem selalu ubah jaringan. Udah paketan mahal'],
#  ['XL', 'Kecewa pake xl!! @myXL '],
#  ['XL',
#   '@myXL saya kecewa dan kesal dengan jaringan XL yg trouble dalam 1 minggu ini terutama wilayah sumbar. Saya kesal karena tidak ada pemberitahuan trouble dan lanjutan kekesalab saya ketika lgi asik gaming eh jaringan ilang. Ujung2 saya dianggap afk '],
#  ['INDOSAT',
#   'hallo @IndosatCare kenapa indosat klo sms statusnya tertunda semua?? gak bisa terima sms juga. tolong bantuannya.. '],
#  ['TRI',
#   '"@triindonesia GARA"" LU QUIZ KULIAH GW JADI SKIP JING BANGSAT! KALAH ESIA NGE LAGNYA! TOLOL!!! ANJING!!! BANGKRUT LO JING!!!! "'],
#  ['INDOSAT', 'Dear @Telkomsel kok sinyal indosat gue suka ilang2an gini'],
#  ['INDOSAT',
#   'Membalas @SilentReader00 @detikcom @jokowi To the point saja pak @prabowo ? Inilah sebagian rakyat Indonesia itu cepat lupa'],
#  ['XL',
#   'Males kali baca email yg signature-nya kek gini : Sent from my BlackBerry® smartphone from Sinyal Bagus XL'],
#  ['XL',
#   'Membalas @_Kokevin @Kevin_trailer01 trnyata klo d VIP sinyal xl yg joss..klo timur telkomsel yg buosok! '],
#  ['INDOSAT', '@IndosatCare jangkauan 4G di Bogor masih terbatas'],
#  ['TSEL',
#   'Membalas @Telkomsel @baiqalifiannisa Terima kasih sudah menunggu. Mohon kamu coba kembali sekarang jika masih terkendala tolong kirimkan screenshoot sms nya ke kami nanti kami akan mengecek lebih lanjut. ? '],
#  ['TRI', 'terima kasih @triindonesia atas bonus 768 Mb nya (????)? '],
#  ['TRI',
#   '@triindonesia kalo mau jadi csc gimana? Pengen ngelayanin pengguna tri dengan jadi csc. Kalo ada infonya'],
#  ['XL',
#   'Mau ngerasain internetan cepat dan stabil tapi belum pake XL? Dateng ke XL Center Jabo hari ini #XLappreciationDay? '],
#  ['XL', 'Membalas @myXL @tangguhniti Tai l xl anjing'],
#  ['INDOSAT', 'Ktika sy SMP kls 3 dulu'],
#  ['INDOSAT',
#   'Membalas @Fauzan_bondos19 @Fauzan_bondos19 tergantung lokasi gan kalo sinyal indosat disana bagus kecepatan lumayan '],
#  ['TSEL',
#   'Enak axis iki lo.. Murah banter.. Hahahahaah.. RT @dannyardy: Oyo??wahh..enak ta nganggo telkomsel?m3 iki yo bedes.. '],
#  ['INDOSAT', 'Selamat beristirahat @thiiafellow '],
#  ['XL',
#   'Membalas @myXL @Bang_Jos11 @myXLCare Provider anjing xl isiny cm maling dan penipu konsumen tai l xl kampret '],
#  ['XL',
#   '"Adaw RT @Rastamore: Iya ya seperti hati ku kepada mu #asik asik joss RT @apriliaAS: Sinyal XL lg timbul tenggelam --"" "'],
#  ['INDOSAT', '@IndosatCare INTERNET INDOSAT SAMPAH NORMAL 15 Mbps'],
#  ['XL',
#   'Menikmati santai dengan vietnam drip dan sinyal kencang 4.5G dari XL. Setelah seharian mengembara '],
#  ['INDOSAT', 'Edge nya indosat lumayan bagus di rumah '],
#  ['XL', '@myXL signal 4G... Speed lebih lambat dari GSM... '],
#  ['TRI',
#   'Membalas @triindonesia saya coba registrasi kok tdk bisa ya? pdhl memasukan no NIK sdh benar. Mohon dibantu secepatnya. '],
#  ['XL', 'Membalas @myXL Provider anjing ini @myXL '],
#  ['INDOSAT',
#   '@IndosatCare saya dpt sms dari indosat mengenai perubahan paket yellow ttg perubahan harga dan benefit pulsa safe . saya klik link info tidak bisa . mohon diinfokan lbh detil . terima kasih '],
#  ['INDOSAT', 'tidak sia2 pakai kartu indosat..alhamdulillah '],
#  ['INDOSAT', 'Sumpah indosat dino iki jancok tenan '],
#  ['TSEL',
#   'Sejauh ini masih sangat sangat puas dengan @Telkomsel. Belum ada masalah dan lemot sama sekali'],
#  ['INDOSAT', 'Indosat dh lumayan bagus jaringan internetnya'],
#  ['XL', 'Membalas @myXL Woi bangsat'],
#  ['TRI',
#   '@triindonesia klo mau cari informasi tentang chip 3sakti seperti program2 dan berita terbaru nya dimana? '],
#  ['XL', 'Sinyal @myXL bangsat!!!! '],
#  ['TSEL',
#   '@jrx_sid @telkomsel sy sangat kecewa provider plat merah ikut2 mendukung pro reklamasi #telkomselmusuhbali '],
#  ['TSEL',
#   '@Telkomsel Mohon bantuan kode PUK & Kode T-Care. No hp : 082166461988 Angka di belakang kartu : 6210066662461988 '],
#  ['XL',
#   'Waktunya bersenang-senang bareng teman atau keluarga di The Lodge Maribaya! '],
#  ['XL',
#   'Membalas @myXL Kalau ada kualitas!!! bukan kuota banyak tapi muter² terus tidak konek!!! Kecewa '],
#  ['XL',
#   'Membalas @myXLCare @myXL Jujur saya kecewa dengan kualitas jaringan xl saat ini '],
#  ['XL', 'Membalas @myXL Bangsat l xl 4h tai kotok '],
#  ['INDOSAT', 'cie @nisyatiara kenal sama security nya indosat nih'],
#  ['TRI',
#   'Membalas @triindonesia Saya melakukan pengecekan mengunakan bima 3 tp tidak ada informasi pengunaan kuota '],
#  ['XL', '@myXL Hai xl'],
#  ['INDOSAT',
#   '@IndosatCare cek nomor saya 081572226923 ga bisa paket 2500 yg 1GB 3hr ada pulsa tapi ga bisa daftar katanya ga cukup pulsa . Saya mau cek PING indosat lagi apa sudah bagus atau belum '],
#  ['XL',
#   '@XLCare saya baru beli paket promo joss 4.5 gb 50rb tapi sinyal di kartu xl saya tidak ada'],
#  ['TSEL',
#   'Membalas @OkkyBazt 3 gak enak :D murah iku :D RT@OkkyBazt Mkane gae 3 tok :p RT @CytraDewy_Arbnt: telkomsel gangguan'],
#  ['XL', '@myXL @myXLCare anjing lah jaringan nya jancookkk'],
#  ['XL', 'Membalas @myXLCare @XLCare belum ada mba'],
#  ['XL', 'Please'],
#  ['XL', 'Kok kesannya cuma buat sementara doang ya'],
#  ['XL',
#   '@myXL mau tanya..bisa gak ya kalau nmr saya hangus (karena lupa tidak dibelikan pulsa) kemudian ingin saya aktifkan lg...sayang bgt nmrnya bagus..mohon petunjuk min. Trims '],
#  ['TRI', 'Membalas @zrnss_game @triindonesia Hai mas gatot'],
#  ['XL', '@Bramasta050575 @myXL Bagus di iklan doank '],
#  ['XL',
#   '@myXL skrg xl lebih cenderung menjual kartu perdana dg paket data murah. Sdgkan pembelian paket di *123# sangat mahal shg kmu hars bongkar hp utk mendapatkan pket murah. Knp xl tidak jual paket d *123# tnp hrs gnt kartu dg harga yg sama???? . Mhn konfrms'],
#  ['INDOSAT',
#   'Knp koneksi Indosat di depok 1 itu jelek? Cepat saat tengah malam aja. Terakhir pakai indosat 2thn lalu & memang lelet. Kebetulan coba lg krn direkomendasikan teman ada paket murah. Please dong mas/mbaknya saya mau tanya'],
#  ['INDOSAT',
#   'Nyoba daftar paket Indosat Yellow yg katanya murah meriah pulsa 1000 dapet 1 Gb buat seharian'],
#  ['INDOSAT',
#   '@yurrayurra sy pernah pake indosat lambat. waktu itu temen pake telkomsel disini bagus. tapi kata tetangga 3 juga lumayan. '],
#  ['INDOSAT',
#   'Biasa... Coba nangis pas lagi jual indosat.. Baru luar biasa ? TIGABINTANG menambahkan'],
#  ['TRI', 'malam min'],
#  ['XL',
#   'Membalas @myXL Lokasi di seluruh jogja. Semua pengguna xl mengalami keluhan yg sama. Jaringan sangat lemot '],
#  ['TSEL',
#   '@Telkomsel cara update lokasi buat internet lokal gimana kak? bisa diupdate lebih dr satu kali ga lokasinya? '],
#  ['TRI',
#   'Membalas @triindonesia Registrasi saya selalu gagal ini. Tolong di bantu dong min '],
#  ['TSEL',
#   'Ketinggalan kereta kali ini disponsori oleh telkomsel yang tiba2 ilang signal jd gal bisa pesen gojek. Antara ingin muntah dan nangis Gusti paringono sabaaaar~ '],
#  ['TSEL',
#   'Saya sangat kecewa sekali dengan pelayanan @telkomsel CS hanya bisa memjawab dgn jawaban tidak tahu. '],
#  ['XL',
#   'Ohhh tentu bukan.... RT @govalgogo: Pasti XL :D RT itsmefunnie: Sinyal kencang'],
#  ['TRI', '@triindonesia woy yg serius dikit dong nanganin komplain'],
#  ['INDOSAT',
#   'Hujan + indomie goreng sambel matah + signal indosat = mantap ??? '],
#  ['XL', '@myXLCare Padahal 2 2 nya XL'],
#  ['INDOSAT', 'Udah 5 tahun'],
#  ['TRI',
#   '@triindonesia mau registrasi kok balasan smsnya system is busy gitu terus.. '],
#  ['TRI', '@triindonesia pulsa gw kesedot ni ?'],
#  ['INDOSAT', 'lagi main twitter di laptop atau komputer. ada sms'],
#  ['XL',
#   'Mau marah sambil nangis sama sinyal 4G @XLAxiata_Tbk @myXL di rumah. Per Minggu kemarin tiba-tiba drop parah'],
#  ['INDOSAT', '@IndosatCare hai'],
#  ['TSEL', 'Gunakankan persamaan rasa'],
#  ['TRI',
#   'Membalas @triindonesia Min saya sudah registrasi tapi ko dapet bonus kuota ya? '],
#  ['TSEL', 'Guys saranku beli pake app my telkomsel aja'],
#  ['XL',
#   'Membalas @Dedek_Charaka @myXLCare dan 2 lainnya gak di respon sama skali twit ku nok'],
#  ['XL', 'Walaupun mendung di sini tetep seger para pesertanya'],
#  ['XL',
#   'Berlibur nggak cuma untuk senang-senang & menikmati pemadangannya aja guys'],
#  ['TSEL',
#   'Membalas @Telkomsel Ayolah admin jangan membuat event2 gak karuan.. mending bikin towar diplosok2 dan fix 4G biar stabil... biar mantap. '],
#  ['TSEL', '@lewatmana hush jangan ngeflame. Saya pengguna telkomsel'],
#  ['INDOSAT',
#   'Membalas @IndosatCare Mohon ditingkatkan lagi kualitas layanan @IndosatCare agar tidak terjadi masalah seperti pulsa yang tersedot secara massal. Saya menggunakan indosat hampir 10 tahun'],
#  ['TSEL', 'saya gak bisa daftar t cash wallet mohon bantuan nya. @Telkomsel '],
#  ['TSEL', 'Membalas @aciel @Telkomsel Bikin nangis emang harga paketannya ? '],
#  ['TSEL',
#   '@Telkomsel lokasi di @JayapuraID kota Jayapura sinyalnya lemot banget padahal kekuatan sinyal full via @KadalzItem '],
#  ['XL', 'Membalas @ghinaskr @myXL Sore mba ghina'],
#  ['TSEL',
#   '"Oke tampaknya memang pake telkomsel adalah pilihan terbaik -__-"" "'],
#  ['XL', 'Kuota mahal'],
#  ['INDOSAT',
#   'Membalas @IndosatCare Saya heran dengan indosat kok bisa bsanya ada sms konten padahal kita gak ikut sms konten '],
#  ['TSEL',
#   'Membalas @Telkomsel @SelbieSatria30 saya sudah hampir 5 tahun pake telkomsel aman aman aja.. walaupun suka down tp diatasinya cepat haha mantap tsel '],
#  ['TRI',
#   'Kuota @triindonesia vs unlimited @ask_AXIS ? menang Axis lah orang axis sinyalnya stay di 4G Klo 3 4Gnya super cacat kayak anjing '],
#  ['XL', 'Nyesel isi ulang paketan @myXL. Bangsat masih lag jam segini. Babi '],
#  ['TRI',
#   'Membalas @triindonesia min tlg perbaikan dong jaringannya internet nya jgn kek tai apah menjijikkan bgt koneksi Internet nya fakkkkk lah '],
#  ['TSEL', 'Email menumpuk'],
#  ['TRI',
#   'Wah keren @triindonesia respon keluhan dan kasih solusi dalam waktu yang cukup cepat. Trima kasih! :) '],
#  ['XL',
#   'Beli kuota @myXL @myXLCare 240rb belum sehari udah jadi sampah haha ga bisa dipake sama sekali ? mantap lah '],
#  ['INDOSAT',
#   'hai @IndosatCare apa indosat sedang ada kendala lagi? sast ini sinyal tidak bisa 4g'],
#  ['INDOSAT',
#   'Membalas @mhudalloh @ustadtengkuzul @Gemacan70 Ada yg murah.... 1Gb/seribu paket yellow'],
#  ['TSEL',
#   'Woi anjing @IndosatCare @Telkomsel jaringannya kayak tai ... Bangsat '],
#  ['TSEL', '@Telkomsel tolong di respon dong keluhan customer'],
#  ['TRI',
#   'Membalas @triindonesia @triindonesia karena ku sanggup utk slalu berdoa & berusaha di jaman yg trbilang keras dgn Three maka bsa hemat untuk rakyat #TriJakartaFair '],
#  ['INDOSAT', 'Ni aq make simpati'],
#  ['TSEL',
#   '@Telkomsel mas mba. Saya beli perdana simpati loop tapi tdk dapat regist. Pdhal NIK dan KK suda bnar tlg bantuan nya. Mohon banget. No: 082274925914 '],
#  ['TRI',
#   '@triindonesia sinyal taek jaringan bangsat gak guna operator jancukan mati ae kon cok '],
#  ['TSEL',
#   '"Heh #Telkomsel jancok... Prasa""an provider lain waktu ganti jam paketan gak pake ngilangin sinyal paket data...... http://fb.me/51AjQwvue "'],
#  ['TSEL',
#   'No ini me nelp mengatasnamakan @Telkomsel mohon bantuan dari @Telkomsel '],
#  ['TRI', 'Kini tersedia paket AXTRI 1juta murah meriah !!! AXIS 1'],
#  ['INDOSAT', 'Aku pake indosat eon'],
#  ['XL', '@myXL @myXLCare provider penipu anjink'],
#  ['XL', '@myXL @myXLCare Internetan dengan XL sangat lambat'],
#  ['TRI', 'Membalas @triindonesia Sinyal bangsat '],
#  ['INDOSAT',
#   'Maka nya gnti kartu lo dan pake @indosat snyal cepat dan stabil @privasirait '],
#  ['TRI',
#   '"3G""@BekantanKEPO: sinyal hp pian edge kah tri G ? #AdingTantan"" "'],
#  ['XL', 'tak cukup akses cepat'],
#  ['TRI',
#   'Ternyata skrg sudah bisa twitter-an gratis dgn Internet Tri AlwaysOn (AON) @triindonesia http://bit.ly/Sw6YXU '],
#  ['XL',
#   '@myXLCare sia sia gue isi paket data ga bisa di pake udah 2 hari costumer service nya juga ga bisa di hubungin'],
#  ['TSEL',
#   '@Telkomsel sudah 3 hari 4G mu kagak bisa anjing!! Tanggung jawab woi '],
#  ['TSEL',
#   'Membalas @SobatHAPE masalahnya kita lbh pilih mahal dikit tp lemot ketimbang mahal banget tp lemot juga. cth telkomsel 65k dpt 30GB dg pembagian tentunya. kalo beli pulsa bisa habis 100k baru dpt 30GB dg pembagian yg sama. speed nya ancur pula di 4Gnya. ya jelas pilih 65k dpt 30GB kartu sekali pake. '],
#  ['INDOSAT', 'Membalas @asyhph @aiisyaaaah sebulan kmrn aku nyoba xl'],
#  ['INDOSAT',
#   'Sama parah nih RT @kfto29: Sinyal indosat bikin nangis @indosatcare ??? beli paket mahal toh sama aja. '],
#  ['TRI', '@triindonesia tolong di respon keluhan saya'],
#  ['INDOSAT', '@IndosatCare mantap jaringan indosat drop lagi'],
#  ['XL',
#   'Membalas @myXL @myXLCare Kenapa jaringan kaya gini pake LTE serasa pake 2G lambat bener udah gitu lagi signal naik turun lagi '],
#  ['XL', '"Mari mulai hari ini dengan berita yang bikin senang'],
#  ['TRI',
#   '"Membalas @triindonesia mau kasih kejutan tapi ga punya pasangan. gimana dong? tolong bantu agar program ""voucher asmaraku"" berjalan lancar dgn semestinya "'],
#  ['TRI', 'Membalas @triindonesia tai lahhh '],
#  ['XL', '"Membalas @myXL #XLBagiBerkah Kecepatan jaringan""y kenceng abis'],
#  ['TRI', 'Tai lo! @triindonesia bisanya pending aja! Sial doangan '],
#  ['INDOSAT', 'Membalas @lindrafrvd Halo'],
#  ['TSEL',
#   'Buat apa mahalnya? Gue telkomsel nih *mjb RT @beefyfeb: Jancok. Mahal itu RT @manjatgones: makanya pk telkomsel kaga pernah tuh pending '],
#  ['TSEL', 'kalo ppake bb enak nya paske telkomsel '],
#  ['TSEL', 'Ok'],
#  ['XL', 'Sinyal XL lg kencang nih °\\(???)/° '],
#  ['TRI',
#   'Wah tumben nih di kosan sinyal tri bagus... Hahaha ? azeeek mantap ?? (at Wisma Wibisono) — https://path.com/p/1PRU3C '],
#  ['TSEL',
#   'Apa pendapat kamu ttg orang yg buang sampah sembarangan di gunung? Jangan ditiru ya'],
#  ['INDOSAT',
#   'Membalas @acifahifah9 Iyh tpi alhamdulillah kuota malamnya 5GB ga kyk indosat 13GB :( '],
#  ['TSEL', 'Membalas @Telkomsel @Telkomsel oh gitu ya min'],
#  ['TRI', 'Membalas @triindonesia @triindonesia kalo marah'],
#  ['TRI',
#   'Kapan benernya ini di daerah cilamaya wetan koneksinya bangsat sampe ketinggalan ulangan gini @ask_AXIS masa kalah sama @triindonesia sih '],
#  ['INDOSAT', 'Liat timeline @indosatcare pada ngmongin 4G an'],
#  ['TSEL',
#   'bersama @Rosalia12 jbr-jogya tanpa wifi kalah sm @PO_EKA_CEPAT cak... untung ada @telkomsel flash lumayan #mudik '],
#  ['XL', 'Pada jaman dahulu'],
#  ['TSEL',
#   'Enak pake simpati freedom murah sesama telkomsel nelpon 1 menit gratis berjam2 '],
#  ['TSEL', 'WOY INTERNET GUE GIMANA INI? KAPAN BISANYA? ANJING @Telkomsel '],
#  ['TSEL',
#   'SANGAT PUAS utk pelayanan @Telkomsel khususnya di GRAPARI ITC ROXY MAS. Kmrn sangat kesusahan utk registrasi ulang'],
#  ['INDOSAT', 'dear Indosat'],
#  ['TRI',
#   'Membalas @triindonesia bagaimana update an nya? parah banget tri asli sekarang parahnya banget'],
#  ['INDOSAT',
#   'Membalas @jars_onyonds @IndosatCare INDOSAT MAH TOLOL... JARINGAN SUKA LAG NGAPAIN LU MAKE INDOSAT ANJING INDOSAT ANJING '],
#  ['TSEL', '@Telkomsel Admin'],
#  ['XL', 'Membalas @myXL @myXLCare Provider anjing xl '],
#  ['XL', 'Xl.ku gak joss RT @ngakanyoman Sinyal di surabaya joss '],
#  ['TRI',
#   '@triindonesia provider terburuk sepanjang sejarah indonesia..!! Gegayaan lu bangsat sponsorin mobile legend tapi ngeleg.. Anjing Dancok udah 5 hari ga bisa internetan ini aja make wifi.. '],
#  ['TSEL', 'Yatuhan hujan seharian Telkomsel'],
#  ['INDOSAT',
#   'Membalas @IndosatCare #HariKonsumenNasional....Indosat.. bagi sy bagai kan kekasihku udah murah Dan mudah terakses ke seglapenjuru. Selamat Hari Kinsmen Indonesia '],
#  ['INDOSAT', 'indosat getting worse. asu Terjemahkan Tweet'],
#  ['XL',
#   'Membalas @helmianselmo Perlu donlot kenceng Bro..? Lha ini @myXL_Jabo @myXLCare juga aneh'],
#  ['TSEL', 'pake telkomsel emg enak bgttt cepet'],
#  ['INDOSAT', 'Membalas @EBoyzzLove indosat jancok '],
#  ['TRI',
#   'Halo operator cacat @triindonesia ...mau registrasi lewat aplikasi bawaan aja gini'],
#  ['XL',
#   'Membalas @myXL Ia.. Nonton nya patah-patah karena sinyal jelek.. Kualitas sampah. '],
#  ['TRI',
#   '"Koneksi Internet di Indonesia memuncaki peringkat 1 sebagai Koneksi Tercepat Bikin Marah'],
#  ['INDOSAT',
#   'Membalas @IndosatCare @aduanBRTI @YLKI_ID Apa segitu susahnya ya proses stop SMS Indosat? Boleh tau gak tindakan apa aja yg udah dilakuin kok sampe 1 bulan ga kelar2 urusannya dan sampe hari ini saya msh trs dikirim sampah? '],
#  ['TSEL',
#   '@Telkomsel mohon bantuan telkomsel. Nmr telfon kami kontaknya diretas orang yg gak bertanggung jawab. Gimana cara menindak lanjutinya. Karena sdh banyak org yg tertipu. '],
#  ['TRI', 'Membalas @triindonesia nyaman kpd nasabah. Tks ~ Aldi '],
#  ['TSEL', 'Seturan'],
#  ['XL',
#   '@myXL wey xl ini kenapa sinyal ilang2an padahl jaringan adaa ? Coba kasih tau alasannya'],
#  ['TSEL',
#   'Membalas @NendraLasmana RT @NendraLasmana: telkomsel RT @Arif_Suhada: Kartu apa yang enak buat internetan yg murah and koneksi cepat? '],
#  ['TSEL',
#   '"Iyah mao pake telkomsel aje :p ""@ayuriifa: Ganti provider ajee :D ""@AresDaunn: Murah sih'],
#  ['XL', '@myXL saya ingin konfirmasi mengenai sinyal'],
#  ['INDOSAT', 'UGM dan Indosat membatalkan pembicara pro HTI'],
#  ['INDOSAT', '"Membalas @IM3OoredooMTR @IsatOoredooMTR jalan"" k pantai'],
#  ['XL', 'network nya cacat nih @myXL '],
#  ['XL', 'Membalas @myXL @nfryda Reastart kepala l aja xl bangsat '],
#  ['TRI',
#   'RT @triindonesia: Jaman sekarang kayanya mudah sekali untuk mendapatkan informasi ya'],
#  ['TSEL', '"ga enak'],
#  ['XL',
#   '@myXLCare @myXL tiap hari laporan keluhan hilang kuota selama sebulan tanggapan hanya tunggu update doang ah XL memang tdk bertanggung jwb atas keluhan pelanggan cuma mau ambil untung sendiri tanpa mau slesai kan masalah pelanggan '],
#  ['XL',
# ...
#  ['TSEL',
#   'Membalas @ayuwidy2nd @Telkomsel Ntah lah mbak agak kecewa juga di tengah main sinyal mancet '],
#  ['TSEL',
#   'Membalas @zuraydasalim1 Sama mbak sy ikut sebulan 4GB 2 minggu lgsg habis sy juga kecewa @zuraydasalim1 @Telkomsel '],
#  ['TRI', 'kalo @triindonesia '],
#  ['TRI', 'tadi sore ditelp operator @triindonesia Jakarta'],
#  ['XL',
#   'Membalas @myXLCare @fadlunfauzi @myXL 4g provider bangsat xl maling '],
#  ['XL', 'Mifi XL GO paling enak dipake rame2 yo. Sinyal kencang'],
#  ['TSEL',
#   'Pertama kali berasa sangat puas dgn layanan customer service Telkomsel. #telkomselGandaria'],
#  ['XL',
#   'Jadi setahun belakangan internet gw sering mati-mati sendiri & kalau hidup pun lambat banget. Percuma ada kuota YouTube juga'],
#  ['TSEL', 'Terimakasih'],
#  ['TSEL', 'AKU OREP MANEH.PULSA TELKOMSEL KU MBALIK! JANCOK ANCEN '],
#  ['TSEL', 'Sinyal 4 G di oro2 dowo kota Malang lemot @Telkomsel '],
#  ['XL',
#   'Hahaa demi sinyal hape RT @shuangli99: Wah sinyal xl da kartosuro joss bgt.. Gimana kalo ak pindah kartosuro aaja yaaa???? '],
#  ['TRI',
#   'Membalas @triindonesia bisa kah memberikan saya informasi tri retail?? Untuk wilayah cengkareng '],
#  ['INDOSAT', '"Situ jual aset indosat'],
#  ['TSEL',
#   'enak opmin unlimited-an pake telkomsel . uda murah cepat pula #abisinitandatangankontrak '],
#  ['INDOSAT', 'JANCOK'],
#  ['XL',
#   'Test ilmu JOSS tuh #ehhRT @vidisarah: Test Sinyal yah mas hendy..XL nya sdg Bermasalah nih sinyalnya..RT @hendy_JOSS: Test.. '],
#  ['TSEL', 'Telkomsel ini memang penyedot pulsa terbaik ya..subhanallah! '],
#  ['INDOSAT', 'Jaringan terbaru indosat mantap :D '],
#  ['XL', 'XLamat Hari minggu'],
#  ['XL',
#   '@myXL Sekali nya make prov ini. kesan nya langsung KECEWA BERAT ??#nuhunxl '],
#  ['XL',
#   'Untuk @myXL dan @XLCare yang terhormat. Saya kecewa dengan pelayanan xl yang susah sekali untuk masuk di halaman my xl di aplikasi maupun melalui browser. Saya ingin isi ulang paket internet modem saya jadi tidak bisa ini terjadi selalu berulang-ulang . '],
#  ['TSEL', 'Ini telkomsel gangguan atau apa sih anjing'],
#  ['TSEL', 'Telkomsel'],
#  ['XL',
#   'mereka gatau nyanyi lagu apa coba kalo bisa request lagu korea mantab kali ya si golden boyz @myXL_Jabo #Xtravaganza #Fantaxis4Jabo '],
#  ['TSEL',
#   'Membalas @RANS_surabaya Min telkomsel lagi sos ne tahu gk card sim yg enak murah twitteran @fellyciousisme '],
#  ['XL', 'Membalas @ask_AXIS Di daerah rumah saya saja min'],
#  ['INDOSAT',
#   'Tolong bantuan nya dong ini sinyal indosat jelek banget lola bnget. Mhon di bantu terima kasih.@IndosatCare '],
#  ['XL',
#   'Membalas @komanksu Gamau nyoba xl prioritas bli? Kenceng sinyal lumayan murah jg untuk kelasnya '],
#  ['TRI', 'Membalas @triindonesia @triindonesia makasi informasi nya min'],
#  ['XL',
#   '@myXL Salam hormat untyk xl. Saya mau sampaikan keluhan saya yang terjadi kemarin dan sampai sekatang belum seleSai.. Yaitu kuota paket xlcombo 37 gb tiba tiba habis padahal pemakaian bari satu hari dan itupun baru dipakai untuk chatimgan... Mohon bantua'],
#  ['INDOSAT',
#   'Sabar yah bro.. klo malam emang kek gitu RT @Ririsflorida: Gila ya indosat ooredoo sinyalnya jelek banget. Mau nangis ? '],
#  ['INDOSAT',
#   'Woow heebat cepet bnget RT @RheinaDefani: RBT nya @XO_IX udah ada loh buat Indosat & XL =) terus sbentar lg ... http://tmi.me/bkmQT '],
#  ['TRI',
#   '"Wow #AlwaysOn dong ya :) RT @kriewull: @triindonesia udah 5 tahun pake tri lancar"" aja.. :D kartunya mantab'],
#  ['TSEL',
#   'Klo kartu baru gitu byarny brp lex? RT @alex_turang: @tarisrtari ke graphari telkomsel cpt koq'],
#  ['XL',
#   'Ini XL lucu.. Di lantai 20 sinyal amburadul tp 2 lantai dibawah basement sinyal pol'],
#  ['TRI', '@triindonesia 4g lo cacat di cilegon '],
#  ['TSEL',
#   '@Telkomsel Kak aku mau registrasi kok nggak bisa malah muncul hanya panggilan tetap pas aku mau nonaktifkan fdn nya malah disuruh masukin kode puk trus gimana kak? '],
#  ['XL', 'Hai selamat pagi'],
#  ['TRI', 'Membalas @triindonesia makasih min'],
#  ['XL', 'Membalas @myXL Bukti layanan sampah C19143112'],
#  ['XL',
#   'Membalas @edwardsuhadi @aMrazing @myXL Yakin Lex bukan wifi loe itu? Macasih XL sampe segitu? ? Itu Sinciapo tuh emang ya ampun'],
#  ['XL', '@myXL provider sampah'],
#  ['TRI',
#   'Membalas @triindonesia @triindonesia asli min TVC nya banyak bgd yg ngena nih . Hahahaha . Mantab emg 3 sekalinya buat iklan bermutu bgd (y) '],
#  ['TSEL',
#   'asli lah @telkomsel ini kampret. udah harga paket internet makin mahal'],
#  ['XL',
#   '@myXL cumaa di XL jaringan 4G sinyal full kuota banyak tapii gabisaa internetan cumaa di XL kecewa beratt sumpahh '],
#  ['TRI', 'Membalas @triindonesia Cukup. hayati lelah maas'],
#  ['TRI',
#   '@triindonesia keluhan saya kok ga dijawab ya ? Dari kemarin sampe skrg ? '],
#  ['TRI',
#   '@triindonesia jadi ajudan beliau aja pasti mudah deketinya #3BangkitIndonesia '],
#  ['INDOSAT', 'indosat udah lancar ni?? alhamdulillah '],
#  ['XL',
#   'Bangsat benerlah ini provider nguji kesabaran di bulan suci Ramadan @myXL @myXLCare '],
#  ['XL',
#   'Membalas @myXL @masiponk Selamat siang sis saya mau bertanya tentang keluhan sya apa sis bsa membantu sya jlaskn masa berlaku kartu sya '],
#  ['INDOSAT', 'Alhamdulillah Hujan....!!! Ready Axis 1gb'],
#  ['XL',
#   'Membalas @myXLCare @myXL @RioNyoch1 Provider anjing xl isiny cm maling dan penipu konsumen '],
#  ['TRI', 'Membalas @triindonesia @Jokoki898 Tai'],
#  ['XL',
#   'Bangsat fuck minta data malah di cuekin @myXL @myXLCare #kuotahilangsendiri !!! '],
#  ['XL', 'Membalas @myXLCare @alldiJF Provider goblok maling l xl tolol '],
#  ['TSEL',
#   'Membalas @Telkomsel Ok terima kasih Tolong supaya di daerah saya ini tercover 4G juga ya'],
#  ['XL',
#   'Halo min @myXLCare @myXL kok tweet saya tidak ditanggapi min. Internet Xl selalu tdk bisa diakses'],
#  ['TSEL',
#   'Membalas @kaatuu @princek2 Gratis yo wah enak tenan aq pake telkomsel ne mahal he he tp ad trik biar murah he he '],
#  ['XL', '@rsaputraa @myXL @myXLCare Bagus '],
#  ['TSEL',
#   '@Telkomsel udah seminggu belakangan ini 4G hallo kick saya ga stabil tiap jam 22.00 keatas'],
#  ['XL',
#   'Membalas @XLAxiata_Tbk @keristiar dan 3 lainnya Provider bangsat ganti l kerugian konsumen anjing l. Maling jd provider bangsat xl '],
#  ['INDOSAT',
#   '"Kembali kasih :) ""@romi_asdi: Bahagia itu kalo balas tweet lancar n cepat'],
#  ['TSEL',
#   'Membalas @Telkomsel Seharian kemarim nyoba beli gagal terus .. ada gangguan infonya . Kecewa '],
#  ['INDOSAT', '@IndosatCare selamat sore'],
#  ['TRI',
#   'Membalas @3Tri_Indonesia @3Tri_Indonesia @triindonesia betul gak three mengadakan undian poin 3 care mohon informasi nya '],
#  ['TSEL',
#   '@telkomsel mbak/mas gimana nih udah 3 hari gw main game tapi ga bisa'],
#  ['INDOSAT',
#   'Photo: Jaringan baru cepat dan stabil #Repost @endahtri95 ??? #iwantitnow #indosat #im3 http://tmblr.co/ZvPRtr1gi3TL6 '],
#  ['TSEL',
#   'lemot ya lemot aja RT @Telkomsel Tergantung untuk paket yang digunain'],
#  ['TRI',
#   'Makasi Kaka Mimin RT @triindonesia: Informasi lengkap PakeTri Hello Masa Aktif Panjang bisa langsung klik disini ya http://bit.ly/1Aa5evB '],
#  ['TSEL', 'Seneng pake telkomsel'],
#  ['XL', 'Terima kasih'],
#  ['TSEL', 'On pake telkomsel tujuan utamanya adalah biar paketan tri ga abis'],
#  ['TRI',
#   'Membalas @triindonesia @triindonesia cinta seperti serangkaian huruf yg membentuk satu kata hingga menjadi kalimat utuh yg mudah dibaca #AhliCinta '],
#  ['TRI',
#   '@triindonesia sinyal kaya tai aja lagu2an sposorin ML! Urusin dulu sinyal lu bego!!!!! Semenjak sponsor atau bayar apa aja paket tri jadi kontol sinyalnya '],
#  ['XL', 'iya sih.. dirumahku'],
#  ['TRI', '@triindonesia kemarin 3 eror pacar gue marah min???? '],
#  ['INDOSAT', 'Membalas @JoneKan Hi Ibu Kandou'],
#  ['INDOSAT',
#   'Membalas @TelkomCare Saya regist pake indosat ga bisa bos... Terus saya regist pake telkomsel wah mantap terasa... '],
#  ['XL',
#   'Membalas @myXLCare @alldiJF Provider bangsat xl maling jadi provider l xl goblok '],
#  ['INDOSAT',
#   'Membalas @IndosatCare Baru kemarin isi pulsa 5000 buset ini cek pulsa langsung Rp 0 wkwkwk Lol banget sumpah baru kali ini ada operator sebesar indosat pelayanannya maling malingggg @kemkominfo Tolong cepat ditangani'],
#  ['TRI', 'Aku & Tri seperti hubungan pacaran yg udah lama'],
#  ['XL',
#   'Membalas @agusmanlubis16 @myXL @myXLCare lebih cape liat keluhan custimer di sosmed dari jaman dulu tapi gapindah2 operator meng hahahaha '],
#  ['XL', 'sinyal OK'],
#  ['TRI', 'Telpon murah seharian ke semua operator'],
#  ['TRI',
#   '"Makanya pke tri :D ""@FirmaIndah: Sinyal di jatinangor dak mantap :P"" "'],
#  ['TSEL', '@INDOBARCA_JYPR: Oia'],
#  ['TSEL',
#   'Dear @Telkomsel saya baru saja registrasi kartu tp tulizannya NIK tidk ditemukan. Mohon bantuan. Nomor dan ID di DM '],
#  ['TSEL', 'Kalau masih gini gimana? Udah di restart'],
#  ['XL', '@Bagus_Satub @myXLCare @myXL Nek liyane yo mbuh..hahaha '],
#  ['TSEL',
#   'Waw sungguh puas membaca keluhan para pelanggan #TELKOMSEL di @detikcom ... Sangat ² kecewa dgn kwalitasnya .. http://myloc.me/iF4Vj '],
#  ['INDOSAT', 'Membalas @IndosatCare Aku baru isi pulsa kemarin sore'],
#  ['INDOSAT', 'Indosat ngapa si anjing kesel banget '],
#  ['TSEL',
#   '2) @Telkomsel kok lemot ya? Apakah benar dr telkomsel ini perdana nya '],
#  ['TSEL', 'Butuh telkomsel poin buat jajan murah'],
#  ['INDOSAT', 'Kerja Sama PT Indosat '],
#  ['INDOSAT', 'No signal @IndosatCare sudah di restart'],
#  ['XL',
#   'Internetan Pake Xl Rasakan Jaringan HotRod Internet Super Cepat & Stabil. Cek *123# '],
#  ['XL', '@myXL JARINGAN NAJIS NGEBATIN AMPUN'],
#  ['TSEL',
#   'Sinyal 3G Telkomsel lumayan cepat di Sekolah Laskar Pelangi- Kota Manggar :) (at GeraiHALO Manggar) [pic] — http://path.com/p/1JWUFN '],
#  ['XL', 'Udah nyala.. Sekarang lg dibanda aceh'],
#  ['TSEL', 'hai @Telkomsel anjing ? '],
#  ['XL', 'Pasti XL :D RT @itsmefunnie: Sinyal kencang'],
#  ['TSEL', 'kecewa doi ko jadi cacat bgt @Telkomsel '],
#  ['INDOSAT', 'RT iyah'],
#  ['TSEL', 'Duuh jd ngrepotin gini'],
#  ['INDOSAT',
#   'Membalas @P3nj3l4j4h @jokowi dan 6 lainnya Alhamdulillah.... ternyata ada yang lebih bermafaat dibanding membeli indosat.... '],
#  ['XL',
#   '@myXLCare @myXL kalian beneran provide 4G service gak sih. Pingin nangis rasanya. '],
#  ['TSEL',
#   'Membalas @kulineryogya @kulineryogya soto ayam yg enak soto pak dalbe sebelahnya telkomsel lama..murah pula '],
#  ['TRI',
#   'Emang operator 3nya ka yg bafukkkkRT @niezzmay: Ini kartu gue doang apa emang operator tri yg gda sinyal -_- bapuk '],
#  ['INDOSAT', 'Alhamdulillah sinyal 4G indosat sudah normal kembali '],
#  ['TRI', 'Hahahhahahha...marehhh'],
#  ['XL',
#   '@myXL min xl lagi gangguan? Kenapa koneksi internetnya lambat sekali? Padahal sinyal bagus LTE. '],
#  ['TRI',
#   'Indosat udah gabung sama tri ya sekarang ? Kuota doang banyak sinyal lemotnya mantap @IndosatCare '],
#  ['INDOSAT', '"RT @Auliyamaharani: Sumpaaaaaah indosat what the hell yah'],
#  ['TRI',
#   '@triindonesia anjing sinyal ilang 15 menit gua lagi di game bangsat. nherrikn lah gua gamer. kerja ngapain aja kontol '],
#  ['TRI', '@triindonesia benci jadi cinta'],
#  ['TSEL',
#   'Karena 4G atau 3G @Telkomsel @simPATI sangat cepat dan kuat signalnya....apalagi sdg nongkrong @ExcelsoCoffee ......?????? '],
#  ['XL', 'Ada apa dengan @myXL ??? @myXLCare Masak iya'],
#  ['TRI', 'asik :) @DimasYoung: Beli perdana 15rb isi pulsa 15rb'],
#  ['INDOSAT',
#   'RT @kikidieryolank: Aku Seneng bgd ungu band mraih menang indosat award kpn nih hits klip ke-3 & mantap Alm.Benyamin S mraih indosat Legen '],
#  ['TRI',
#   'Membalas @menikuswati Aku sih isih ng yk nik ? Widihh mantap tak kiro susah sinyal nik wkwkwk '],
#  ['INDOSAT',
#   'Nah kaya gini kan enak. Jadi ada klarifikasi dari Indosat & pengguna gak capek ganti ganti jaringan. Terima Kasih Mba Mila. Semangat ya kerjanya. Jangan jaringan aja yang dipelihara. Hati juga ~~ wuff! ????? ?????? menambahkan'],
#  ['INDOSAT',
#   'ganti aj dit :) RT @dittiy: pokoknya saya lagi kecewa berat sm Indosat M2.kualitas sinyal HSDPA n GPRS nya kalah sama 3 '],
#  ['INDOSAT',
#   'Membalas @IndosatCare Pulsa saya berkurang 7000 ribu saat ada sms dari i-Ring'],
#  ['INDOSAT',
#   '@IndosatCare min tolong bantu cek no indosat saya di no 08159279661'],
#  ['TSEL', '@Telkomsel wei anjing'],
#  ['INDOSAT', 'Membalas @amaar25 @amaar25 Hai Kak'],
#  ['TRI', 'Lumayan Lapar :3 RT@triindonesia: Selamat siang'],
#  ['TRI',
#   '@triindonesia paket malam gue kok gak aktif operator kontol?! ? Bangsat lu semua! '],
#  ['TRI',
#   '@triindonesia ini sinyal tri di rumah saya masih lemot dan tidak terjangkau 4g. Jangan di suruh pindahkan ke HP lain deh'],
#  ['TRI', 'Berngkt krj tpt jm 8'],
#  ['TRI',
#   'Enaknya make tri nih gini. Paket murah sinyal 3g gapake pending! Axis buat di hp butut aja buat smsan wkwkwk. '],
#  ['INDOSAT', 'Membalas @IndosatCare Sudah dari 2008 pake Indosat'],
#  ['TRI', '"@triindonesia min folback'],
#  ['INDOSAT', 'Membalas @RahmatLintang2 Hi Kak'],
#  ['INDOSAT', '3. Sebulan kemudian ke indosat'],
#  ['INDOSAT',
#   'Membalas @rlthingy Kirain kartu gua keblokir. Indosat asu emg. '],
#  ['INDOSAT', 'Indosat bikin nangis nih T______T '],
#  ['INDOSAT',
#   'Kenapa sekarang indosat kuotanya juga kebagi ada yg midnight pula.? Jam terbang paling banyak kan pagi malem om.?duh cepet abis '],
#  ['TSEL', 'Membalas @Telkomsel Boleh saya minta bantuan terkait nomor saya '],
#  ['INDOSAT',
#   'Membalas @mandanaila @onlymand @DinaErKa @IndosatCare sblm d ganti'],
#  ['XL',
#   'klik link http://bit.ly/i86HQL RT @riobimoo Gmn sih caranya?RT @XL123: @tomigumilangs Alhamdulillah sy dpt paket Gemini XL murah dari @XL123 '],
#  ['TRI', 'Min @triindonesia '],
#  ['TRI',
#   'Membalas @rlthingy Tergantung sinyal di rumah kamu sih. Xl lebih murah tp ya di aku xl lemot parah. Bagusan tri '],
#  ['XL', 'Di dalem gor uny ini xl ga ada sinyal'],
#  ['TSEL',
#   'Sedang kecewa sama layanan BIS @simPATI @telkomsel beberapa hari ini. Kalo udah di atas jam maghrib paket BIS-nya NGGAK bisa dipake. Tumben! '],
#  ['XL',
#   'Sinyal kuat XL membuat surfing terasa lebih cepat dgn PAKET BALCKBERRY DARI XL. #cek123 '],
#  ['INDOSAT',
#   'INI FIRSTMEDIA AMA INDOSAT KNP SIH ANJING DARI SIANG GW OFFLINE '],
#  ['TSEL',
#   'Saya ucapkan terimakasih kepada tim @Telkomsel GraPari PGC Lt 3A & Telesindo Mall Kalibata yang sudah mempermudah saya membuat kartu saya yg hilang'],
#  ['TRI', 'Sinyal tri lemot'],
#  ['TRI',
#   'Jual pulsa paket internet all operator. Murah bgt!! Indosat 2GB 24jam/30hr cuma 38k'],
#  ['INDOSAT', 'Gileee baru laporan indosat kalo paketan bermasalah'],
#  ['XL',
#   '"Yeahhh RT @aanaccess Jiaaah disini sinyal 2G aja gak nongol ""@kompascom: Seberapa Kencang 4G LTE Besutan XL Axiata? http://kom.ps/AFonLx "" "'],
#  ['TSEL',
#   '#PejuangForward Guidolin Puas Raih Kemenangan Magis di Anfield: Francesco Guidolin merasa sangat g... http://bit.ly/UkqlJa cc @telkomsel '],
#  ['TSEL',
#   'Membalas @Telkomsel JANCOK. DIREKTURNYA BUSUK TUKANG KORUPSI PULSA PELANGGANANNYA ! @Telkomsel '],
#  ['TRI', '@triindonesia min'],
#  ['TSEL', 'aku juga pnya trie'],
#  ['XL',
#   '4G XL Itu Jaringannya sangat memuaskan banget bagi para pengguna XL #XL4Gmobile '],
#  ['XL', 'Sepertinya harus pake XL nih'],
#  ['INDOSAT', '@IndosatCare ga lagi-lagi sy pake indosat ya'],
#  ['XL',
#   'Membalas @myXL @hermawansyah29 Hy provider xl bangsat. Kebanyakan nipu konsumem l anjing pake byk alesan kampret '],
#  ['TSEL',
#   'Masa siiy... Gw gak niy RT @MuhammadMelvin: Kecewa bgt dgn telkomsel'],
#  ['TSEL',
#   'Membalas @Telkomsel @Telkomsel kita tunggu kehadiran nya di solo....tapi untuk saat ini sudah sangat puas dengan kecepatan internet yang ada '],
#  ['TRI',
#   'Admin @IndosatCare lelet ya sekarang.... balas cat lelet DM lelet.. kalo @Telkomsel @myXLCare @triindonesia lumayan cepet... mungkinkah micin kebanyakan?? #PramborsThrowback #WARTEGDKIEPS18 '],
#  ['TSEL',
#   'Tae loe telkomsel bikin gw kesel aja loe mau loe apa sih tiba2 lost koneksi jancok goblok.. '],
#  ['XL', '@myXL Sinyal full 4G tapi koneksi sangat lambat.. kecewa '],
#  ['INDOSAT',
#   'Indosat Ooredoo memperkenalkan 4Gplus untk memberikan jaringan yg lbh kuat'],
#  ['INDOSAT', 'Gila ya indosat ooredoo sinyalnya jelek banget. Mau nangis ? '],
#  ['XL', 'Membalas @dikki_cantona Hahaha benar2 bikin bablas Mas'],
#  ...]

# %%
# Declare StemmerFactory from Sastrawi
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# %%
# Cleaning RAW
listwit[0][0] = 'INDOSAT'

for row in listwit:
    row[1] = row[1].lower()
    row[1] = re.sub(r'\s\s+',' ', row[1])
    row[1] = re.sub(r'http\S+', '', row[1]) #hapus link http
    row[1] = re.sub(r'@\S+', '', row[1]) #hapus mention
    row[1] = re.sub(r'Membalas', '', row[1]) #hapus membalas
    row[1] = re.sub(r'RT', '', row[1]) #hapus RT
    row[1] = re.sub(r"\.", '', row[1]) #hapus titik
    row[1] = re.sub(r",", '', row[1]) #hapus koma
    row[1] = re.sub(r":", '', row[1]) #hapus titik dua
    row[1] = re.sub(r"\?", '', row[1]) #hapus tanda tanya
    row[1] = re.sub(r"!", '', row[1]) #hapus tanda seru
    row[1] = re.sub(r"#", '', row[1]) #hapus hashtag
    row[1] = re.sub(r"\(", '', row[1]) #hapus (
    row[1] = re.sub(r"\)", '', row[1]) #hapus )
    row[1] = re.sub(r"\[", '', row[1]) #hapus [
    row[1] = re.sub(r"\]", '', row[1]) #hapus ]
    for i in range(0,9):
            row[1] = re.sub(r"{}".format(i), '', row[1]) #hapus ]
    row[1] = re.sub('(\\b[A-Za-z] \\b|\\b [A-Za-z]\\b)', '', row[1])
    row[1] = re.sub(r"[^A-Za-z0-9().,<_>!?\'`]", ' ', row[1]) #hapus entah apa ini :v
    row[1] = re.sub(r"\s{2,}", ' ', row[1]) #hapus entah apa ini :v (2)
    
listwit

# lowerCase = []
# for i in lttoken:
#     for j in i[1]:
#         j = j.lower()
#     lowerCase.append(i)

# noUname = []    
# for i in lowerCase:
#     noUname.append(i[1])
    
# noUname.pop(8)    
# for i in noUname:
#     num = []
#     for j, k in enumerate(i):
#         if k is '':
#             num.append(j)
#     print(num)
#     print(i)
    
    
#     for l in num:
#         del i[l]
#     print(i)
#         if k[0] is '@':
#             num.append(j)
#     print(num)

    
#         for k in string.punctuation:
#             j = j.replace(k, '')
#         for l in number:
#             j = j.replace(l, '')
#         print(j)
# noUname
# lttoken
    
#     for j in i:
#         j[1] = j[1].lower()
#         for k in string.punctuation:
#             j[1] = j[1].replace(k, '')
#         for l in number:
#             j[1] = j[1].replace(l, '')
#         print(j[1])
# Out:
# [['INDOSAT',
#   ' kenapa kartu diregistrasi nggak bisa pak padahal nomor kk ktp nya sudah benar sampai gagal'],
#  ['INDOSAT', 'indosat mantap djaja koneksinya '],
#  ['INDOSAT',
#   'membalas mau nangis deh rasanya pdahl saya percaya betul dengan indosat soal koneksi di wil karimun tp sudah hari koneksi kacau balau '],
#  ['INDOSAT', 'sinyal indosat asu ari musim hujan'],
#  ['TRI', 'membalas cek dm woi '],
#  ['XL',
#   'ini kenapa di bale endah sinyal xl tiba bagus yah pindah kali yah tower nya ke deket rumah aneh liat hp sendiri '],
#  ['TRI', 'hotsale gb hanya gratis nelfon aja ga ada gratis sms nya tah min '],
#  ['TRI', 'membalas dan lainnya hai kak andika'],
#  ['TSEL',
#   'membalas iya min udah bisa kok hihihi tengkyu yaaaa seneng banget pake telkomsel sinyal lancaaar '],
#  ['INDOSAT',
#   ' ribu saya beneran atau bohongan saya coba buat internet lngsung tanpa daftar paket internet dan alhamdulillah bisa buat internet trus saya buka halaman indosat baru kebuka saya dpt sms dari indosat kamu internetan dg tarif perkb'],
#  ['XL', 'sinyal kencang xl mantabbbzz '],
#  ['INDOSAT',
#   ' tolong kasih penjelasan yg bisa saya terima dong kenapa hari ini sinyal indosat sangat mengecewakan di daerah mampang depok '],
#  ['INDOSAT',
#   'yang lagi mau liburan di the jungle bogor indosat super wifi juga ada di sana looh'],
#  ['TRI',
#   'membalas saya juga cukup heran mengapa speednya bisa naik dirumah akan saya ss sisa paket saya'],
#  ['TRI', 'jikalau masalah sdm yg mengakibatkan keluhan saya tidak dibalas'],
#  ['TRI',
#   ' operator tolong yah sinyal nya jangan jelek terus tiap hari saya kecewa sekali dengan sekarang padahal sdh tahun pakai '],
#  ['TSEL', 'membalas mantap jiwa nih min harga paketnya '],
#  ['INDOSAT', 'terima kasih kepada sponsor yg sudah mendukung acara kita'],
#  ['XL',
#   ' sinyal dimana cuma padahal paket internet makin mahal makin bobrok aja xl kecewa saiah '],
#  ['XL',
#   'membalas woy anjing bukan dikota jakarya saja semua kota apa lo gak baca twett pengguna lain makasar aja uda seminggu sialan lo anjing kampret '],
#  ['TRI',
#   ' ____ rt aseek nickminaj kalo hujan dan malam tri pasti lemot bangsat '],
#  ['TRI', 'frontal cuk rt bangsat'],
#  ['TSEL', 'memang terbaik sakali iye teh telkomsel '],
#  ['XL', 'ya ampun'],
#  ['INDOSAT', 'indosat sinyale koyo ngelec asu '],
#  ['TRI', ' gimana nich'],
#  ['XL',
#   'haloo bagaimana nasib keluhan saya tiket c9 apakah masih di tanggapi atau di anggap angin lalu sejak januari masih belum selesaikah cc '],
#  ['XL', ' makassar lg seru banget nih guys sore ini'],
#  ['INDOSAT', 'kecewa berat saiah dengan '],
#  ['INDOSAT', ' min'],
#  ['XL', 'th pakai xl'],
#  ['INDOSAT', 'kebiasan pake indosat ngecek pulsa salah'],
#  ['XL',
#   'sudah bulan sejak januari keluhan saya no tiket c9 tidak ada respon dan solusi cc '],
#  ['TSEL', ' sinyal jelek bgt sih'],
#  ['TRI', ' maju tak gentar membela yang benar'],
#  ['TSEL',
#   'membalas min mau nanya ni knp sim card telkomsel saya tdk bisa buat panggilan keluar sedangkan kemarin bisa sudah dua minggu koit min sdh berhasil registrasi pula gimana saran dan tanggapan anda mewakili telkomsel '],
#  ['INDOSAT',
#   'setelah telkomsel ini indosat memakai jasa felix kwetiau org hti ormas terlarang utk isi acara ramadhan emangnya gak ada kah ulama yg lain mohon klarifikasinya utk apa benar flyer yg saya terima ini d '],
#  ['XL', ' coba cek ke zhir bukanorangdalemxl '],
#  ['TSEL', 'di tahun anjing tanah ini'],
#  ['INDOSAT',
#   'alhamdulillah kartu indosat pintar laris manisbisa free call menit sms ke semua indosat dan data '],
#  ['XL', 'sinyal xl kencang badai'],
#  ['TRI',
#   'membalas saya sedang mempertanyakan informasi kuota yg berbeda antara bima dan web saya pinta penjelasan '],
#  ['TRI',
#   ' sinyal tri di area cikarang delta mas dan jababeka hilang sinyal mulai jam tadi mohon perbaikannya terima kasih '],
#  ['TSEL', 'sekarang udah jamannya lte'],
#  ['INDOSAT', 'makasih keluhanku sudah di tangani dengan cepat'],
#  ['INDOSAT', 'sekarang pake indosat pasca bayar'],
#  ['XL',
#   'ogah rt beralihalah ke xlsinyal kencang dan lari pulsanya juga kencang rt indosat kampring '],
#  ['INDOSAT',
#   'di buat nangis sama jaringan indosat gara jaringan nya jelek nyangka nya mz dari dia ga di lz hampura sayank '],
#  ['XL', 'membalas nambahin wacana'],
#  ['TRI', 'membalas tolong perbaiki sinyal di aceh'],
#  ['TSEL',
#   ' ` keluarga telkomsel memang terbaik rt kayaknya aq jg akan kembali ke kartu as qu '],
#  ['TSEL',
#   'membalas saya mau nangis kejer rasanya mas kalau saya main mobile legend tuh tiba tiba jaringan terputus tanpa sebab tau gak telkomsel sering banget kayak gini padahal untuk streaming apapun itu lancar lancar aja mas saya udah turun credit score mobile legend gara koneksi terputus '],
#  ['TRI', 'kepada para pemenang kuis bangkitindonesia bisa dicek dm nya ya'],
#  ['TSEL', 'mantapsinyal stabil skrg dirumahthx telkomsel '],
#  ['XL', ' kualitas sinyalnya makin hari makin ancur tolong dong diperbaiki'],
#  ['TSEL',
#   'im ne iklan sampah kreatif dikit napa ikutan as telkomsel maluuuuuuu '],
#  ['TRI',
#   ' ready pisan rt sudah siap untuk kuis bangkitindonesia tes suara dulu ah ',
#   ') "'],
#  ['TSEL',
#   'membalas kalo kayak gini gimana coba aktifinnyaaaaa kasih tau dong caranyaaaaaa '],
#  ['TRI',
#   'nah ini rt cari tri store terdekat di kota kamu klik link ini untuk informasi lengkapnya yaa '],
#  ['XL', ' pake antena pf goceng brad'],
#  ['TSEL', 'membalas klo bisa nangis'],
#  ['TSEL',
#   'gw yakin ga bisa baca komen ini lemot telkomselproradikalis telkomselproradikalis telkomselproradikalis telkomselproradikalis telkomselproradikalis telkomselproradikalis telkomselproradikalis telkomselproradikalisjoe menambahkan'],
#  ['TSEL', 'monyeet koneksi sampah'],
#  ['TRI',
#   'irsoekarno hatta rt kuis bangkitindonesia tebak tokoh yang ada di gambar ini '],
#  ['TSEL', 'membalas anyway'],
#  ['INDOSAT', 'pengalaman gue sangat mantap pakek indosat '],
#  ['TSEL', ' min saya mau nanya'],
#  ['INDOSAT',
#   'kumpul mahadelta dapet rejeki dari indosat lumayan gb free lancar abis terima kasih indosat '],
#  ['TRI', 'membalas baik'],
#  ['XL',
#   'joss makany klo beli no sklian bli sinyal ahhaha rt plis xl jgn balak donk knp skr signal nya ababil sih '],
#  ['TSEL',
#   ' anjing lukalau gk suka mobile legend jangan dilenotin dong sinyalnya asu aov itu asu kyk telkomsel '],
#  ['XL',
#   ' udah senin nih upload foto pas weekend kmrn ayo pakai xl internet super cepat stabil lovepalembang hotrod '],
#  ['TRI',
#   'lagu favoritku kecewa karna org itu sukanya bikin hati org kecewa baper bgt lagunya konserrossa '],
#  ['TRI', 'merah sinyalnya'],
#  ['INDOSAT',
#   'nih provider harus banyak belajar sama keluhan cepat di tanggapi '],
#  ['INDOSAT',
#   'apakah ini kemajuan apa indosat makin maju dari kemarin kemarin internetnya cepet terusssss selamat '],
#  ['TSEL', 'cs nya lelet dan lemot'],
#  ['XL',
#   'sumpah xl sampah banget sinyalnya benerin dong jaringannya jangan cuma berani ngasih promo murah '],
#  ['XL', 'indosat sinyal nya palang merah okeee xl lumayan lah ada dikit '],
#  ['TRI', ' min '],
#  ['INDOSAT', 'membalas terima kasih indosat '],
#  ['XL',
#   'membalas memang gitu sinyal xl terkadang kencang tiba lambatsama ditempat jga gitutapi jgn ganti kartu semuanya sama '],
#  ['TRI',
#   ' 99 jlphh musofa jln suci dpn sma yas knpa ya skarang sinyal tri edge terus ga pernah di area rumah saya '],
#  ['XL',
#   'sama tolong kenapa ini xl di rumah yang biasanya streaming ga buffer ini buka twitter aja gabisa hadeh kile menambahkan'],
#  ['INDOSAT',
#   'membalas anjing indosat goblok fakk maen moba aja leg nya minta di tampil kontol '],
#  ['INDOSAT',
#   'asu jaringane kek tai percuma pket banyak tp nge lag gbsa ngapain sumpah payah jancuk '],
#  ['INDOSAT',
#   'membalas dan lainnya iya nih kontol indosat pulsa gua dipotong anjing babi'],
#  ['TSEL', 'satelit telkomsel meledak pa gimana hng sehunxlv lvcruise '],
#  ['INDOSAT',
#   'pertama kalinya xl dibawa ke luar rumah signal internetnya bagus bye bye indosat cukup lah ya bertahan tahun '],
#  ['INDOSAT',
#   'membalas semua program infrastruktur warisan dari pemerintahaan sebelumnya kita tunggu yg murni dari jokowi seperti listrik megawatt'],
#  ['TSEL', 'susah sama smpai skrg cuma di tanya'],
#  ['TSEL', 'kecewa sama pelayanan telkomsel'],
#  ['XL', 'membalas makin lama makin jelek'],
#  ['INDOSAT', 'membalas waktu itu kartu udah hangus karena lupa isi pulsa'],
#  ['TRI', ' harusnya lihat kualitasnya dulu baru naikkin harga'],
#  ['INDOSAT', ' halo indosat'],
#  ['XL',
#   'membalas ini xl knapa sih gangguan mulu signal ada tapi no internet connection sampah '],
#  ['TRI', 'oke thanks infonya rt informasi paket sms bisa km cek di '],
#  ['XL',
#   'membalas saya tidak pilih semuanya karena saat ini jaringan internet xl mbyarpet alis mati hidup plus lelet sangatsangatsangat mengecewakan kecewa karena sudah terjadi sejak sabtu kemarin'],
#  ['XL',
#   'sudah hampir seminggu lebih sinyal daerah ku sangat lambat sekali apakah xl sedang ada ganguguan '],
#  ['INDOSAT', 'membalas saya akui indosat cukup bagus'],
#  ['XL',
#   'promosi awak iya rt pake xl la hahha punyaku kencang rt udah midnite gini pun sinyal tetep aja kacau '],
#  ['XL',
#   'dibayar berapa nis buat ngeboong ekekekke rt makannya pakai xl sinyal kencang saat anda berada dimana saja yrt '],
#  ['XL',
#   'membalas iki nang munggur kok mung oleh sinyal mentok bar paketan mahal sinyal busuk'],
#  ['TSEL', 'emang juga telkomsel cacat '],
#  ['TRI',
#   ' kasih pete bapaknya nih mimin ulang kuis bangkitindonesia gimana caranya deketin anak presiden biar direstui '],
#  ['XL',
#   'membalas kno dit selama masih indonesia jgn harap lebih sama dunia selular'],
#  ['XL', 'sinyal xl di bintaro kurang bagus yaa'],
#  ['TSEL', ' ini jaringan kenapa dan ilang cacat banget koneksi '],
#  ['INDOSAT', 'membalas dm gue gimana riza taek '],
#  ['INDOSAT', 'paketan internet indosat bikin nangis borosss yawooh '],
#  ['XL', ' min'],
#  ['TRI', ' admin jancok'],
#  ['TRI', 'sinyalnya gawat min'],
#  ['TSEL', 'tekad sudah bulat'],
#  ['XL',
#   ' apakah ada cara situs no yg bisa diakses untuk mengetes jaringan xl bermaksud membeli mifi'],
#  ['TSEL', 'gak boleh nyebut merk titik rt internetnya telkomsel lemottitik '],
#  ['INDOSAT',
#   'membalas sudah saya dm cek segera itu no hp saya tolong matikan layanan prime joy yang saya tidak daftar itu saya tidak terima pulsa saya terpotong tiap bulan hanya demi benefit prime dari indosat yang sama sekali tidak berguna dan tak akan saya gunakan thanks '],
#  ['TRI',
#   'membalas gambar aku pake baju perang dengan background kobaran api sambil bawa bendera hehe bangkitindonesia '],
#  ['TSEL', 'saya kecewa sama telkomsel ketok palu '],
#  ['XL',
#   'cuaca cerah telah berganti di siang ini angin mulai kencang tanda apa ya sinyal xl tetep lantjar jaya '],
#  ['XL',
#   'saya sangat kecewa jaringan internet di daerah saya lemotbuka fb sama vidio fb lemotbuat maen game stabil '],
#  ['XL', 'membalas yaaa makanyaaa aku sedih'],
#  ['INDOSAT', ' selamat malam'],
#  ['XL', 'dulu rekomen soalnya internetnya cepet dan lancar'],
#  ['TRI', 'membalas bisa dibantu link url informasi tersebut '],
#  ['INDOSAT',
#   'gmn dong gue mau nangis besok tuh gue mau bukber masa gue bukber dengan gaada kuota anjing bangsat lo indosat tolol '],
#  ['TRI', ' tlg kalo kasih info itu yg jujur biar konsumen ga marah ga kesel'],
#  ['INDOSAT',
#   'kecewa dg kualitas indosat kuota masih gban kuota ludes gak jelas '],
#  ['TSEL',
#   'haha tapi da lelet pake telkomsel engga ah udh enak pake yang ini murah aaaa '],
#  ['INDOSAT',
#   'yah hehe pake xl lumayan bagus lho say rt tapi bb aku indosat gabisa ganti ke xlhhe rt '],
#  ['TRI',
#   'gimana cara ngilangin ini selamanya saya beli kartu baru dan langsung berhasil registrasi tapi notifikasi ini nongol terus ganggu banget '],
#  ['TRI',
#   'membalas ga ada kendala katanya bener tai ni cs sinyal saya hilangan jg dibilang ga ada kendala dan cs bales komplain waktu sinyalnya membaik ga punya otak ni cs '],
#  ['XL', 'dear '],
#  ['TRI',
#   'selamat pagi mohon informasi untuk upgrade kartu menjadi lokasi bekasi gerai tri ada dimana ya '],
#  ['TRI', ' min hp adik saya hilang'],
#  ['INDOSAT',
#   ' tolong cek no knp ga ada balasan dr indosat ya terima kasih segera ditindak lanjuti '],
#  ['TRI', 'dm ga direspon'],
#  ['TSEL', ' lurd cek poin gimana yah '],
#  ['TRI', 'marah dengan '],
#  ['TSEL',
#   ' baru kali ini saya kecewa sekali dengan pelayanan caroline officer agent name tari saya menanyakan ttg proses running paket data saya kenapa tdk berjalan seperti biasanya '],
#  ['XL', ' jancuk'],
#  ['TSEL',
#   'nabungbuatapa buat biaya mengumpulin orang untuk membersihkan sampah di pantai'],
#  ['TSEL', 'delapan tahun make telkomsel baru kali ini tukar poin'],
#  ['INDOSAT',
#   ' kenapa ya jaringan indosat belakangan ini suka hilang sinyal lama kelamaan bisa kecewa saya dan lagi'],
#  ['TRI',
#   'membalas paling kesel kalo udah lelet dan bilang tidak ada masalah hahahaha tai memang '],
#  ['TSEL', 'sinyal di tmpt saya sering mati udah minggu ini'],
#  ['XL', 'membalas untung gw ga pernah pakai selain mahal'],
#  ['TSEL', 'membalas telkom 9999 dari telkomsel mantap jiwa '],
#  ['INDOSAT',
#   'membalas indosat juga lagi bermasalah alhamdulillah ternyata provider mahal juga bermasalah '],
#  ['INDOSAT', 'jaringan indosat lumayan bagus '],
#  ['TSEL', 'telkomsel memang terbaik '],
#  ['TRI', ' min saya mau kasih saran nih'],
#  ['TRI', ' sinyal tri ngebut rt wifi mencret'],
#  ['INDOSAT',
#   ' maksud nya apa ya ini karena sistem indosat yang trouble ataukah kesengajaan tolong dikembalikan pulsa saya terima ka '],
#  ['XL',
#   'membalas nich provider bangsat isuny cm maling dan penipu konsumen provider zaman now maling bermodus provider xl bangsat '],
#  ['TSEL', ' memang macam anjing sinyalnya'],
#  ['TRI',
#   'smart juga set jam download mb lewat bb rt sinyal tri pagi emang mantap jaya '],
#  ['TRI',
#   'promo sampe kpn nih blackberry berisi voucher blackberry full service mingguan bonus voucher yang sama '],
#  ['TRI', 'membalas mungkin udh naik'],
#  ['TRI',
#   'gratis kok sms gratis tu pulsa rt pake tri sms sekali gratis terus donk seharian'],
#  ['TRI', ' laek'],
#  ['XL',
#   'kenapa ya nomor prabayar itu ga bisa diaktifkan lagi seperti nomor atau padahal baru lewat hari dari masa tenggangdipaksa pindah ke pascabayarsistem yang jadul atau karena merasa provider paling besar '],
#  ['INDOSAT',
#   'terluka yang baru dipecat maupinjemuang eagkbisa mau ngutang enggak dikasih boikotindosat atau nangis ilcmembidikhabibrizieq '],
#  ['INDOSAT', 'rt lurd urgent'],
#  ['INDOSAT', 'ucweb indosat mantap bisa new tab norak'],
#  ['INDOSAT', 'hallo indosat yang baik hati'],
#  ['TSEL', 'telkomsel absen pesta rbt'],
#  ['TRI', ' min'],
#  ['TSEL',
#   ' membalas telkomsel murah jg jok rt gedor be rt belum dtng dy rt duku jg enak rt lewat jendelo '],
#  ['TSEL',
#   ' jancok banget ni kartu saya udah maketin paket flash eh tapi pulsa tetep kepotong '],
#  ['INDOSAT',
#   'dunia harus tau kalo skrng di rumahku udah ada sinyal indosat alhamdulillah packet yellowku wkwk '],
#  ['INDOSAT', ' tolong informasinya segera saya belum pernah ikut paypro'],
#  ['XL', ' sini kok sinyal xl kencang aneh '],
#  ['INDOSAT',
#   'sipooo rt oke makasih glo rt theodoregloria lumayan rt eh yang indosat sinyalnya bagus gak '],
#  ['TRI', 'better upload service'],
#  ['TRI', 'buat kaum jomblo'],
#  ['INDOSAT',
#   'indosat jan bulsit di paketke kok sik kenggo pulsa pokok paketane wutuh asu asu '],
#  ['TSEL',
#   'membalas yeee terbukaaa terima kasih engkau memang pelayanan terbaik '],
#  ['INDOSAT',
#   'asu tnan seng jupuk hp qw ch lek pnteng mzo nek kne 9 sng qw indosat ilang '],
#  ['TSEL', 'iya'],
#  ['XL',
#   'pakai xl dijamin cepat dan sinyal kuat haya iklan hahaha rt bbm masih aja pendingzzzzzzz '],
#  ['INDOSAT', ' indosat jancok kaya gini masih gak cukup pulsanya jancok '],
#  ['TRI', 'membalas tolong beri informasi yg jelas tentang gangguan nya'],
#  ['INDOSAT', 'membalas kemrin waktu ke pantai parangtritis jogja'],
#  ['TSEL', 'membalas saya mau regis tapi nik tidak ditemukan gimana tuh min '],
#  ['TRI', 'tolong ya perhatikan dengan baik no hp yang bermasalah adalah 999 '],
#  ['INDOSAT', 'membalas hai kak'],
#  ['TSEL', 'membalas terimakasih kami sangat puas '],
#  ['INDOSAT',
#   'indosat lg ada masalah ya min nomor saya tidak bisa terima sms masuk dan harus di copot simcardnya dulu baru smsnya masuk tolong di cek '],
#  ['XL',
#   'udah hari masih juga gangguan ini xl ga mendengarkan keluhan pelanggannya ya kayanya udh banyak yg ngadu tpi kok ga lebih baik udah berkali kali reset signal '],
#  ['TSEL',
#   'hash rt pake xl dongga pernah bs belaajar rt telkomsel jancok hari ini gsm mulu '],
#  ['INDOSAT',
#   'membalas bnr ngak diperhatiin kualitas isat bb sibuk promo trus tp kualitas sinyal ancurrr kecewa bneran dh pelayanan indosat '],
#  ['XL', 'provider bangsat xl isiny cm maling '],
#  ['TRI', ' ini kenapa koneksi nya tai banget dari siang '],
#  ['TRI',
#   'membalas masih gaada tindak lanjut udah hari jaringan hilang percuma kuota dikasih harga murah kalo pelayanan terutama kepada keluhan konsumen masih kek tai'],
#  ['TRI', ' baji gau melulu '],
#  ['TRI', ' hai'],
#  ['TSEL',
#   'mudah mudahan bisa lebih baik dlm pelayanan pelanggan krn terus terang urusan sinyal dan coverage saya sangat puas dg telkomsel '],
#  ['INDOSAT',
#   'lumayan bagus wan rt rekomendasi dong jaringan indosat khususnya im bagus ga sih '],
#  ['INDOSAT', ' halo indosat ada pengaturan yang cocok gk buat hp advan ic'],
#  ['TSEL',
#   'pakai telkomsel itu enak yaa gak pernah pending kalau bbman terus kalau telfonan sama smsan murah banget '],
#  ['TSEL', 'ak wes onok telkomsel tp halo ran rt ganti simpati wes rt jancok '],
#  ['XL',
#   ' nyalahin customer belum regist padahal udah regis kok sampah ya anda problemnya ada di anda bagian it anda yang tidak becus '],
#  ['TRI', ' jaringan cacat'],
#  ['XL', ' jaringan nya cacat payah lah '],
#  ['XL', 'thanks xl download apapun sangat cepat '],
#  ['INDOSAT',
#   ' untuk yg kesekian kalinya pulsa saya hilang tiba tiba pulsa tinggal mantap indosat diem diem mencuri '],
#  ['TRI', 'dear sampai sekarang belum ada jawaban dr keluhan saya'],
#  ['XL', 'tumben sinyal xl bagus '],
#  ['TSEL',
#   'mau sampai kapan gangguan sinyal begini semingguan tidak bisa dipakai buat main mobile legends saya kecewa beneran '],
#  ['XL',
#   'ni laptop koneksinya malah dari tethering wifi hape cino pake xl lumayan ngebut juga'],
#  ['XL',
#   'fix ganti kartu sudah capek dengan xl keluhan gak ditanggapi sekali ditanggapi jawabannya ngelantur cc '],
#  ['XL', 'mau tahu tips agar cod kamu lancar jawabannya'],
#  ['TSEL',
#   ' penekanan pertama ad di kata murah rt indosat dganti opo enak telkomsel '],
#  ['XL', ' sampah banget koneksi internet xl ini bah sampah '],
#  ['INDOSAT', 'tanggapan dari cs indosat cukup bagus lah menurut saya '],
#  ['TSEL',
#   'membalas owh itu aj ya oh ya makasih ya paket tau nya udh ak pake itu dan ak merasa sangat puas semga pket tau di adakn lg '],
#  ['INDOSAT',
#   ' tolong baca dm saya saya urgent perlu bantuan nomor indosat saya sdh tdk aktif berhari hari terima kasih '],
#  ['XL', ' sampahudh hari sinyal leleeeeeet '],
#  ['TRI',
#   ' gak bakalan kolaborasi sama nih soalnya sinyal kalian sama sama bapuk dan selalu tidak respon keluhan konsumen '],
#  ['INDOSAT', ' jadi'],
#  ['INDOSAT', 'mantap pake indosat nih'],
#  ['TSEL',
#   ' tp katae plng enak telkomsel rt podo ae se jatuhe kabehrt lek paketan iku murah endi '],
#  ['TSEL', 'membalas baik'],
#  ['TRI',
#   ' apa sih benefit yg kita terima sbg pelanggan postpaid krn hampir thn ga dpt bonus apa '],
#  ['INDOSAT',
#   'membalas mungkin sekitar tahun aku pake provider indosat sejauh ini cukup puas'],
#  ['TRI', ' knapa sinyal gnya main yah informasi detail mengenai aon cek ke '],
#  ['TSEL', 'em btw ini konek pake ya'],
#  ['TRI',
#   ' woy bangsat anjing ngentot babi kontol memek lu lelet tai anjing mahal sering di lletin lagi ahh ngentot awas lu ya '],
#  ['XL', 'membalas hai krisnantyo'],
#  ['TRI', 'kukud ja banyak keluhan tp gak di tanggapi'],
#  ['XL',
#   'slamat datang di manokwari sinyal xl lumayan bangetlah rasa kok hehe ga lost sinyal kyk sebelah yuk eksplor papua barat '],
#  ['TRI', ' batang jak agik pelosok sinyal tri mantap batang jak '],
#  ['TSEL',
#   'sms blast telkomsel sampah banget isinya udah bayar pulsa tetep aja di blast unethical '],
#  ['TRI', 'keluhan gua berharu hari gak di tanggapin'],
#  ['TSEL', ' jaringan bb telkomsel napa ilang mulu lemot cuy '],
#  ['TSEL',
#   'kaksinyal di daerah saya kok sekarang jelek sejak ada sinyal ghp ahrus di lock agar dapt sinyal gkalo gak di lock cuma dpt sinyal dan itu lemotbantuannya kak '],
#  ['TRI',
#   'membalas nomor lama juga dong udah pake tri tahun pas registrasi ulang gak dapet hadiah apapun '],
#  ['TRI', ' siang'],
#  ['XL', ' karena pasca bayar xl sudah lambat'],
#  ['TRI',
#   ' goblog jaringan lu udah sebulan lebih ngga bener jgn cm ngiklan doangpikirin konsumen '],
#  ['XL',
#   ' tolong sekali lagi saya minta tanggung jawabnya yaa saya tertarik beli'],
#  ['TSEL',
#   'pada heboh paket bis namun telkomsel tetap juaranyamurah koq njaluk enak '],
#  ['INDOSAT',
#   ' ya beli aja perdananya murah iniaxis lumayan bagus kokasal jangan kedap udara ajaheheperminggu rb'],
#  ['TSEL',
#   'lagi lagi tcash telkomsel mesin edc nya error kedua kali nya di centre point medan ckckck kecewa bngt '],
#  ['TSEL', ' mohon bantuan puk untuk nomor terimakasih '],
#  ['INDOSAT',
#   ' satu kata telkomsel browsing cepet rt indosat sialaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaannnnn '],
#  ['TRI',
#   'membalas kemarin lusa sy beli paket gb gb gb rb setelah habis lalu sy beli yg gb'],
#  ['TRI', 'membalas di selamatin doang'],
#  ['XL',
#   'dear kenapa jaringanya selalu gangguan jadi ga berguna baru beli kartu perdana yang gb tapi gakepake sama sekali gara jaringanya lemot jelekkk parahh banget asli'],
#  ['TSEL',
#   'sebagai konsumen saya sangat kecewa dengan iklan ini kemana saya harus mengadu '],
#  ['XL',
#   'semoga xl xlalu menghadirkan pelayanan terbaik dan super cepat utk pelanggan setianya jaringanxtrasuka '],
#  ['TRI', 'semangat dong'],
#  ['TSEL', 'dear kenapa kalo saya nonton film dari viu'],
#  ['INDOSAT', ' malam nomor saya sudah tidak aktif sejak '],
#  ['TSEL',
#   'seneng banget arsenal jadi ke indonesia ` ada promo khusus pelanggan telkomsel lagi ` jingkrakjingkrak '],
#  ['TSEL', 'sinyal bagus ko tapi lemot yah '],
#  ['XL', 'buat yang senang pelajaran fisika atau kimia'],
#  ['XL',
#   'xl sama axis itu beda jauh axis cm rb full service sinyal bagus sedangkan xl 9rb full service tpi sama aja kyk ga pake paket full servc '],
#  ['TRI',
#   'rt terima kasih semua yg sudah kasih info ttg provider tri kesimpulannya'],
#  ['TRI', 'membalas saya langganan paket tri gb sebulan cuma ribu '],
#  ['XL',
#   'membalas banyak gangguannya dah gitu slow respon lagi hadeeeh nyesel dah ini beli perdana malah mahal lagi '],
#  ['XL',
#   'bikin boros batere bro rt disini hspa mas hihi rt sinyal hsdpa xl joss gandos men '],
#  ['TRI', ' tri gaada sinyal mantap yah '],
#  ['INDOSAT', 'membalas itu smartfreen'],
#  ['INDOSAT', 'sore min'],
#  ['TSEL', ' rekan mohon bantuan respon dm tks '],
#  ['INDOSAT', 'sampah indosat minyat we ah aja ke '],
#  ['INDOSAT',
#   ' butuh trik perpanjang masa aktif indosat moso tp ewuminim masa aktif 9 hari nangis nangis '],
#  ['XL',
#   'musti banyak sabar ngadepin xl ini yaa udah banyak keluhan dari pelanggan klen tolong bagusinlaah bodaat '],
#  ['TRI', ' mas sinyal nya kyk tai kucing mas '],
#  ['TRI', ' bangsat nih'],
#  ['INDOSAT', 'streaming putus ni wooeee'],
#  ['XL', 'ceritanya tadi mau nanya kenapa minggu ini xl ilang di hp'],
#  ['INDOSAT', 'membalas dah pasrahin aja'],
#  ['XL',
#   'sinyal xl dirumah gue bagus deh sampe pengen demo saking sinyalnya bagus '],
#  ['INDOSAT',
#   ' membalas rp gb how dare are you btw koq tau aku pake paket rakyat jelantah hahaha hati hati paket yellow habis kuota atau habis waktu pulsa reguler akan dihajar habis dalam satu kerdipan mata papa memang jahat jawab indosat murah mau selamat '],
#  ['TRI', 'beberapa orang ngetwit galau biar dapat simpati'],
#  ['TRI', 'haha sinyal kuat ege rt pea _ rt kartu kredit'],
#  ['TRI',
#   ' ehh bangsat perasaan gw beli paket kuota yg reguler internet knp gw kudu jadi pindahin mode en sebaliknya terus kek '],
#  ['XL',
#   'lancar menterjemahkan semua jurnal berbahasa inggris dengan cepat tinggal jurnal lagi thanks xl'],
#  ['XL', 'membalas maaf'],
#  ['TRI',
#   ' knp signal tri di cikarang utara bikin marahlemottttt bgt signal sering '],
#  ['INDOSAT', ' indosat sinyalnya bikin pengen nangis '],
#  ['XL',
#   'game keren yang bisa kamu dapetin dengan gratis adalah batman arkham origins pengguna android pasti senang banget nih xlgames '],
#  ['XL', ' dimana saya bisa menyampaikan keluhan terkait xl'],
#  ['XL', 'halo mengap sinyal xl di tempat saya jadi lemot tiba'],
#  ['TSEL',
#   ' sangat puas dengan layanan call center telkomsel we love telkomsel '],
#  ['TRI',
#   'kok semenjak aku ganti im kamu gak pernah sms aku lagi kamu marah ya '],
#  ['INDOSAT',
#   'membalas duh mahal ya indosat donk murah gb rb hr jam paket yellow '],
#  ['TRI', ' koneksi parah gk ada perkembangan percuma lapor kayak tai '],
#  ['XL', ' kuat dan kencang rt kuat po kencang kan pake xl'],
#  ['TSEL',
#   ' telkomsel xl tahik banget cepet abis mana mahal lagi pingin ganti yang murah sama enak buat paketan android ada saran '],
#  ['TRI', ' ka kartu sim saya ke blokir karna abis masa tenggang'],
#  ['INDOSAT', 'astagfirulloh nangis gua indosat dirumah gua gini amat sih '],
#  ['TSEL', ' mosok hahahad rt telkomsel jancok'],
#  ['TRI', 'membalas tolong secepatnya keluhan pelanggan tri di tanggapi '],
#  ['XL', 'ini xl lagi kenapa si gak jelas bgt koneksinya dari tadi sampah '],
#  ['INDOSAT',
#   'mantap 9 tahun indosat ooredoo imsemaranginner indosatooredoo9smg '],
#  ['INDOSAT',
#   ' ping kegedean asu ngeleg mulu lemot mulu kapan majunya indosat malah semakin blangsak aja tolo dasar '],
#  ['TSEL',
#   'murah tau sama aja na rt muaaaahal rt ganti telkomsel aje rt enak si sms sama telfonnya gratis tp '],
#  ['TSEL',
#   ' kenapa cacat banget sih tiap jam malem selalu ubah jaringan udah paketan mahal'],
#  ['XL', 'kecewa pake xl '],
#  ['XL',
#   ' saya kecewa dan kesal dengan jaringan xl yg trouble dalam minggu ini terutama wilayah sumbar saya kesal karena tidak ada pemberitahuan trouble dan lanjutan kekesalab saya ketika lgi asik gaming eh jaringan ilang ujung saya dianggap afk '],
#  ['INDOSAT',
#   'hallo kenapa indosat klo sms statusnya tertunda semua gak bisa terima sms juga tolong bantuannya '],
#  ['TRI',
#   ' gara lu quiz kuliah gw jadi skip jing bangsat kalah esia nge lagnya tolol anjing bangkrut lo jing '],
#  ['INDOSAT', 'dear kok sinyal indosat gue suka ilangan gini'],
#  ['INDOSAT',
#   'membalas to the point saja pak inilah sebagian rakyat indonesia itu cepat lupa'],
#  ['XL',
#   'males kali baca email yg signature nya kek gini sent from my blackberry smartphone from sinyal bagus xl'],
#  ['XL',
#   'membalas trnyata klo vip sinyal xl yg jossklo timur telkomsel yg buosok '],
#  ['INDOSAT', ' jangkauan di bogor masih terbatas'],
#  ['TSEL',
#   'membalas terima kasih sudah menunggu mohon kamu coba kembali sekarang jika masih terkendala tolong kirimkan screenshoot sms nya ke kami nanti kami akan mengecek lebih lanjut '],
#  ['TRI', 'terima kasih atas bonus mb nya '],
#  ['TRI',
#   ' kalo mau jadi csc gimana pengen ngelayanin pengguna tri dengan jadi csc kalo ada infonya'],
#  ['XL',
#   'mau ngerasain internetan cepat dan stabil tapi belum pake xl dateng ke xl center jabo hari ini xlappreciationday '],
#  ['XL', 'membalas tai xl anjing'],
#  ['INDOSAT', 'ktika sy smp kls dulu'],
#  ['INDOSAT',
#   'membalas tergantung lokasi gan kalo sinyal indosat disana bagus kecepatan lumayan '],
#  ['TSEL',
#   'enak axis iki lo murah banter hahahahaah rt oyowahhenak ta nganggo telkomselm iki yo bedes '],
#  ['INDOSAT', 'selamat beristirahat '],
#  ['XL',
#   'membalas provider anjing xl isiny cm maling dan penipu konsumen tai xl kampret '],
#  ['XL',
#   ' adaw rt iya ya seperti hati ku kepada mu asik asik joss rt sinyal xl lg timbul tenggelam '],
#  ['INDOSAT', ' internet indosat sampah normal mbps'],
#  ['XL',
#   'menikmati santai dengan vietnam drip dan sinyal kencang dari xl setelah seharian mengembara '],
#  ['INDOSAT', 'edge nya indosat lumayan bagus di rumah '],
#  ['XL', ' signal speed lebih lambat dari gsm '],
#  ['TRI',
#   'membalas saya coba registrasi kok tdk bisa ya pdhl memasukan no nik sdh benar mohon dibantu secepatnya '],
#  ['XL', 'membalas provider anjing ini '],
#  ['INDOSAT',
#   ' saya dpt sms dari indosat mengenai perubahan paket yellow ttg perubahan harga dan benefit pulsa safe saya klik link info tidak bisa mohon diinfokan lbh detil terima kasih '],
#  ['INDOSAT', 'tidak sia pakai kartu indosatalhamdulillah '],
#  ['INDOSAT', 'sumpah indosat dino iki jancok tenan '],
#  ['TSEL',
#   'sejauh ini masih sangat sangat puas dengan belum ada masalah dan lemot sama sekali'],
#  ['INDOSAT', 'indosat dh lumayan bagus jaringan internetnya'],
#  ['XL', 'membalas woi bangsat'],
#  ['TRI',
#   ' klo mau cari informasi tentang chip sakti seperti program dan berita terbaru nya dimana '],
#  ['XL', 'sinyal bangsat '],
#  ['TSEL',
#   ' sy sangat kecewa provider plat merah ikut mendukung pro reklamasi telkomselmusuhbali '],
#  ['TSEL',
#   ' mohon bantuan kode puk kode care no hp 9 angka di belakang kartu 9 '],
#  ['XL',
#   'waktunya bersenang senang bareng teman atau keluarga di the lodge maribaya '],
#  ['XL',
#   'membalas kalau ada kualitas bukan kuota banyak tapi muter terus tidak konek kecewa '],
#  ['XL', 'membalas jujur saya kecewa dengan kualitas jaringan xl saat ini '],
#  ['XL', 'membalas bangsat xl tai kotok '],
#  ['INDOSAT', 'cie kenal sama security nya indosat nih'],
#  ['TRI',
#   'membalas saya melakukan pengecekan mengunakan bima tp tidak ada informasi pengunaan kuota '],
#  ['XL', ' hai xl'],
#  ['INDOSAT',
#   ' cek nomor saya 9 ga bisa paket yg gb hr ada pulsa tapi ga bisa daftar katanya ga cukup pulsa saya mau cek ping indosat lagi apa sudah bagus atau belum '],
#  ['XL',
#   ' saya baru beli paket promo joss gb rb tapi sinyal di kartu xl saya tidak ada'],
#  ['TSEL',
#   'membalas gak enak murah iku rt mkane gae tok rt telkomsel gangguan'],
#  ['XL', ' anjing lah jaringan nya jancookkk'],
#  ['XL', 'membalas belum ada mba'],
#  ['XL', 'please'],
#  ['XL', 'kok kesannya cuma buat sementara doang ya'],
#  ['XL',
#   ' mau tanyabisa gak ya kalau nmr saya hangus karena lupa tidak dibelikan pulsa kemudian ingin saya aktifkan lgsayang bgt nmrnya bagusmohon petunjuk min trims '],
#  ['TRI', 'membalas hai mas gatot'],
#  ['XL', ' bagus di iklan doank '],
#  ['XL',
#   ' skrg xl lebih cenderung menjual kartu perdana dg paket data murah sdgkan pembelian paket di sangat mahal shg kmu hars bongkar hp utk mendapatkan pket murah knp xl tidak jual paket tnp hrs gnt kartu dg harga yg sama mhn konfrms'],
#  ['INDOSAT',
#   'knp koneksi indosat di depok itu jelek cepat saat tengah malam aja terakhir pakai indosat thn lalu memang lelet kebetulan coba lg krn direkomendasikan teman ada paket murah please dong mas mbaknya saya mau tanya'],
#  ['INDOSAT',
#   'nyoba daftar paket indosat yellow yg katanya murah meriah pulsa dapet gb buat seharian'],
#  ['INDOSAT',
#   ' sy pernah pake indosat lambat waktu itu temen pake telkomsel disini bagus tapi kata tetangga juga lumayan '],
#  ['INDOSAT',
#   'biasa coba nangis pas lagi jual indosat baru luar biasa tigabintang menambahkan'],
#  ['TRI', 'malam min'],
#  ['XL',
#   'membalas lokasi di seluruh jogja semua pengguna xl mengalami keluhan yg sama jaringan sangat lemot '],
#  ['TSEL',
#   ' cara update lokasi buat internet lokal gimana kak bisa diupdate lebih dr satu kali ga lokasinya '],
#  ['TRI',
#   'membalas registrasi saya selalu gagal ini tolong di bantu dong min '],
#  ['TSEL',
#   'ketinggalan kereta kali ini disponsori oleh telkomsel yang tiba ilang signal jd gal bisa pesen gojek antara ingin muntah dan nangis gusti paringono sabaaaar '],
#  ['TSEL',
#   'saya sangat kecewa sekali dengan pelayanan cs hanya bisa memjawab dgn jawaban tidak tahu '],
#  ['XL', 'ohhh tentu bukan rt pasti xl rt itsmefunnie sinyal kencang'],
#  ['TRI', ' woy yg serius dikit dong nanganin komplain'],
#  ['INDOSAT', 'hujan indomie goreng sambel matah signal indosat mantap '],
#  ['XL', ' padahal nya xl'],
#  ['INDOSAT', 'udah tahun'],
#  ['TRI', ' mau registrasi kok balasan smsnya system is busy gitu terus '],
#  ['TRI', ' pulsa gw kesedot ni '],
#  ['INDOSAT', 'lagi main twitter di laptop atau komputer ada sms'],
#  ['XL',
#   'mau marah sambil nangis sama sinyal di rumah per minggu kemarin tiba tiba drop parah'],
#  ['INDOSAT', ' hai'],
#  ['TSEL', 'gunakankan persamaan rasa'],
#  ['TRI', 'membalas min saya sudah registrasi tapi ko dapet bonus kuota ya '],
#  ['TSEL', 'guys saranku beli pake app my telkomsel aja'],
#  ['XL', 'membalas dan lainnya gak di respon sama skali twit ku nok'],
#  ['XL', 'walaupun mendung di sini tetep seger para pesertanya'],
#  ['XL',
#   'berlibur nggak cuma untuk senang senang menikmati pemadangannya aja guys'],
#  ['TSEL',
#   'membalas ayolah admin jangan membuat event gak karuan mending bikin towar diplosok dan fix biar stabil biar mantap '],
#  ['TSEL', ' hush jangan ngeflame saya pengguna telkomsel'],
#  ['INDOSAT',
#   'membalas mohon ditingkatkan lagi kualitas layanan agar tidak terjadi masalah seperti pulsa yang tersedot secara massal saya menggunakan indosat hampir tahun'],
#  ['TSEL', 'saya gak bisa daftar cash wallet mohon bantuan nya '],
#  ['TSEL', 'membalas bikin nangis emang harga paketannya '],
#  ['TSEL',
#   ' lokasi di kota jayapura sinyalnya lemot banget padahal kekuatan sinyal full via '],
#  ['XL', 'membalas sore mba ghina'],
#  ['TSEL', ' oke tampaknya memang pake telkomsel adalah pilihan terbaik __ '],
#  ['XL', 'kuota mahal'],
#  ['INDOSAT',
#   'membalas saya heran dengan indosat kok bisa bsanya ada sms konten padahal kita gak ikut sms konten '],
#  ['TSEL',
#   'membalas saya sudah hampir tahun pake telkomsel aman aman aja walaupun suka down tp diatasinya cepat haha mantap tsel '],
#  ['TRI',
#   'kuota vs unlimited menang axis lah orang axis sinyalnya stay di klo gnya super cacat kayak anjing '],
#  ['XL', 'nyesel isi ulang paketan bangsat masih lag jam segini babi '],
#  ['TRI',
#   'membalas min tlg perbaikan dong jaringannya internet nya jgn kek tai apah menjijikkan bgt koneksi internet nya fakkkkk lah '],
#  ['TSEL', 'email menumpuk'],
#  ['TRI',
#   'wah keren respon keluhan dan kasih solusi dalam waktu yang cukup cepat trima kasih '],
#  ['XL',
#   'beli kuota rb belum sehari udah jadi sampah haha ga bisa dipake sama sekali mantap lah '],
#  ['INDOSAT',
#   'hai apa indosat sedang ada kendala lagi sast ini sinyal tidak bisa'],
#  ['INDOSAT', 'membalas ada yg murah gb seribu paket yellow'],
#  ['TSEL', 'woi anjing jaringannya kayak tai bangsat '],
#  ['TSEL', ' tolong di respon dong keluhan customer'],
#  ['TRI',
#   'membalas karena ku sanggup utk slalu berdoa berusaha di jaman yg trbilang keras dgn three maka bsa hemat untuk rakyat trijakartafair '],
#  ['INDOSAT', 'ni aq make simpati'],
#  ['TSEL',
#   ' mas mba saya beli perdana simpati loop tapi tdk dapat regist pdhal nik dan kk suda bnar tlg bantuan nya mohon banget no 99 '],
#  ['TRI',
#   ' sinyal taek jaringan bangsat gak guna operator jancukan mati ae kon cok '],
#  ['TSEL',
#   ' heh telkomsel jancok prasa an provider lain waktu ganti jam paketan gak pake ngilangin sinyal paket data '],
#  ['TSEL', 'no ini me nelp mengatasnamakan mohon bantuan dari '],
#  ['TRI', 'kini tersedia paket axtri juta murah meriah axis '],
#  ['INDOSAT', 'aku pake indosat eon'],
#  ['XL', ' provider penipu anjink'],
#  ['XL', ' internetan dengan xl sangat lambat'],
#  ['TRI', 'membalas sinyal bangsat '],
#  ['INDOSAT', 'maka nya gnti kartu lo dan pake snyal cepat dan stabil '],
#  ['TRI', ' g sinyal hp pian edge kah tri adingtantan '],
#  ['XL', 'tak cukup akses cepat'],
#  ['TRI',
#   'ternyata skrg sudah bisa twitter an gratis dgn internet tri alwayson aon '],
#  ['XL',
#   ' sia sia gue isi paket data ga bisa di pake udah hari costumer service nya juga ga bisa di hubungin'],
#  ['TSEL', ' sudah hari mu kagak bisa anjing tanggung jawab woi '],
#  ['TSEL',
#   'membalas masalahnya kita lbh pilih mahal dikit tp lemot ketimbang mahal banget tp lemot juga cth telkomsel dpt gb dg pembagian tentunya kalo beli pulsa bisa habis baru dpt gb dg pembagian yg sama speed nya ancur pula di gnya ya jelas pilih dpt gb kartu sekali pake '],
#  ['INDOSAT', 'membalas sebulan kmrn aku nyoba xl'],
#  ['INDOSAT',
#   'sama parah nih rt sinyal indosat bikin nangis beli paket mahal toh sama aja '],
#  ['TRI', ' tolong di respon keluhan saya'],
#  ['INDOSAT', ' mantap jaringan indosat drop lagi'],
#  ['XL',
#   'membalas kenapa jaringan kaya gini pake lte serasa pake lambat bener udah gitu lagi signal naik turun lagi '],
#  ['XL', ' mari mulai hari ini dengan berita yang bikin senang'],
#  ['TRI',
#   ' membalas mau kasih kejutan tapi ga punya pasangan gimana dong tolong bantu agar program voucher asmaraku berjalan lancar dgn semestinya '],
#  ['TRI', 'membalas tai lahhh '],
#  ['XL', ' membalas xlbagiberkah kecepatan jaringan kenceng abis'],
#  ['TRI', 'tai lo bisanya pending aja sial doangan '],
#  ['INDOSAT', 'membalas halo'],
#  ['TSEL',
#   'buat apa mahalnya gue telkomsel nih mjb rt jancok mahal itu rt makanya pk telkomsel kaga pernah tuh pending '],
#  ['TSEL', 'kalo ppake bb enak nya paske telkomsel '],
#  ['TSEL', 'ok'],
#  ['XL', 'sinyal xl lg kencang nih '],
#  ['TRI',
#   'wah tumben nih di kosan sinyal tri bagus hahaha azeeek mantap at wisma wibisono '],
#  ['TSEL',
#   'apa pendapat kamu ttg orang yg buang sampah sembarangan di gunung jangan ditiru ya'],
#  ['INDOSAT',
#   'membalas iyh tpi alhamdulillah kuota malamnya gb ga kyk indosat gb '],
#  ['TSEL', 'membalas oh gitu ya min'],
#  ['TRI', 'membalas kalo marah'],
#  ['TRI',
#   'kapan benernya ini di daerah cilamaya wetan koneksinya bangsat sampe ketinggalan ulangan gini masa kalah sama sih '],
#  ['INDOSAT', 'liat timeline pada ngmongin an'],
#  ['TSEL',
#   'bersama jbr jogya tanpa wifi kalah sm cak untung ada flash lumayan mudik '],
#  ['XL', 'pada jaman dahulu'],
#  ['TSEL',
#   'enak pake simpati freedom murah sesama telkomsel nelpon menit gratis berjam '],
#  ['TSEL', 'woy internet gue gimana ini kapan bisanya anjing '],
#  ['TSEL',
#   'sangat puas utk pelayanan khususnya di grapari itc roxy mas kmrn sangat kesusahan utk registrasi ulang'],
#  ['INDOSAT', 'dear indosat'],
#  ['TRI',
#   'membalas bagaimana update an nya parah banget tri asli sekarang parahnya banget'],
#  ['INDOSAT',
#   'membalas indosat mah tolol jaringan suka lag ngapain lu make indosat anjing indosat anjing '],
#  ['TSEL', ' admin'],
#  ['XL', 'membalas provider anjing xl '],
#  ['XL', 'xlku gak joss rt sinyal di surabaya joss '],
#  ['TRI',
#   ' provider terburuk sepanjang sejarah indonesia gegayaan lu bangsat sponsorin mobile legend tapi ngeleg anjing dancok udah hari ga bisa internetan ini aja make wifi '],
#  ['TSEL', 'yatuhan hujan seharian telkomsel'],
#  ['INDOSAT',
#   'membalas harikonsumennasionalindosat bagi sy bagai kan kekasihku udah murah dan mudah terakses ke seglapenjuru selamat hari kinsmen indonesia '],
#  ['INDOSAT', 'indosat getting worse asu terjemahkan tweet'],
#  ['XL', 'membalas perlu donlot kenceng bro lha ini juga aneh'],
#  ['TSEL', 'pake telkomsel emg enak bgttt cepet'],
#  ['INDOSAT', 'membalas indosat jancok '],
#  ['TRI', 'halo operator cacat mau registrasi lewat aplikasi bawaan aja gini'],
#  ['XL',
#   'membalas ia nonton nya patah patah karena sinyal jelek kualitas sampah '],
#  ['TRI',
#   ' koneksi internet di indonesia memuncaki peringkat sebagai koneksi tercepat bikin marah'],
#  ['INDOSAT',
#   'membalas apa segitu susahnya ya proses stop sms indosat boleh tau gak tindakan apa aja yg udah dilakuin kok sampe bulan ga kelar urusannya dan sampe hari ini saya msh trs dikirim sampah '],
#  ['TSEL',
#   ' mohon bantuan telkomsel nmr telfon kami kontaknya diretas orang yg gak bertanggung jawab gimana cara menindak lanjutinya karena sdh banyak org yg tertipu '],
#  ['TRI', 'membalas nyaman kpd nasabah tks aldi '],
#  ['TSEL', 'seturan'],
#  ['XL',
#   ' wey xl ini kenapa sinyal ilangan padahl jaringan adaa coba kasih tau alasannya'],
#  ['TSEL',
#   'membalas rt telkomsel rt kartu apa yang enak buat internetan yg murah and koneksi cepat '],
#  ['TSEL', ' iyah mao pake telkomsel aje ganti provider ajee murah sih'],
#  ['XL', ' saya ingin konfirmasi mengenai sinyal'],
#  ['INDOSAT', 'ugm dan indosat membatalkan pembicara pro hti'],
#  ['INDOSAT', ' membalas jalan pantai'],
#  ['XL', 'network nya cacat nih '],
#  ['XL', 'membalas reastart kepala aja xl bangsat '],
#  ['TRI',
#   'rt jaman sekarang kayanya mudah sekali untuk mendapatkan informasi ya'],
#  ['TSEL', ' ga enak'],
#  ['XL',
#   ' tiap hari laporan keluhan hilang kuota selama sebulan tanggapan hanya tunggu update doang ah xl memang tdk bertanggung jwb atas keluhan pelanggan cuma mau ambil untung sendiri tanpa mau slesai kan masalah pelanggan '],
#  ['XL',
#   'membalas masih aja sama koneksinya sampah padahal pakai kuota khusus malam masih mending paket xl mifi yg dlu dripada xl go izi yg bikin emosi '],
#  ['INDOSAT', 'membalas ditempatku kelapa gading xl jelek banget'],
#  ['TRI',
#   ' apakah masih tersedia saya buka laman dan tdk menemukan informasi ttg '],
#  ['TSEL', 'membalas lw mlem telkomsel emang gtu lemot prepareroadshowirwan '],
#  ['TSEL',
#   'mau makan enak trus murah tukerin poin telkomsel kamu terimakasih tweetlayananmasyarakat '],
#  ['TRI',
#   ' gimana nih cara cek sisa gratisan internet sms saya beli kartu tri yg edisi kartu perdana kosong'],
#  ['INDOSAT', 'yaaa'],
#  ['INDOSAT', 'indosat lgi ngebut'],
#  ['INDOSAT',
#   ' knp terjadi lg kesedot pulsa padahal sisa kuota masih ada dan sisa waktu kuota juga tolong bantu mas mbak indosat terima kasih '],
#  ['INDOSAT',
#   'membalas apakah informasi yang saya berikan tdk jelas bagaimana caranya daerah saya masih bagaimana mau nikmati akses internet operator lain sudah mendukung data dan indosat sama sekali tidak pernah urus jaringan nya di soppeng hanya saja butuh info apa lagi bukti nyata '],
#  ['TSEL', ' halooo sy mau bertanya dong '],
#  ['TSEL',
#   'tolol kalo gw blg sih kakrt kocak ah axis rt gitu kek bikin iklan ramadhan kayak telkomsel axis sampah banget '],
#  ['INDOSAT', 'dengerin lagu dari youtube pake koneksi indosat'],
#  ['INDOSAT',
#   'tower indosat rt spongebobwithpatrick nangis di atas pohon rumah tower '],
#  ['TRI', 'tri cirebon koplaknya gak waras'],
#  ['XL', 'saya beli paket xtra kuota dan ada kuota iflix gb'],
#  ['INDOSAT',
#   'kau tinggal di daerah sana bah deket sekolahkurt padahal kalo tinggal di deket kantor indosat'],
#  ['TRI', 'membalas woy gemana woy'],
#  ['INDOSAT',
#   ' halo permisi mau tnya ini kan saya lagi langganan indosat unlimited gb unlimited apps tapi kenapa di aplikasi my im tidak keluar claimnya dan vpnnya ya minta tolong dm saya juga dibalas terima kasih '],
#  ['TRI',
#   ' min follback dong biar bisa gabung sama mimin dan bisa tau informasi tentang three aku juga pengguna three '],
#  ['INDOSAT', 'mau nangis ishhhhhh aaaaaaa indosat kau neo kaesekei yya '],
#  ['XL',
#   'membalas gua kok make xl sinyal gak beres yak maen ml koneksi nya cacat banget daerah galaxi bekasi yaelahhhh '],
#  ['XL', 'anjing lu ngentot xl goblok dasar gk tau diri udh hrga paketan naik'],
#  ['XL', 'minggu pagi enak ke kios bang yusufmoga dapat buku keren'],
#  ['TSEL',
#   'wifi di rumah lemot banget uda beberapa hari kenapa sih ini kesel ih '],
#  ['XL',
#   'membalas sepertinya xl ini operator yg gak recomend it pelayanan dan tindak lanjut nya tidak jelas kepastian nya'],
#  ['TSEL',
#   'telkomsel seneng banget ngasih bonus sms sesama tsel pertanyaannya'],
#  ['XL', 'membalas provider bangsat xl '],
#  ['TRI', 'membalas cek informasi pulsa balesan nya minta maaf trus '],
#  ['XL', 'pagi pagi gini sinyal xl rame kencang'],
#  ['INDOSAT',
#   ' lo bw simcard dr indo yah ktny indosat bs yang sinyalnya lumayan bagus verizon'],
#  ['XL', 'lumayan lah sinyal xl buat maen coc doang'],
#  ['TRI',
#   ' weeeh min ini gimane si sinyalnye makin cacat ae njs dari kmren saya bisa internetan '],
#  ['TSEL', 'membalas nomer saya infokan via dm tolong diperiksa terima kasih '],
#  ['INDOSAT', 'frekuensi semakin pendek'],
#  ['TRI', ' disaat saling marah'],
#  ['TSEL',
#   ' sangat kecewa dngan telkomselsaya beli tm knapa banyak sekali pulsa di ambilbuat apa paket banyak ini '],
#  ['TSEL',
#   'kuakui tarif kuota inet telkomsel emang mahaltp brbanding lurus ma kualitasnya dksh murah sambat lemot'],
#  ['TRI', 'si signyal tai kalau dikasih ujan selamat signal '],
#  ['INDOSAT',
#   'lebih cepat dan stabil dibanding yang pake indosat apakah ada yang mengalami hal serupa indosatkeren saveindosat penggunaindosat selalu sabar menghadapi cobaan '],
#  ['XL', 'sengaja mengecek tengah mlm apkh xl masih gangguan'],
#  ['INDOSAT',
#   'membalas kualitas internet indosat masih edge kalah sama operator baru yg ud blackberrypaket kecewa bgt '],
#  ['INDOSAT', ' doyan banget sih indosat kirim sms sampah kayak gini '],
#  ['TSEL', 'pake xl dongk'],
#  ['TRI', ' khusus wil lreung sktr aja mgkn dek'],
#  ['TRI',
#   'yang suka bola ada paket menarik nih dr cobaiin deh monetizeid menambahkan'],
#  ['TSEL', ' dari dulu dan sampai sekarang telkomsel memang terbaik '],
#  ['TRI', 'anjing bangsat'],
#  ['TSEL',
#   'boti promo time rt memang itu selalu memberikan yang terbaik rt g >asik skli '],
#  ['XL',
#   'membalas kenapa pulsa saya terpotong oleh fb yg saya tdk pernah klik berlangganan klo seperti ini sangat merugikan bagi saya sedangkan no operator tdk dpt hub untuk menyampaikan keluhan ini mohon segera di tindak lanjuti keluhan saya ini 99 '],
#  ['INDOSAT', 'membalas saat lagi genting tiba tiba error'],
#  ['TRI', 'membalas lagi pengen marah aja'],
#  ['INDOSAT',
#   'membalas sudah aku coba tapi tetap gak bisa asu asu sekarang indosat ancur ancuran udah uptodate aja masalahnya apa gak usah berbelit belit asu '],
#  ['TRI', 'brengsek juga nih tri beli paket yang murah jaringan lancar'],
#  ['XL',
#   'membalas iyak ih aneh perkara mau cek kuota aja harus ribet pindahin simcard ke hp atau nanya via dm ke admin mulu ribet wey gilak pun jatohnya mahal kuotanya kzl '],
#  ['INDOSAT', 'sinyal indosat ooredoo bangsat lelet parah jancok '],
#  ['INDOSAT',
#   ' aku bener tidak menggunakan kartu untuk apapun dan gila sih ini namanya baru aja diisi bapake rb dan skrg tinggal rb pdhl cuma buat bales sms bapak sekali ini bisa tolong jelasin ga ya aku ga terima soalnya dibela belain pake indosat'],
#  ['INDOSAT',
#   ' tolong masalah sy cepat ditangani dari tanggal saya ada komplain sampai sekarang ibuk sy yg keluhan karena pulsa juga kesedot sm seperti saya tapi blm ada tindak lanjut selain kata maaf sudah kayak indosat aja pulsa kesedot gak jelas '],
#  ['TRI', 'terimakasih '],
#  ['XL',
#   ' kok xl sinyal sering gangguan mulu yak akhir ini naik turun terus jaringannya ampun banget'],
#  ['INDOSAT',
#   'membalas indosat kapan sinyale gk jancoke yo sinyale kyo taek dowo pedot pucuke '],
#  ['INDOSAT', 'huahahahahahahart xl kampreetttttsinyal putus mulu'],
#  ['TRI', 'membalas alhamdulillah'],
#  ['TRI', 'sinyal tri dimasjid ternyata selalu penuh '],
#  ['XL',
#   'membalas yee lu mah pake wajar sinyal nya gitu pake xl aja sinyal nya lumayan lah kalo buat main ml '],
#  ['INDOSAT',
#   'asik ngurus kartu ilang di galeri indosat pekanbaru cepet banget'],
#  ['TRI', 'main ml jadi kalah mulu bangsat '],
#  ['XL', 'untung sinyal xl lumayan kenceng disini '],
#  ['INDOSAT', 'gila tl gue sampah semua isinya rp indosat '],
#  ['TSEL', 'seneng banget kesini'],
#  ['XL', 'membalas cacat xl maen moba nge lag mulu jadinya grgr lemot '],
#  ['TSEL', 'telkomsel daerah soreang'],
#  ['INDOSAT', ' sby jadi presiden ri ke ekonomi ina kurang bagus'],
#  ['TSEL',
#   ' telkomsel tuk android tri kartu yg enak murah buat internetan apa yak '],
#  ['TSEL', 'datanya sudah masukterimakasih banyak atas pelayanannya'],
#  ['INDOSAT', ' fak indosat anjing'],
#  ['XL',
#   'ngambang aja rt kalo di atas sinyal as bagus tp sinyal xl jelekkalo dibawah sinyal xl bagus tp sinyal as jelek '],
#  ['TSEL',
#   'ini kenapa telkomsel kampret banget sih kenapa hari ini jaringan lemot kucing ah '],
#  ['INDOSAT',
#   'duh kartu henpon bikin ribettt nomor asli dari smp pake indosat > ga mungkin diganti krn nomornya uda dipake buat byk hal tapi pacar make xl > mau ga mau jd pake xl juga ehhh duanya sampah layanannya '],
#  ['XL',
#   'membalas kalo masih doyan uang jangan bikin konsumen luh kecewa dengan pelayanan lu '],
#  ['XL', 'ayo jangan bikin pelanggan setiamu ini kecewa'],
#  ['TRI',
#   'colek rt korban penipuan >> rt aon katanya gratis twitter lah ini kok aku twitteran gk bisa akhi '],
#  ['TRI',
#   'ampun deh tri lemot anat sinyal ada luplep chya jdi bisa bom ega tetep idolaku '],
#  ['XL',
# ...
#  ['XL', ' aja raap'],
#  ['INDOSAT',
#   ' min tolong dong jaringan indosat di purwakarta segara di perluas masa aku kalo mau internetan cepet harus ke purwakarta kota dulu '],
#  ['INDOSAT',
#   ' ini kenapa jadi gak ada jawaban ya dari indosat dulu respon cs nya termasuk cepat tapi sekarang bisa seminggu baru dibalas '],
#  ['TSEL',
#   'membalas pakai lebih mantap jiwa dibandingkan pokoknya beda jauhlah '],
#  ['INDOSAT', 'membalas xl lumayan jar'],
#  ['TRI', 'kecewa pake tri sinyal masih bapuk harganya malah naik '],
#  ['TSEL', 'membalas internet lancar apanya anjing '],
#  ['XL', ' sinyal sih tapi data lemotnya kaya apaan tau'],
#  ['XL', 'cobain dulu paket internet dari xl nih tweeps'],
#  ['TRI', 'sinyal tri '],
#  ['TRI',
#   'udah lama gak buka website dan ternyata udah berubah total jauh lebih simpel dan mudah navigasinya bukantwitberbayar '],
#  ['XL', 'membalas siyaaap'],
#  ['INDOSAT', ' kecewa sama kualitas indosat sekarang '],
#  ['XL', 'membalas goblok amat schlo lihat dm gw sebelumnya'],
#  ['INDOSAT',
#   ' halo indosat nomor saya sama sekali tidak bisa digunakan sejak sore tadi meski sudah coba set jaringan manual dan set apn bagaimanakah solusinyadetail informasi saya dm ya '],
#  ['XL', 'membalas lokasi sragen kec gondang kel glonggong'],
#  ['TRI',
#   'membalas informasi selanjutnya kira saya akan dihubungi lewat mana min '],
#  ['INDOSAT',
#   'telpon saya cepat nama twitnya doang indosat care tapi gak care sama pelanggan '],
#  ['XL', ' min keluhan saya kok ga di gubris ya butuh banget nih '],
#  ['XL',
#   'xl kenapa paketnya jadi mahal ya dan gak worth it harga dan kuota yang didapat '],
#  ['INDOSAT', ' indosat anjing kesel aing '],
#  ['TSEL',
#   'telkomsel enak aiy rt indosat chaa rt xl mesti rt aku sebal program promo tarif murah'],
#  ['TSEL', 'tweeps'],
#  ['XL', ' hai bagus'],
#  ['INDOSAT',
#   ' admin help dong mau beli sticker tp error payment pulsa cukup jaringan indosat bagus '],
#  ['XL', ' najissss anjing pke provider ginian'],
#  ['TSEL', 'telkomsel rt provider yg enak buat langganan'],
#  ['XL',
#   'internet yg stabil dan cepat jd kebutuhan saat menggelar workshop toys photo bareng kelas blogger siang tadi untung pake xl jd gak masalah '],
#  ['TRI',
#   ' bangsat nih tri sinyalnya kaya eeq keong lgi main ml sinyalnya rendah bgt anjing emang tutup saja lahh tri bikin tajil '],
#  ['TSEL',
#   'baca berita kmrn bukannya layanan telkomsel yg terbaik rt bis telkomsel memang sering error ya signal edge tapi ga bisa '],
#  ['TRI',
#   'maturnuwun ngasih dingkluk dingkluk rt yeyey koneksi sudah lancar jaya lagi terima kasih '],
#  ['XL',
#   'apakah senang sama dengan bahagia apakah kebahagiaan setiap orang itu sama spreadthelove '],
#  ['INDOSAT',
#   'membalas ah si taehyun kl tinggal di indo jg kynya bakal make indosat dah paling mantap sih telkomsel tp ya gtlah hargane bikin jatuh miskin '],
#  ['TSEL',
#   'membalas ntah lah mbak agak kecewa juga di tengah main sinyal mancet '],
#  ['TSEL',
#   'membalas sama mbak sy ikut sebulan gb minggu lgsg habis sy juga kecewa '],
#  ['TRI', 'kalo '],
#  ['TRI', 'tadi sore ditelp operator jakarta'],
#  ['XL', 'membalas provider bangsat xl maling '],
#  ['XL', 'mifi xl go paling enak dipake rame yo sinyal kencang'],
#  ['TSEL',
#   'pertama kali berasa sangat puas dgn layanan customer service telkomsel telkomselgandaria'],
#  ['XL',
#   'jadi setahun belakangan internet gw sering mati mati sendiri kalau hidup pun lambat banget percuma ada kuota youtube juga'],
#  ['TSEL', 'terimakasih'],
#  ['TSEL', 'aku orep manehpulsa telkomsel ku mbalik jancok ancen '],
#  ['TSEL', 'sinyal di oro dowo kota malang lemot '],
#  ['XL',
#   'hahaa demi sinyal hape rt wah sinyal xl da kartosuro joss bgt gimana kalo ak pindah kartosuro aaja yaaa '],
#  ['TRI',
#   'membalas bisa kah memberikan saya informasi tri retail untuk wilayah cengkareng '],
#  ['INDOSAT', ' situ jual aset indosat'],
#  ['TSEL',
#   'enak opmin unlimited an pake telkomsel uda murah cepat pula abisinitandatangankontrak '],
#  ['INDOSAT', 'jancok'],
#  ['XL',
#   'test ilmu joss tuh ehhrt test sinyal yah mas hendyxl nya sdg bermasalah nih sinyalnyart test '],
#  ['TSEL', 'telkomsel ini memang penyedot pulsa terbaik yasubhanallah '],
#  ['INDOSAT', 'jaringan terbaru indosat mantap '],
#  ['XL', 'xlamat hari minggu'],
#  ['XL', ' sekali nya make prov ini kesan nya langsung kecewa berat nuhunxl '],
#  ['XL',
#   'untuk dan yang terhormat saya kecewa dengan pelayanan xl yang susah sekali untuk masuk di halaman my xl di aplikasi maupun melalui browser saya ingin isi ulang paket internet modem saya jadi tidak bisa ini terjadi selalu berulang ulang '],
#  ['TSEL', 'ini telkomsel gangguan atau apa sih anjing'],
#  ['TSEL', 'telkomsel'],
#  ['XL',
#   'mereka gatau nyanyi lagu apa coba kalo bisa request lagu korea mantab kali ya si golden boyz xtravaganza fantaxisjabo '],
#  ['TSEL',
#   'membalas min telkomsel lagi sos ne tahu gk card sim yg enak murah twitteran '],
#  ['XL', 'membalas di daerah rumah saya saja min'],
#  ['INDOSAT',
#   'tolong bantuan nya dong ini sinyal indosat jelek banget lola bnget mhon di bantu terima kasih '],
#  ['XL',
#   'membalas gamau nyoba xl prioritas bli kenceng sinyal lumayan murah jg untuk kelasnya '],
#  ['TRI', 'membalas makasi informasi nya min'],
#  ['XL',
#   ' salam hormat untyk xl saya mau sampaikan keluhan saya yang terjadi kemarin dan sampai sekatang belum selesai yaitu kuota paket xlcombo gb tiba tiba habis padahal pemakaian bari satu hari dan itupun baru dipakai untuk chatimgan mohon bantua'],
#  ['INDOSAT',
#   'sabar yah bro klo malam emang kek gitu rt gila ya indosat ooredoo sinyalnya jelek banget mau nangis '],
#  ['INDOSAT',
#   'woow heebat cepet bnget rt rbt nya udah ada loh buat indosat xl terus sbentar lg '],
#  ['TRI',
#   ' wow alwayson dong ya rt udah tahun pake tri lancar aja kartunya mantab'],
#  ['TSEL',
#   'klo kartu baru gitu byarny brp lex rt ke graphari telkomsel cpt koq'],
#  ['XL',
#   'ini xl lucu di lantai sinyal amburadul tp lantai dibawah basement sinyal pol'],
#  ['TRI', ' lo cacat di cilegon '],
#  ['TSEL',
#   ' kak aku mau registrasi kok nggak bisa malah muncul hanya panggilan tetap pas aku mau nonaktifkan fdn nya malah disuruh masukin kode puk trus gimana kak '],
#  ['XL', 'hai selamat pagi'],
#  ['TRI', 'membalas makasih min'],
#  ['XL', 'membalas bukti layanan sampah c9'],
#  ['XL',
#   'membalas yakin lex bukan wifi loe itu macasih xl sampe segitu itu sinciapo tuh emang ya ampun'],
#  ['XL', ' provider sampah'],
#  ['TRI',
#   'membalas asli min tvc nya banyak bgd yg ngena nih hahahaha mantab emg sekalinya buat iklan bermutu bgd '],
#  ['TSEL', 'asli lah ini kampret udah harga paket internet makin mahal'],
#  ['XL',
#   ' cumaa di xl jaringan sinyal full kuota banyak tapii gabisaa internetan cumaa di xl kecewa beratt sumpahh '],
#  ['TRI', 'membalas cukup hayati lelah maas'],
#  ['TRI', ' keluhan saya kok ga dijawab ya dari kemarin sampe skrg '],
#  ['TRI', ' jadi ajudan beliau aja pasti mudah deketinya bangkitindonesia '],
#  ['INDOSAT', 'indosat udah lancar ni alhamdulillah '],
#  ['XL',
#   'bangsat benerlah ini provider nguji kesabaran di bulan suci ramadan '],
#  ['XL',
#   'membalas selamat siang sis saya mau bertanya tentang keluhan sya apa sis bsa membantu sya jlaskn masa berlaku kartu sya '],
#  ['INDOSAT', 'alhamdulillah hujan ready axis gb'],
#  ['XL', 'membalas provider anjing xl isiny cm maling dan penipu konsumen '],
#  ['TRI', 'membalas tai'],
#  ['XL', 'bangsat fuck minta data malah di cuekin kuotahilangsendiri '],
#  ['XL', 'membalas provider goblok maling xl tolol '],
#  ['TSEL',
#   'membalas ok terima kasih tolong supaya di daerah saya ini tercover juga ya'],
#  ['XL',
#   'halo min kok tweet saya tidak ditanggapi min internet xl selalu tdk bisa diakses'],
#  ['TSEL',
#   'membalas gratis yo wah enak tenan aq pake telkomsel ne mahal he he tp ad trik biar murah he he '],
#  ['XL', ' bagus '],
#  ['TSEL',
#   ' udah seminggu belakangan ini hallo kick saya ga stabil tiap jam keatas'],
#  ['XL',
#   'membalas dan lainnya provider bangsat ganti kerugian konsumen anjing maling jd provider bangsat xl '],
#  ['INDOSAT', ' kembali kasih bahagia itu kalo balas tweet lancar cepat'],
#  ['TSEL',
#   'membalas seharian kemarim nyoba beli gagal terus ada gangguan infonya kecewa '],
#  ['INDOSAT', ' selamat sore'],
#  ['TRI',
#   'membalas betul gak three mengadakan undian poin care mohon informasi nya '],
#  ['TSEL', ' mbak mas gimana nih udah hari gw main game tapi ga bisa'],
#  ['INDOSAT',
#   'photo jaringan baru cepat dan stabil repost iwantitnow indosat im '],
#  ['TSEL', 'lemot ya lemot aja rt tergantung untuk paket yang digunain'],
#  ['TRI',
#   'makasi kaka mimin rt informasi lengkap paketri hello masa aktif panjang bisa langsung klik disini ya '],
#  ['TSEL', 'seneng pake telkomsel'],
#  ['XL', 'terima kasih'],
#  ['TSEL', 'on pake telkomsel tujuan utamanya adalah biar paketan tri ga abis'],
#  ['TRI',
#   'membalas cinta seperti serangkaian huruf yg membentuk satu kata hingga menjadi kalimat utuh yg mudah dibaca ahlicinta '],
#  ['TRI',
#   ' sinyal kaya tai aja laguan sposorin ml urusin dulu sinyal lu bego semenjak sponsor atau bayar apa aja paket tri jadi kontol sinyalnya '],
#  ['XL', 'iya sih dirumahku'],
#  ['TRI', ' kemarin eror pacar gue marah min '],
#  ['INDOSAT', 'membalas hi ibu kandou'],
#  ['INDOSAT',
#   'membalas saya regist pake indosat ga bisa bos terus saya regist pake telkomsel wah mantap terasa '],
#  ['XL', 'membalas provider bangsat xl maling jadi provider xl goblok '],
#  ['INDOSAT',
#   'membalas baru kemarin isi pulsa buset ini cek pulsa langsung rp wkwkwk lol banget sumpah baru kali ini ada operator sebesar indosat pelayanannya maling malingggg tolong cepat ditangani'],
#  ['TRI', 'aku tri seperti hubungan pacaran yg udah lama'],
#  ['XL',
#   'membalas lebih cape liat keluhan custimer di sosmed dari jaman dulu tapi gapindah operator meng hahahaha '],
#  ['XL', 'sinyal ok'],
#  ['TRI', 'telpon murah seharian ke semua operator'],
#  ['TRI', ' makanya pke tri sinyal di jatinangor dak mantap '],
#  ['TSEL', ' oia'],
#  ['TSEL',
#   'dear saya baru saja registrasi kartu tp tulizannya nik tidk ditemukan mohon bantuan nomor dan id di dm '],
#  ['TSEL', 'kalau masih gini gimana udah di restart'],
#  ['XL', ' nek liyane yo mbuhhahaha '],
#  ['TSEL',
#   'waw sungguh puas membaca keluhan para pelanggan telkomsel di sangat kecewa dgn kwalitasnya '],
#  ['INDOSAT', 'membalas aku baru isi pulsa kemarin sore'],
#  ['INDOSAT', 'indosat ngapa si anjing kesel banget '],
#  ['TSEL', ' kok lemot ya apakah benar dr telkomsel ini perdana nya '],
#  ['TSEL', 'butuh telkomsel poin buat jajan murah'],
#  ['INDOSAT', 'kerja sama pt indosat '],
#  ['INDOSAT', 'no signal sudah di restart'],
#  ['XL',
#   'internetan pake xl rasakan jaringan hotrod internet super cepat stabil cek '],
#  ['XL', ' jaringan najis ngebatin ampun'],
#  ['TSEL',
#   'sinyal telkomsel lumayan cepat di sekolah laskar pelangi kota manggar at geraihalo manggar pic '],
#  ['XL', 'udah nyala sekarang lg dibanda aceh'],
#  ['TSEL', 'hai anjing '],
#  ['XL', 'pasti xl rt sinyal kencang'],
#  ['TSEL', 'kecewa doi ko jadi cacat bgt '],
#  ['INDOSAT', 'rt iyah'],
#  ['TSEL', 'duuh jd ngrepotin gini'],
#  ['INDOSAT',
#   'membalas dan lainnya alhamdulillah ternyata ada yang lebih bermafaat dibanding membeli indosat '],
#  ['XL', ' kalian beneran provide service gak sih pingin nangis rasanya '],
#  ['TSEL',
#   'membalas soto ayam yg enak soto pak dalbe sebelahnya telkomsel lamamurah pula '],
#  ['TRI',
#   'emang operator nya ka yg bafukkkkrt ini kartu gue doang apa emang operator tri yg gda sinyal _ bapuk '],
#  ['INDOSAT', 'alhamdulillah sinyal indosat sudah normal kembali '],
#  ['TRI', 'hahahhahahhamarehhh'],
#  ['XL',
#   ' min xl lagi gangguan kenapa koneksi internetnya lambat sekali padahal sinyal bagus lte '],
#  ['TRI',
#   'indosat udah gabung sama tri ya sekarang kuota doang banyak sinyal lemotnya mantap '],
#  ['INDOSAT', ' rt sumpaaaaaah indosat what the hell yah'],
#  ['TRI',
#   ' anjing sinyal ilang menit gua lagi di game bangsat nherrikn lah gua gamer kerja ngapain aja kontol '],
#  ['TRI', ' benci jadi cinta'],
#  ['TSEL', 'karena atau sangat cepat dan kuat signalnyaapalagi sdg nongkrong '],
#  ['XL', 'ada apa dengan masak iya'],
#  ['TRI', 'asik beli perdana rb isi pulsa rb'],
#  ['INDOSAT',
#   'rt aku seneng bgd ungu band mraih menang indosat award kpn nih hits klip ke mantap almbenyamin mraih indosat legen '],
#  ['TRI',
#   'membalas aku sih isih ng yk nik widihh mantap tak kiro susah sinyal nik wkwkwk '],
#  ['INDOSAT',
#   'nah kaya gini kan enak jadi ada klarifikasi dari indosat pengguna gak capek ganti ganti jaringan terima kasih mba mila semangat ya kerjanya jangan jaringan aja yang dipelihara hati juga wuff menambahkan'],
#  ['INDOSAT',
#   'ganti aj dit rt pokoknya saya lagi kecewa berat sm indosat mkualitas sinyal hsdpa gprs nya kalah sama '],
#  ['INDOSAT', 'membalas pulsa saya berkurang ribu saat ada sms dari ring'],
#  ['INDOSAT', ' min tolong bantu cek no indosat saya di no 99'],
#  ['TSEL', ' wei anjing'],
#  ['INDOSAT', 'membalas hai kak'],
#  ['TRI', 'lumayan lapar rt selamat siang'],
#  ['TRI', ' paket malam gue kok gak aktif operator kontol bangsat lu semua '],
#  ['TRI',
#   ' ini sinyal tri di rumah saya masih lemot dan tidak terjangkau jangan di suruh pindahkan ke hp lain deh'],
#  ['TRI', 'berngkt krj tpt jm '],
#  ['TRI',
#   'enaknya make tri nih gini paket murah sinyal gapake pending axis buat di hp butut aja buat smsan wkwkwk '],
#  ['INDOSAT', 'membalas sudah dari pake indosat'],
#  ['TRI', ' min folback'],
#  ['INDOSAT', 'membalas hi kak'],
#  ['INDOSAT', ' sebulan kemudian ke indosat'],
#  ['INDOSAT', 'membalas kirain kartu gua keblokir indosat asu emg '],
#  ['INDOSAT', 'indosat bikin nangis nih t______t '],
#  ['INDOSAT',
#   'kenapa sekarang indosat kuotanya juga kebagi ada yg midnight pula jam terbang paling banyak kan pagi malem omduh cepet abis '],
#  ['TSEL', 'membalas boleh saya minta bantuan terkait nomor saya '],
#  ['INDOSAT', 'membalas sblm ganti'],
#  ['XL',
#   'klik link rt gmn sih caranyart alhamdulillah sy dpt paket gemini xl murah dari '],
#  ['TRI', 'min '],
#  ['TRI',
#   'membalas tergantung sinyal di rumah kamu sih xl lebih murah tp ya di aku xl lemot parah bagusan tri '],
#  ['XL', 'di dalem gor uny ini xl ga ada sinyal'],
#  ['TSEL',
#   'sedang kecewa sama layanan bis beberapa hari ini kalo udah di atas jam maghrib paket bis nya nggak bisa dipake tumben '],
#  ['XL',
#   'sinyal kuat xl membuat surfing terasa lebih cepat dgn paket balckberry dari xl cek '],
#  ['INDOSAT',
#   'ini firstmedia ama indosat knp sih anjing dari siang gw offline '],
#  ['TSEL',
#   'saya ucapkan terimakasih kepada tim grapari pgc lt telesindo mall kalibata yang sudah mempermudah saya membuat kartu saya yg hilang'],
#  ['TRI', 'sinyal tri lemot'],
#  ['TRI',
#   'jual pulsa paket internet all operator murah bgt indosat gb jam hr cuma'],
#  ['INDOSAT', 'gileee baru laporan indosat kalo paketan bermasalah'],
#  ['XL',
#   ' yeahhh rt jiaaah disini sinyal aja gak nongol seberapa kencang lte besutan xl axiata '],
#  ['TSEL',
#   'pejuangforward guidolin puas raih kemenangan magis di anfield francesco guidolin merasa sangat cc '],
#  ['TSEL',
#   'membalas jancok direkturnya busuk tukang korupsi pulsa pelangganannya '],
#  ['TRI', ' min'],
#  ['TSEL', 'aku juga pnya trie'],
#  ['XL',
#   'xl itu jaringannya sangat memuaskan banget bagi para pengguna xl xlgmobile '],
#  ['XL', 'sepertinya harus pake xl nih'],
#  ['INDOSAT', ' ga lagi lagi sy pake indosat ya'],
#  ['XL',
#   'membalas hy provider xl bangsat kebanyakan nipu konsumem anjing pake byk alesan kampret '],
#  ['TSEL', 'masa siiy gw gak niy rt kecewa bgt dgn telkomsel'],
#  ['TSEL',
#   'membalas kita tunggu kehadiran nya di solotapi untuk saat ini sudah sangat puas dengan kecepatan internet yang ada '],
#  ['TRI',
#   'admin lelet ya sekarang balas cat lelet dm lelet kalo lumayan cepet mungkinkah micin kebanyakan pramborsthrowback wartegdkieps '],
#  ['TSEL',
#   'tae loe telkomsel bikin gw kesel aja loe mau loe apa sih tiba lost koneksi jancok goblok '],
#  ['XL', ' sinyal full tapi koneksi sangat lambat kecewa '],
#  ['INDOSAT',
#   'indosat ooredoo memperkenalkan gplus untk memberikan jaringan yg lbh kuat'],
#  ['INDOSAT', 'gila ya indosat ooredoo sinyalnya jelek banget mau nangis '],
#  ['XL', 'membalas hahaha benar bikin bablas mas'],
#  ...]

# %%
# Token
lttoken = []
for i in listwit:
    i[1] = i[1].strip()
    lttoken.append([i[0], i[1].split(' ')])
lttoken
# Out:
# [['INDOSAT',
#   ['kenapa',
#    'kartu',
#    'diregistrasi',
#    'nggak',
#    'bisa',
#    'pak',
#    'padahal',
#    'nomor',
#    'kk',
#    'ktp',
#    'nya',
#    'sudah',
#    'benar',
#    'sampai',
#    'gagal']],
#  ['INDOSAT', ['indosat', 'mantap', 'djaja', 'koneksinya']],
#  ['INDOSAT',
#   ['membalas',
#    'mau',
#    'nangis',
#    'deh',
#    'rasanya',
#    'pdahl',
#    'saya',
#    'percaya',
#    'betul',
#    'dengan',
#    'indosat',
#    'soal',
#    'koneksi',
#    'di',
#    'wil',
#    'karimun',
#    'tp',
#    'sudah',
#    'hari',
#    'koneksi',
#    'kacau',
#    'balau']],
#  ['INDOSAT', ['sinyal', 'indosat', 'asu', 'ari', 'musim', 'hujan']],
#  ['TRI', ['membalas', 'cek', 'dm', 'woi']],
#  ['XL',
#   ['ini',
#    'kenapa',
#    'di',
#    'bale',
#    'endah',
#    'sinyal',
#    'xl',
#    'tiba',
#    'bagus',
#    'yah',
#    'pindah',
#    'kali',
#    'yah',
#    'tower',
#    'nya',
#    'ke',
#    'deket',
#    'rumah',
#    'aneh',
#    'liat',
#    'hp',
#    'sendiri']],
#  ['TRI',
#   ['hotsale',
#    'gb',
#    'hanya',
#    'gratis',
#    'nelfon',
#    'aja',
#    'ga',
#    'ada',
#    'gratis',
#    'sms',
#    'nya',
#    'tah',
#    'min']],
#  ['TRI', ['membalas', 'dan', 'lainnya', 'hai', 'kak', 'andika']],
#  ['TSEL',
#   ['membalas',
#    'iya',
#    'min',
#    'udah',
#    'bisa',
#    'kok',
#    'hihihi',
#    'tengkyu',
#    'yaaaa',
#    'seneng',
#    'banget',
#    'pake',
#    'telkomsel',
#    'sinyal',
#    'lancaaar']],
#  ['INDOSAT',
#   ['ribu',
#    'saya',
#    'beneran',
#    'atau',
#    'bohongan',
#    'saya',
#    'coba',
#    'buat',
#    'internet',
#    'lngsung',
#    'tanpa',
#    'daftar',
#    'paket',
#    'internet',
#    'dan',
#    'alhamdulillah',
#    'bisa',
#    'buat',
#    'internet',
#    'trus',
#    'saya',
#    'buka',
#    'halaman',
#    'indosat',
#    'baru',
#    'kebuka',
#    'saya',
#    'dpt',
#    'sms',
#    'dari',
#    'indosat',
#    'kamu',
#    'internetan',
#    'dg',
#    'tarif',
#    'perkb']],
#  ['XL', ['sinyal', 'kencang', 'xl', 'mantabbbzz']],
#  ['INDOSAT',
#   ['tolong',
#    'kasih',
#    'penjelasan',
#    'yg',
#    'bisa',
#    'saya',
#    'terima',
#    'dong',
#    'kenapa',
#    'hari',
#    'ini',
#    'sinyal',
#    'indosat',
#    'sangat',
#    'mengecewakan',
#    'di',
#    'daerah',
#    'mampang',
#    'depok']],
#  ['INDOSAT',
#   ['yang',
#    'lagi',
#    'mau',
#    'liburan',
#    'di',
#    'the',
#    'jungle',
#    'bogor',
#    'indosat',
#    'super',
#    'wifi',
#    'juga',
#    'ada',
#    'di',
#    'sana',
#    'looh']],
#  ['TRI',
#   ['membalas',
#    'saya',
#    'juga',
#    'cukup',
#    'heran',
#    'mengapa',
#    'speednya',
#    'bisa',
#    'naik',
#    'dirumah',
#    'akan',
#    'saya',
#    'ss',
#    'sisa',
#    'paket',
#    'saya']],
#  ['TRI',
#   ['jikalau',
#    'masalah',
#    'sdm',
#    'yg',
#    'mengakibatkan',
#    'keluhan',
#    'saya',
#    'tidak',
#    'dibalas']],
#  ['TRI',
#   ['operator',
#    'tolong',
#    'yah',
#    'sinyal',
#    'nya',
#    'jangan',
#    'jelek',
#    'terus',
#    'tiap',
#    'hari',
#    'saya',
#    'kecewa',
#    'sekali',
#    'dengan',
#    'sekarang',
#    'padahal',
#    'sdh',
#    'tahun',
#    'pakai']],
#  ['TSEL', ['membalas', 'mantap', 'jiwa', 'nih', 'min', 'harga', 'paketnya']],
#  ['INDOSAT',
#   ['terima',
#    'kasih',
#    'kepada',
#    'sponsor',
#    'yg',
#    'sudah',
#    'mendukung',
#    'acara',
#    'kita']],
#  ['XL',
#   ['sinyal',
#    'dimana',
#    'cuma',
#    'padahal',
#    'paket',
#    'internet',
#    'makin',
#    'mahal',
#    'makin',
#    'bobrok',
#    'aja',
#    'xl',
#    'kecewa',
#    'saiah']],
#  ['XL',
#   ['membalas',
#    'woy',
#    'anjing',
#    'bukan',
#    'dikota',
#    'jakarya',
#    'saja',
#    'semua',
#    'kota',
#    'apa',
#    'lo',
#    'gak',
#    'baca',
#    'twett',
#    'pengguna',
#    'lain',
#    'makasar',
#    'aja',
#    'uda',
#    'seminggu',
#    'sialan',
#    'lo',
#    'anjing',
#    'kampret']],
#  ['TRI',
#   ['____',
#    'rt',
#    'aseek',
#    'nickminaj',
#    'kalo',
#    'hujan',
#    'dan',
#    'malam',
#    'tri',
#    'pasti',
#    'lemot',
#    'bangsat']],
#  ['TRI', ['frontal', 'cuk', 'rt', 'bangsat']],
#  ['TSEL', ['memang', 'terbaik', 'sakali', 'iye', 'teh', 'telkomsel']],
#  ['XL', ['ya', 'ampun']],
#  ['INDOSAT', ['indosat', 'sinyale', 'koyo', 'ngelec', 'asu']],
#  ['TRI', ['gimana', 'nich']],
#  ['XL',
#   ['haloo',
#    'bagaimana',
#    'nasib',
#    'keluhan',
#    'saya',
#    'tiket',
#    'c9',
#    'apakah',
#    'masih',
#    'di',
#    'tanggapi',
#    'atau',
#    'di',
#    'anggap',
#    'angin',
#    'lalu',
#    'sejak',
#    'januari',
#    'masih',
#    'belum',
#    'selesaikah',
#    'cc']],
#  ['XL', ['makassar', 'lg', 'seru', 'banget', 'nih', 'guys', 'sore', 'ini']],
#  ['INDOSAT', ['kecewa', 'berat', 'saiah', 'dengan']],
#  ['INDOSAT', ['min']],
#  ['XL', ['th', 'pakai', 'xl']],
#  ['INDOSAT', ['kebiasan', 'pake', 'indosat', 'ngecek', 'pulsa', 'salah']],
#  ['XL',
#   ['sudah',
#    'bulan',
#    'sejak',
#    'januari',
#    'keluhan',
#    'saya',
#    'no',
#    'tiket',
#    'c9',
#    'tidak',
#    'ada',
#    'respon',
#    'dan',
#    'solusi',
#    'cc']],
#  ['TSEL', ['sinyal', 'jelek', 'bgt', 'sih']],
#  ['TRI', ['maju', 'tak', 'gentar', 'membela', 'yang', 'benar']],
#  ['TSEL',
#   ['membalas',
#    'min',
#    'mau',
#    'nanya',
#    'ni',
#    'knp',
#    'sim',
#    'card',
#    'telkomsel',
#    'saya',
#    'tdk',
#    'bisa',
#    'buat',
#    'panggilan',
#    'keluar',
#    'sedangkan',
#    'kemarin',
#    'bisa',
#    'sudah',
#    'dua',
#    'minggu',
#    'koit',
#    'min',
#    'sdh',
#    'berhasil',
#    'registrasi',
#    'pula',
#    'gimana',
#    'saran',
#    'dan',
#    'tanggapan',
#    'anda',
#    'mewakili',
#    'telkomsel']],
#  ['INDOSAT',
#   ['setelah',
#    'telkomsel',
#    'ini',
#    'indosat',
#    'memakai',
#    'jasa',
#    'felix',
#    'kwetiau',
#    'org',
#    'hti',
#    'ormas',
#    'terlarang',
#    'utk',
#    'isi',
#    'acara',
#    'ramadhan',
#    'emangnya',
#    'gak',
#    'ada',
#    'kah',
#    'ulama',
#    'yg',
#    'lain',
#    'mohon',
#    'klarifikasinya',
#    'utk',
#    'apa',
#    'benar',
#    'flyer',
#    'yg',
#    'saya',
#    'terima',
#    'ini',
#    'd']],
#  ['XL', ['coba', 'cek', 'ke', 'zhir', 'bukanorangdalemxl']],
#  ['TSEL', ['di', 'tahun', 'anjing', 'tanah', 'ini']],
#  ['INDOSAT',
#   ['alhamdulillah',
#    'kartu',
#    'indosat',
#    'pintar',
#    'laris',
#    'manisbisa',
#    'free',
#    'call',
#    'menit',
#    'sms',
#    'ke',
#    'semua',
#    'indosat',
#    'dan',
#    'data']],
#  ['XL', ['sinyal', 'xl', 'kencang', 'badai']],
#  ['TRI',
#   ['membalas',
#    'saya',
#    'sedang',
#    'mempertanyakan',
#    'informasi',
#    'kuota',
#    'yg',
#    'berbeda',
#    'antara',
#    'bima',
#    'dan',
#    'web',
#    'saya',
#    'pinta',
#    'penjelasan']],
#  ['TRI',
#   ['sinyal',
#    'tri',
#    'di',
#    'area',
#    'cikarang',
#    'delta',
#    'mas',
#    'dan',
#    'jababeka',
#    'hilang',
#    'sinyal',
#    'mulai',
#    'jam',
#    'tadi',
#    'mohon',
#    'perbaikannya',
#    'terima',
#    'kasih']],
#  ['TSEL', ['sekarang', 'udah', 'jamannya', 'lte']],
#  ['INDOSAT',
#   ['makasih', 'keluhanku', 'sudah', 'di', 'tangani', 'dengan', 'cepat']],
#  ['INDOSAT', ['sekarang', 'pake', 'indosat', 'pasca', 'bayar']],
#  ['XL',
#   ['ogah',
#    'rt',
#    'beralihalah',
#    'ke',
#    'xlsinyal',
#    'kencang',
#    'dan',
#    'lari',
#    'pulsanya',
#    'juga',
#    'kencang',
#    'rt',
#    'indosat',
#    'kampring']],
#  ['INDOSAT',
#   ['di',
#    'buat',
#    'nangis',
#    'sama',
#    'jaringan',
#    'indosat',
#    'gara',
#    'jaringan',
#    'nya',
#    'jelek',
#    'nyangka',
#    'nya',
#    'mz',
#    'dari',
#    'dia',
#    'ga',
#    'di',
#    'lz',
#    'hampura',
#    'sayank']],
#  ['XL', ['membalas', 'nambahin', 'wacana']],
#  ['TRI', ['membalas', 'tolong', 'perbaiki', 'sinyal', 'di', 'aceh']],
#  ['TSEL',
#   ['`',
#    'keluarga',
#    'telkomsel',
#    'memang',
#    'terbaik',
#    'rt',
#    'kayaknya',
#    'aq',
#    'jg',
#    'akan',
#    'kembali',
#    'ke',
#    'kartu',
#    'as',
#    'qu']],
#  ['TSEL',
#   ['membalas',
#    'saya',
#    'mau',
#    'nangis',
#    'kejer',
#    'rasanya',
#    'mas',
#    'kalau',
#    'saya',
#    'main',
#    'mobile',
#    'legend',
#    'tuh',
#    'tiba',
#    'tiba',
#    'jaringan',
#    'terputus',
#    'tanpa',
#    'sebab',
#    'tau',
#    'gak',
#    'telkomsel',
#    'sering',
#    'banget',
#    'kayak',
#    'gini',
#    'padahal',
#    'untuk',
#    'streaming',
#    'apapun',
#    'itu',
#    'lancar',
#    'lancar',
#    'aja',
#    'mas',
#    'saya',
#    'udah',
#    'turun',
#    'credit',
#    'score',
#    'mobile',
#    'legend',
#    'gara',
#    'koneksi',
#    'terputus']],
#  ['TRI',
#   ['kepada',
#    'para',
#    'pemenang',
#    'kuis',
#    'bangkitindonesia',
#    'bisa',
#    'dicek',
#    'dm',
#    'nya',
#    'ya']],
#  ['TSEL', ['mantapsinyal', 'stabil', 'skrg', 'dirumahthx', 'telkomsel']],
#  ['XL',
#   ['kualitas',
#    'sinyalnya',
#    'makin',
#    'hari',
#    'makin',
#    'ancur',
#    'tolong',
#    'dong',
#    'diperbaiki']],
#  ['TSEL',
#   ['im',
#    'ne',
#    'iklan',
#    'sampah',
#    'kreatif',
#    'dikit',
#    'napa',
#    'ikutan',
#    'as',
#    'telkomsel',
#    'maluuuuuuu']],
#  ['TRI',
#   ['ready',
#    'pisan',
#    'rt',
#    'sudah',
#    'siap',
#    'untuk',
#    'kuis',
#    'bangkitindonesia',
#    'tes',
#    'suara',
#    'dulu',
#    'ah']],
#  ['TSEL',
#   ['membalas',
#    'kalo',
#    'kayak',
#    'gini',
#    'gimana',
#    'coba',
#    'aktifinnyaaaaa',
#    'kasih',
#    'tau',
#    'dong',
#    'caranyaaaaaa']],
#  ['TRI',
#   ['nah',
#    'ini',
#    'rt',
#    'cari',
#    'tri',
#    'store',
#    'terdekat',
#    'di',
#    'kota',
#    'kamu',
#    'klik',
#    'link',
#    'ini',
#    'untuk',
#    'informasi',
#    'lengkapnya',
#    'yaa']],
#  ['XL', ['pake', 'antena', 'pf', 'goceng', 'brad']],
#  ['TSEL', ['membalas', 'klo', 'bisa', 'nangis']],
#  ['TSEL',
#   ['gw',
#    'yakin',
#    'ga',
#    'bisa',
#    'baca',
#    'komen',
#    'ini',
#    'lemot',
#    'telkomselproradikalis',
#    'telkomselproradikalis',
#    'telkomselproradikalis',
#    'telkomselproradikalis',
#    'telkomselproradikalis',
#    'telkomselproradikalis',
#    'telkomselproradikalis',
#    'telkomselproradikalisjoe',
#    'menambahkan']],
#  ['TSEL', ['monyeet', 'koneksi', 'sampah']],
#  ['TRI',
#   ['irsoekarno',
#    'hatta',
#    'rt',
#    'kuis',
#    'bangkitindonesia',
#    'tebak',
#    'tokoh',
#    'yang',
#    'ada',
#    'di',
#    'gambar',
#    'ini']],
#  ['TSEL', ['membalas', 'anyway']],
#  ['INDOSAT', ['pengalaman', 'gue', 'sangat', 'mantap', 'pakek', 'indosat']],
#  ['TSEL', ['min', 'saya', 'mau', 'nanya']],
#  ['INDOSAT',
#   ['kumpul',
#    'mahadelta',
#    'dapet',
#    'rejeki',
#    'dari',
#    'indosat',
#    'lumayan',
#    'gb',
#    'free',
#    'lancar',
#    'abis',
#    'terima',
#    'kasih',
#    'indosat']],
#  ['TRI', ['membalas', 'baik']],
#  ['XL',
#   ['joss',
#    'makany',
#    'klo',
#    'beli',
#    'no',
#    'sklian',
#    'bli',
#    'sinyal',
#    'ahhaha',
#    'rt',
#    'plis',
#    'xl',
#    'jgn',
#    'balak',
#    'donk',
#    'knp',
#    'skr',
#    'signal',
#    'nya',
#    'ababil',
#    'sih']],
#  ['TSEL',
#   ['anjing',
#    'lukalau',
#    'gk',
#    'suka',
#    'mobile',
#    'legend',
#    'jangan',
#    'dilenotin',
#    'dong',
#    'sinyalnya',
#    'asu',
#    'aov',
#    'itu',
#    'asu',
#    'kyk',
#    'telkomsel']],
#  ['XL',
#   ['udah',
#    'senin',
#    'nih',
#    'upload',
#    'foto',
#    'pas',
#    'weekend',
#    'kmrn',
#    'ayo',
#    'pakai',
#    'xl',
#    'internet',
#    'super',
#    'cepat',
#    'stabil',
#    'lovepalembang',
#    'hotrod']],
#  ['TRI',
#   ['lagu',
#    'favoritku',
#    'kecewa',
#    'karna',
#    'org',
#    'itu',
#    'sukanya',
#    'bikin',
#    'hati',
#    'org',
#    'kecewa',
#    'baper',
#    'bgt',
#    'lagunya',
#    'konserrossa']],
#  ['TRI', ['merah', 'sinyalnya']],
#  ['INDOSAT',
#   ['nih',
#    'provider',
#    'harus',
#    'banyak',
#    'belajar',
#    'sama',
#    'keluhan',
#    'cepat',
#    'di',
#    'tanggapi']],
#  ['INDOSAT',
#   ['apakah',
#    'ini',
#    'kemajuan',
#    'apa',
#    'indosat',
#    'makin',
#    'maju',
#    'dari',
#    'kemarin',
#    'kemarin',
#    'internetnya',
#    'cepet',
#    'terusssss',
#    'selamat']],
#  ['TSEL', ['cs', 'nya', 'lelet', 'dan', 'lemot']],
#  ['XL',
#   ['sumpah',
#    'xl',
#    'sampah',
#    'banget',
#    'sinyalnya',
#    'benerin',
#    'dong',
#    'jaringannya',
#    'jangan',
#    'cuma',
#    'berani',
#    'ngasih',
#    'promo',
#    'murah']],
#  ['XL',
#   ['indosat',
#    'sinyal',
#    'nya',
#    'palang',
#    'merah',
#    'okeee',
#    'xl',
#    'lumayan',
#    'lah',
#    'ada',
#    'dikit']],
#  ['TRI', ['min']],
#  ['INDOSAT', ['membalas', 'terima', 'kasih', 'indosat']],
#  ['XL',
#   ['membalas',
#    'memang',
#    'gitu',
#    'sinyal',
#    'xl',
#    'terkadang',
#    'kencang',
#    'tiba',
#    'lambatsama',
#    'ditempat',
#    'jga',
#    'gitutapi',
#    'jgn',
#    'ganti',
#    'kartu',
#    'semuanya',
#    'sama']],
#  ['TRI',
#   ['99',
#    'jlphh',
#    'musofa',
#    'jln',
#    'suci',
#    'dpn',
#    'sma',
#    'yas',
#    'knpa',
#    'ya',
#    'skarang',
#    'sinyal',
#    'tri',
#    'edge',
#    'terus',
#    'ga',
#    'pernah',
#    'di',
#    'area',
#    'rumah',
#    'saya']],
#  ['XL',
#   ['sama',
#    'tolong',
#    'kenapa',
#    'ini',
#    'xl',
#    'di',
#    'rumah',
#    'yang',
#    'biasanya',
#    'streaming',
#    'ga',
#    'buffer',
#    'ini',
#    'buka',
#    'twitter',
#    'aja',
#    'gabisa',
#    'hadeh',
#    'kile',
#    'menambahkan']],
#  ['INDOSAT',
#   ['membalas',
#    'anjing',
#    'indosat',
#    'goblok',
#    'fakk',
#    'maen',
#    'moba',
#    'aja',
#    'leg',
#    'nya',
#    'minta',
#    'di',
#    'tampil',
#    'kontol']],
#  ['INDOSAT',
#   ['asu',
#    'jaringane',
#    'kek',
#    'tai',
#    'percuma',
#    'pket',
#    'banyak',
#    'tp',
#    'nge',
#    'lag',
#    'gbsa',
#    'ngapain',
#    'sumpah',
#    'payah',
#    'jancuk']],
#  ['INDOSAT',
#   ['membalas',
#    'dan',
#    'lainnya',
#    'iya',
#    'nih',
#    'kontol',
#    'indosat',
#    'pulsa',
#    'gua',
#    'dipotong',
#    'anjing',
#    'babi']],
#  ['TSEL',
#   ['satelit',
#    'telkomsel',
#    'meledak',
#    'pa',
#    'gimana',
#    'hng',
#    'sehunxlv',
#    'lvcruise']],
#  ['INDOSAT',
#   ['pertama',
#    'kalinya',
#    'xl',
#    'dibawa',
#    'ke',
#    'luar',
#    'rumah',
#    'signal',
#    'internetnya',
#    'bagus',
#    'bye',
#    'bye',
#    'indosat',
#    'cukup',
#    'lah',
#    'ya',
#    'bertahan',
#    'tahun']],
#  ['INDOSAT',
#   ['membalas',
#    'semua',
#    'program',
#    'infrastruktur',
#    'warisan',
#    'dari',
#    'pemerintahaan',
#    'sebelumnya',
#    'kita',
#    'tunggu',
#    'yg',
#    'murni',
#    'dari',
#    'jokowi',
#    'seperti',
#    'listrik',
#    'megawatt']],
#  ['TSEL', ['susah', 'sama', 'smpai', 'skrg', 'cuma', 'di', 'tanya']],
#  ['TSEL', ['kecewa', 'sama', 'pelayanan', 'telkomsel']],
#  ['XL', ['membalas', 'makin', 'lama', 'makin', 'jelek']],
#  ['INDOSAT',
#   ['membalas',
#    'waktu',
#    'itu',
#    'kartu',
#    'udah',
#    'hangus',
#    'karena',
#    'lupa',
#    'isi',
#    'pulsa']],
#  ['TRI',
#   ['harusnya', 'lihat', 'kualitasnya', 'dulu', 'baru', 'naikkin', 'harga']],
#  ['INDOSAT', ['halo', 'indosat']],
#  ['XL',
#   ['membalas',
#    'ini',
#    'xl',
#    'knapa',
#    'sih',
#    'gangguan',
#    'mulu',
#    'signal',
#    'ada',
#    'tapi',
#    'no',
#    'internet',
#    'connection',
#    'sampah']],
#  ['TRI',
#   ['oke',
#    'thanks',
#    'infonya',
#    'rt',
#    'informasi',
#    'paket',
#    'sms',
#    'bisa',
#    'km',
#    'cek',
#    'di']],
#  ['XL',
#   ['membalas',
#    'saya',
#    'tidak',
#    'pilih',
#    'semuanya',
#    'karena',
#    'saat',
#    'ini',
#    'jaringan',
#    'internet',
#    'xl',
#    'mbyarpet',
#    'alis',
#    'mati',
#    'hidup',
#    'plus',
#    'lelet',
#    'sangatsangatsangat',
#    'mengecewakan',
#    'kecewa',
#    'karena',
#    'sudah',
#    'terjadi',
#    'sejak',
#    'sabtu',
#    'kemarin']],
#  ['XL',
#   ['sudah',
#    'hampir',
#    'seminggu',
#    'lebih',
#    'sinyal',
#    'daerah',
#    'ku',
#    'sangat',
#    'lambat',
#    'sekali',
#    'apakah',
#    'xl',
#    'sedang',
#    'ada',
#    'ganguguan']],
#  ['INDOSAT', ['membalas', 'saya', 'akui', 'indosat', 'cukup', 'bagus']],
#  ['XL',
#   ['promosi',
#    'awak',
#    'iya',
#    'rt',
#    'pake',
#    'xl',
#    'la',
#    'hahha',
#    'punyaku',
#    'kencang',
#    'rt',
#    'udah',
#    'midnite',
#    'gini',
#    'pun',
#    'sinyal',
#    'tetep',
#    'aja',
#    'kacau']],
#  ['XL',
#   ['dibayar',
#    'berapa',
#    'nis',
#    'buat',
#    'ngeboong',
#    'ekekekke',
#    'rt',
#    'makannya',
#    'pakai',
#    'xl',
#    'sinyal',
#    'kencang',
#    'saat',
#    'anda',
#    'berada',
#    'dimana',
#    'saja',
#    'yrt']],
#  ['XL',
#   ['membalas',
#    'iki',
#    'nang',
#    'munggur',
#    'kok',
#    'mung',
#    'oleh',
#    'sinyal',
#    'mentok',
#    'bar',
#    'paketan',
#    'mahal',
#    'sinyal',
#    'busuk']],
#  ['TSEL', ['emang', 'juga', 'telkomsel', 'cacat']],
#  ['TRI',
#   ['kasih',
#    'pete',
#    'bapaknya',
#    'nih',
#    'mimin',
#    'ulang',
#    'kuis',
#    'bangkitindonesia',
#    'gimana',
#    'caranya',
#    'deketin',
#    'anak',
#    'presiden',
#    'biar',
#    'direstui']],
#  ['XL',
#   ['membalas',
#    'kno',
#    'dit',
#    'selama',
#    'masih',
#    'indonesia',
#    'jgn',
#    'harap',
#    'lebih',
#    'sama',
#    'dunia',
#    'selular']],
#  ['XL', ['sinyal', 'xl', 'di', 'bintaro', 'kurang', 'bagus', 'yaa']],
#  ['TSEL',
#   ['ini', 'jaringan', 'kenapa', 'dan', 'ilang', 'cacat', 'banget', 'koneksi']],
#  ['INDOSAT', ['membalas', 'dm', 'gue', 'gimana', 'riza', 'taek']],
#  ['INDOSAT',
#   ['paketan', 'internet', 'indosat', 'bikin', 'nangis', 'borosss', 'yawooh']],
#  ['XL', ['min']],
#  ['TRI', ['admin', 'jancok']],
#  ['TRI', ['sinyalnya', 'gawat', 'min']],
#  ['TSEL', ['tekad', 'sudah', 'bulat']],
#  ['XL',
#   ['apakah',
#    'ada',
#    'cara',
#    'situs',
#    'no',
#    'yg',
#    'bisa',
#    'diakses',
#    'untuk',
#    'mengetes',
#    'jaringan',
#    'xl',
#    'bermaksud',
#    'membeli',
#    'mifi']],
#  ['TSEL',
#   ['gak',
#    'boleh',
#    'nyebut',
#    'merk',
#    'titik',
#    'rt',
#    'internetnya',
#    'telkomsel',
#    'lemottitik']],
#  ['INDOSAT',
#   ['membalas',
#    'sudah',
#    'saya',
#    'dm',
#    'cek',
#    'segera',
#    'itu',
#    'no',
#    'hp',
#    'saya',
#    'tolong',
#    'matikan',
#    'layanan',
#    'prime',
#    'joy',
#    'yang',
#    'saya',
#    'tidak',
#    'daftar',
#    'itu',
#    'saya',
#    'tidak',
#    'terima',
#    'pulsa',
#    'saya',
#    'terpotong',
#    'tiap',
#    'bulan',
#    'hanya',
#    'demi',
#    'benefit',
#    'prime',
#    'dari',
#    'indosat',
#    'yang',
#    'sama',
#    'sekali',
#    'tidak',
#    'berguna',
#    'dan',
#    'tak',
#    'akan',
#    'saya',
#    'gunakan',
#    'thanks']],
#  ['TRI',
#   ['membalas',
#    'gambar',
#    'aku',
#    'pake',
#    'baju',
#    'perang',
#    'dengan',
#    'background',
#    'kobaran',
#    'api',
#    'sambil',
#    'bawa',
#    'bendera',
#    'hehe',
#    'bangkitindonesia']],
#  ['TSEL', ['saya', 'kecewa', 'sama', 'telkomsel', 'ketok', 'palu']],
#  ['XL',
#   ['cuaca',
#    'cerah',
#    'telah',
#    'berganti',
#    'di',
#    'siang',
#    'ini',
#    'angin',
#    'mulai',
#    'kencang',
#    'tanda',
#    'apa',
#    'ya',
#    'sinyal',
#    'xl',
#    'tetep',
#    'lantjar',
#    'jaya']],
#  ['XL',
#   ['saya',
#    'sangat',
#    'kecewa',
#    'jaringan',
#    'internet',
#    'di',
#    'daerah',
#    'saya',
#    'lemotbuka',
#    'fb',
#    'sama',
#    'vidio',
#    'fb',
#    'lemotbuat',
#    'maen',
#    'game',
#    'stabil']],
#  ['XL', ['membalas', 'yaaa', 'makanyaaa', 'aku', 'sedih']],
#  ['INDOSAT', ['selamat', 'malam']],
#  ['XL',
#   ['dulu', 'rekomen', 'soalnya', 'internetnya', 'cepet', 'dan', 'lancar']],
#  ['TRI',
#   ['membalas', 'bisa', 'dibantu', 'link', 'url', 'informasi', 'tersebut']],
#  ['INDOSAT',
#   ['gmn',
#    'dong',
#    'gue',
#    'mau',
#    'nangis',
#    'besok',
#    'tuh',
#    'gue',
#    'mau',
#    'bukber',
#    'masa',
#    'gue',
#    'bukber',
#    'dengan',
#    'gaada',
#    'kuota',
#    'anjing',
#    'bangsat',
#    'lo',
#    'indosat',
#    'tolol']],
#  ['TRI',
#   ['tlg',
#    'kalo',
#    'kasih',
#    'info',
#    'itu',
#    'yg',
#    'jujur',
#    'biar',
#    'konsumen',
#    'ga',
#    'marah',
#    'ga',
#    'kesel']],
#  ['INDOSAT',
#   ['kecewa',
#    'dg',
#    'kualitas',
#    'indosat',
#    'kuota',
#    'masih',
#    'gban',
#    'kuota',
#    'ludes',
#    'gak',
#    'jelas']],
#  ['TSEL',
#   ['haha',
#    'tapi',
#    'da',
#    'lelet',
#    'pake',
#    'telkomsel',
#    'engga',
#    'ah',
#    'udh',
#    'enak',
#    'pake',
#    'yang',
#    'ini',
#    'murah',
#    'aaaa']],
#  ['INDOSAT',
#   ['yah',
#    'hehe',
#    'pake',
#    'xl',
#    'lumayan',
#    'bagus',
#    'lho',
#    'say',
#    'rt',
#    'tapi',
#    'bb',
#    'aku',
#    'indosat',
#    'gabisa',
#    'ganti',
#    'ke',
#    'xlhhe',
#    'rt']],
#  ['TRI',
#   ['gimana',
#    'cara',
#    'ngilangin',
#    'ini',
#    'selamanya',
#    'saya',
#    'beli',
#    'kartu',
#    'baru',
#    'dan',
#    'langsung',
#    'berhasil',
#    'registrasi',
#    'tapi',
#    'notifikasi',
#    'ini',
#    'nongol',
#    'terus',
#    'ganggu',
#    'banget']],
#  ['TRI',
#   ['membalas',
#    'ga',
#    'ada',
#    'kendala',
#    'katanya',
#    'bener',
#    'tai',
#    'ni',
#    'cs',
#    'sinyal',
#    'saya',
#    'hilangan',
#    'jg',
#    'dibilang',
#    'ga',
#    'ada',
#    'kendala',
#    'dan',
#    'cs',
#    'bales',
#    'komplain',
#    'waktu',
#    'sinyalnya',
#    'membaik',
#    'ga',
#    'punya',
#    'otak',
#    'ni',
#    'cs']],
#  ['XL', ['dear']],
#  ['TRI',
#   ['selamat',
#    'pagi',
#    'mohon',
#    'informasi',
#    'untuk',
#    'upgrade',
#    'kartu',
#    'menjadi',
#    'lokasi',
#    'bekasi',
#    'gerai',
#    'tri',
#    'ada',
#    'dimana',
#    'ya']],
#  ['TRI', ['min', 'hp', 'adik', 'saya', 'hilang']],
#  ['INDOSAT',
#   ['tolong',
#    'cek',
#    'no',
#    'knp',
#    'ga',
#    'ada',
#    'balasan',
#    'dr',
#    'indosat',
#    'ya',
#    'terima',
#    'kasih',
#    'segera',
#    'ditindak',
#    'lanjuti']],
#  ['TRI', ['dm', 'ga', 'direspon']],
#  ['TSEL', ['lurd', 'cek', 'poin', 'gimana', 'yah']],
#  ['TRI', ['marah', 'dengan']],
#  ['TSEL',
#   ['baru',
#    'kali',
#    'ini',
#    'saya',
#    'kecewa',
#    'sekali',
#    'dengan',
#    'pelayanan',
#    'caroline',
#    'officer',
#    'agent',
#    'name',
#    'tari',
#    'saya',
#    'menanyakan',
#    'ttg',
#    'proses',
#    'running',
#    'paket',
#    'data',
#    'saya',
#    'kenapa',
#    'tdk',
#    'berjalan',
#    'seperti',
#    'biasanya']],
#  ['XL', ['jancuk']],
#  ['TSEL',
#   ['nabungbuatapa',
#    'buat',
#    'biaya',
#    'mengumpulin',
#    'orang',
#    'untuk',
#    'membersihkan',
#    'sampah',
#    'di',
#    'pantai']],
#  ['TSEL',
#   ['delapan',
#    'tahun',
#    'make',
#    'telkomsel',
#    'baru',
#    'kali',
#    'ini',
#    'tukar',
#    'poin']],
#  ['INDOSAT',
#   ['kenapa',
#    'ya',
#    'jaringan',
#    'indosat',
#    'belakangan',
#    'ini',
#    'suka',
#    'hilang',
#    'sinyal',
#    'lama',
#    'kelamaan',
#    'bisa',
#    'kecewa',
#    'saya',
#    'dan',
#    'lagi']],
#  ['TRI',
#   ['membalas',
#    'paling',
#    'kesel',
#    'kalo',
#    'udah',
#    'lelet',
#    'dan',
#    'bilang',
#    'tidak',
#    'ada',
#    'masalah',
#    'hahahaha',
#    'tai',
#    'memang']],
#  ['TSEL',
#   ['sinyal', 'di', 'tmpt', 'saya', 'sering', 'mati', 'udah', 'minggu', 'ini']],
#  ['XL',
#   ['membalas', 'untung', 'gw', 'ga', 'pernah', 'pakai', 'selain', 'mahal']],
#  ['TSEL',
#   ['membalas', 'telkom', '9999', 'dari', 'telkomsel', 'mantap', 'jiwa']],
#  ['INDOSAT',
#   ['membalas',
#    'indosat',
#    'juga',
#    'lagi',
#    'bermasalah',
#    'alhamdulillah',
#    'ternyata',
#    'provider',
#    'mahal',
#    'juga',
#    'bermasalah']],
#  ['INDOSAT', ['jaringan', 'indosat', 'lumayan', 'bagus']],
#  ['TSEL', ['telkomsel', 'memang', 'terbaik']],
#  ['TRI', ['min', 'saya', 'mau', 'kasih', 'saran', 'nih']],
#  ['TRI', ['sinyal', 'tri', 'ngebut', 'rt', 'wifi', 'mencret']],
#  ['INDOSAT',
#   ['maksud',
#    'nya',
#    'apa',
#    'ya',
#    'ini',
#    'karena',
#    'sistem',
#    'indosat',
#    'yang',
#    'trouble',
#    'ataukah',
#    'kesengajaan',
#    'tolong',
#    'dikembalikan',
#    'pulsa',
#    'saya',
#    'terima',
#    'ka']],
#  ['XL',
#   ['membalas',
#    'nich',
#    'provider',
#    'bangsat',
#    'isuny',
#    'cm',
#    'maling',
#    'dan',
#    'penipu',
#    'konsumen',
#    'provider',
#    'zaman',
#    'now',
#    'maling',
#    'bermodus',
#    'provider',
#    'xl',
#    'bangsat']],
#  ['TSEL', ['memang', 'macam', 'anjing', 'sinyalnya']],
#  ['TRI',
#   ['smart',
#    'juga',
#    'set',
#    'jam',
#    'download',
#    'mb',
#    'lewat',
#    'bb',
#    'rt',
#    'sinyal',
#    'tri',
#    'pagi',
#    'emang',
#    'mantap',
#    'jaya']],
#  ['TRI',
#   ['promo',
#    'sampe',
#    'kpn',
#    'nih',
#    'blackberry',
#    'berisi',
#    'voucher',
#    'blackberry',
#    'full',
#    'service',
#    'mingguan',
#    'bonus',
#    'voucher',
#    'yang',
#    'sama']],
#  ['TRI', ['membalas', 'mungkin', 'udh', 'naik']],
#  ['TRI',
#   ['gratis',
#    'kok',
#    'sms',
#    'gratis',
#    'tu',
#    'pulsa',
#    'rt',
#    'pake',
#    'tri',
#    'sms',
#    'sekali',
#    'gratis',
#    'terus',
#    'donk',
#    'seharian']],
#  ['TRI', ['laek']],
#  ['XL',
#   ['kenapa',
#    'ya',
#    'nomor',
#    'prabayar',
#    'itu',
#    'ga',
#    'bisa',
#    'diaktifkan',
#    'lagi',
#    'seperti',
#    'nomor',
#    'atau',
#    'padahal',
#    'baru',
#    'lewat',
#    'hari',
#    'dari',
#    'masa',
#    'tenggangdipaksa',
#    'pindah',
#    'ke',
#    'pascabayarsistem',
#    'yang',
#    'jadul',
#    'atau',
#    'karena',
#    'merasa',
#    'provider',
#    'paling',
#    'besar']],
#  ['INDOSAT',
#   ['terluka',
#    'yang',
#    'baru',
#    'dipecat',
#    'maupinjemuang',
#    'eagkbisa',
#    'mau',
#    'ngutang',
#    'enggak',
#    'dikasih',
#    'boikotindosat',
#    'atau',
#    'nangis',
#    'ilcmembidikhabibrizieq']],
#  ['INDOSAT', ['rt', 'lurd', 'urgent']],
#  ['INDOSAT', ['ucweb', 'indosat', 'mantap', 'bisa', 'new', 'tab', 'norak']],
#  ['INDOSAT', ['hallo', 'indosat', 'yang', 'baik', 'hati']],
#  ['TSEL', ['telkomsel', 'absen', 'pesta', 'rbt']],
#  ['TRI', ['min']],
#  ['TSEL',
#   ['membalas',
#    'telkomsel',
#    'murah',
#    'jg',
#    'jok',
#    'rt',
#    'gedor',
#    'be',
#    'rt',
#    'belum',
#    'dtng',
#    'dy',
#    'rt',
#    'duku',
#    'jg',
#    'enak',
#    'rt',
#    'lewat',
#    'jendelo']],
#  ['TSEL',
#   ['jancok',
#    'banget',
#    'ni',
#    'kartu',
#    'saya',
#    'udah',
#    'maketin',
#    'paket',
#    'flash',
#    'eh',
#    'tapi',
#    'pulsa',
#    'tetep',
#    'kepotong']],
#  ['INDOSAT',
#   ['dunia',
#    'harus',
#    'tau',
#    'kalo',
#    'skrng',
#    'di',
#    'rumahku',
#    'udah',
#    'ada',
#    'sinyal',
#    'indosat',
#    'alhamdulillah',
#    'packet',
#    'yellowku',
#    'wkwk']],
#  ['INDOSAT',
#   ['tolong',
#    'informasinya',
#    'segera',
#    'saya',
#    'belum',
#    'pernah',
#    'ikut',
#    'paypro']],
#  ['XL', ['sini', 'kok', 'sinyal', 'xl', 'kencang', 'aneh']],
#  ['INDOSAT',
#   ['sipooo',
#    'rt',
#    'oke',
#    'makasih',
#    'glo',
#    'rt',
#    'theodoregloria',
#    'lumayan',
#    'rt',
#    'eh',
#    'yang',
#    'indosat',
#    'sinyalnya',
#    'bagus',
#    'gak']],
#  ['TRI', ['better', 'upload', 'service']],
#  ['TRI', ['buat', 'kaum', 'jomblo']],
#  ['INDOSAT',
#   ['indosat',
#    'jan',
#    'bulsit',
#    'di',
#    'paketke',
#    'kok',
#    'sik',
#    'kenggo',
#    'pulsa',
#    'pokok',
#    'paketane',
#    'wutuh',
#    'asu',
#    'asu']],
#  ['TSEL',
#   ['membalas',
#    'yeee',
#    'terbukaaa',
#    'terima',
#    'kasih',
#    'engkau',
#    'memang',
#    'pelayanan',
#    'terbaik']],
#  ['INDOSAT',
#   ['asu',
#    'tnan',
#    'seng',
#    'jupuk',
#    'hp',
#    'qw',
#    'ch',
#    'lek',
#    'pnteng',
#    'mzo',
#    'nek',
#    'kne',
#    '9',
#    'sng',
#    'qw',
#    'indosat',
#    'ilang']],
#  ['TSEL', ['iya']],
#  ['XL',
#   ['pakai',
#    'xl',
#    'dijamin',
#    'cepat',
#    'dan',
#    'sinyal',
#    'kuat',
#    'haya',
#    'iklan',
#    'hahaha',
#    'rt',
#    'bbm',
#    'masih',
#    'aja',
#    'pendingzzzzzzz']],
#  ['INDOSAT',
#   ['indosat',
#    'jancok',
#    'kaya',
#    'gini',
#    'masih',
#    'gak',
#    'cukup',
#    'pulsanya',
#    'jancok']],
#  ['TRI',
#   ['membalas',
#    'tolong',
#    'beri',
#    'informasi',
#    'yg',
#    'jelas',
#    'tentang',
#    'gangguan',
#    'nya']],
#  ['INDOSAT',
#   ['membalas', 'kemrin', 'waktu', 'ke', 'pantai', 'parangtritis', 'jogja']],
#  ['TSEL',
#   ['membalas',
#    'saya',
#    'mau',
#    'regis',
#    'tapi',
#    'nik',
#    'tidak',
#    'ditemukan',
#    'gimana',
#    'tuh',
#    'min']],
#  ['TRI',
#   ['tolong',
#    'ya',
#    'perhatikan',
#    'dengan',
#    'baik',
#    'no',
#    'hp',
#    'yang',
#    'bermasalah',
#    'adalah',
#    '999']],
#  ['INDOSAT', ['membalas', 'hai', 'kak']],
#  ['TSEL', ['membalas', 'terimakasih', 'kami', 'sangat', 'puas']],
#  ['INDOSAT',
#   ['indosat',
#    'lg',
#    'ada',
#    'masalah',
#    'ya',
#    'min',
#    'nomor',
#    'saya',
#    'tidak',
#    'bisa',
#    'terima',
#    'sms',
#    'masuk',
#    'dan',
#    'harus',
#    'di',
#    'copot',
#    'simcardnya',
#    'dulu',
#    'baru',
#    'smsnya',
#    'masuk',
#    'tolong',
#    'di',
#    'cek']],
#  ['XL',
#   ['udah',
#    'hari',
#    'masih',
#    'juga',
#    'gangguan',
#    'ini',
#    'xl',
#    'ga',
#    'mendengarkan',
#    'keluhan',
#    'pelanggannya',
#    'ya',
#    'kayanya',
#    'udh',
#    'banyak',
#    'yg',
#    'ngadu',
#    'tpi',
#    'kok',
#    'ga',
#    'lebih',
#    'baik',
#    'udah',
#    'berkali',
#    'kali',
#    'reset',
#    'signal']],
#  ['TSEL',
#   ['hash',
#    'rt',
#    'pake',
#    'xl',
#    'dongga',
#    'pernah',
#    'bs',
#    'belaajar',
#    'rt',
#    'telkomsel',
#    'jancok',
#    'hari',
#    'ini',
#    'gsm',
#    'mulu']],
#  ['INDOSAT',
#   ['membalas',
#    'bnr',
#    'ngak',
#    'diperhatiin',
#    'kualitas',
#    'isat',
#    'bb',
#    'sibuk',
#    'promo',
#    'trus',
#    'tp',
#    'kualitas',
#    'sinyal',
#    'ancurrr',
#    'kecewa',
#    'bneran',
#    'dh',
#    'pelayanan',
#    'indosat']],
#  ['XL', ['provider', 'bangsat', 'xl', 'isiny', 'cm', 'maling']],
#  ['TRI',
#   ['ini', 'kenapa', 'koneksi', 'nya', 'tai', 'banget', 'dari', 'siang']],
#  ['TRI',
#   ['membalas',
#    'masih',
#    'gaada',
#    'tindak',
#    'lanjut',
#    'udah',
#    'hari',
#    'jaringan',
#    'hilang',
#    'percuma',
#    'kuota',
#    'dikasih',
#    'harga',
#    'murah',
#    'kalo',
#    'pelayanan',
#    'terutama',
#    'kepada',
#    'keluhan',
#    'konsumen',
#    'masih',
#    'kek',
#    'tai']],
#  ['TRI', ['baji', 'gau', 'melulu']],
#  ['TRI', ['hai']],
#  ['TSEL',
#   ['mudah',
#    'mudahan',
#    'bisa',
#    'lebih',
#    'baik',
#    'dlm',
#    'pelayanan',
#    'pelanggan',
#    'krn',
#    'terus',
#    'terang',
#    'urusan',
#    'sinyal',
#    'dan',
#    'coverage',
#    'saya',
#    'sangat',
#    'puas',
#    'dg',
#    'telkomsel']],
#  ['INDOSAT',
#   ['lumayan',
#    'bagus',
#    'wan',
#    'rt',
#    'rekomendasi',
#    'dong',
#    'jaringan',
#    'indosat',
#    'khususnya',
#    'im',
#    'bagus',
#    'ga',
#    'sih']],
#  ['INDOSAT',
#   ['halo',
#    'indosat',
#    'ada',
#    'pengaturan',
#    'yang',
#    'cocok',
#    'gk',
#    'buat',
#    'hp',
#    'advan',
#    'ic']],
#  ['TSEL',
#   ['pakai',
#    'telkomsel',
#    'itu',
#    'enak',
#    'yaa',
#    'gak',
#    'pernah',
#    'pending',
#    'kalau',
#    'bbman',
#    'terus',
#    'kalau',
#    'telfonan',
#    'sama',
#    'smsan',
#    'murah',
#    'banget']],
#  ['TSEL',
#   ['ak',
#    'wes',
#    'onok',
#    'telkomsel',
#    'tp',
#    'halo',
#    'ran',
#    'rt',
#    'ganti',
#    'simpati',
#    'wes',
#    'rt',
#    'jancok']],
#  ['XL',
#   ['nyalahin',
#    'customer',
#    'belum',
#    'regist',
#    'padahal',
#    'udah',
#    'regis',
#    'kok',
#    'sampah',
#    'ya',
#    'anda',
#    'problemnya',
#    'ada',
#    'di',
#    'anda',
#    'bagian',
#    'it',
#    'anda',
#    'yang',
#    'tidak',
#    'becus']],
#  ['TRI', ['jaringan', 'cacat']],
#  ['XL', ['jaringan', 'nya', 'cacat', 'payah', 'lah']],
#  ['XL', ['thanks', 'xl', 'download', 'apapun', 'sangat', 'cepat']],
#  ['INDOSAT',
#   ['untuk',
#    'yg',
#    'kesekian',
#    'kalinya',
#    'pulsa',
#    'saya',
#    'hilang',
#    'tiba',
#    'tiba',
#    'pulsa',
#    'tinggal',
#    'mantap',
#    'indosat',
#    'diem',
#    'diem',
#    'mencuri']],
#  ['TRI',
#   ['dear',
#    'sampai',
#    'sekarang',
#    'belum',
#    'ada',
#    'jawaban',
#    'dr',
#    'keluhan',
#    'saya']],
#  ['XL', ['tumben', 'sinyal', 'xl', 'bagus']],
#  ['TSEL',
#   ['mau',
#    'sampai',
#    'kapan',
#    'gangguan',
#    'sinyal',
#    'begini',
#    'semingguan',
#    'tidak',
#    'bisa',
#    'dipakai',
#    'buat',
#    'main',
#    'mobile',
#    'legends',
#    'saya',
#    'kecewa',
#    'beneran']],
#  ['XL',
#   ['ni',
#    'laptop',
#    'koneksinya',
#    'malah',
#    'dari',
#    'tethering',
#    'wifi',
#    'hape',
#    'cino',
#    'pake',
#    'xl',
#    'lumayan',
#    'ngebut',
#    'juga']],
#  ['XL',
#   ['fix',
#    'ganti',
#    'kartu',
#    'sudah',
#    'capek',
#    'dengan',
#    'xl',
#    'keluhan',
#    'gak',
#    'ditanggapi',
#    'sekali',
#    'ditanggapi',
#    'jawabannya',
#    'ngelantur',
#    'cc']],
#  ['XL',
#   ['mau', 'tahu', 'tips', 'agar', 'cod', 'kamu', 'lancar', 'jawabannya']],
#  ['TSEL',
#   ['penekanan',
#    'pertama',
#    'ad',
#    'di',
#    'kata',
#    'murah',
#    'rt',
#    'indosat',
#    'dganti',
#    'opo',
#    'enak',
#    'telkomsel']],
#  ['XL',
#   ['sampah', 'banget', 'koneksi', 'internet', 'xl', 'ini', 'bah', 'sampah']],
#  ['INDOSAT',
#   ['tanggapan',
#    'dari',
#    'cs',
#    'indosat',
#    'cukup',
#    'bagus',
#    'lah',
#    'menurut',
#    'saya']],
#  ['TSEL',
#   ['membalas',
#    'owh',
#    'itu',
#    'aj',
#    'ya',
#    'oh',
#    'ya',
#    'makasih',
#    'ya',
#    'paket',
#    'tau',
#    'nya',
#    'udh',
#    'ak',
#    'pake',
#    'itu',
#    'dan',
#    'ak',
#    'merasa',
#    'sangat',
#    'puas',
#    'semga',
#    'pket',
#    'tau',
#    'di',
#    'adakn',
#    'lg']],
#  ['INDOSAT',
#   ['tolong',
#    'baca',
#    'dm',
#    'saya',
#    'saya',
#    'urgent',
#    'perlu',
#    'bantuan',
#    'nomor',
#    'indosat',
#    'saya',
#    'sdh',
#    'tdk',
#    'aktif',
#    'berhari',
#    'hari',
#    'terima',
#    'kasih']],
#  ['XL', ['sampahudh', 'hari', 'sinyal', 'leleeeeeet']],
#  ['TRI',
#   ['gak',
#    'bakalan',
#    'kolaborasi',
#    'sama',
#    'nih',
#    'soalnya',
#    'sinyal',
#    'kalian',
#    'sama',
#    'sama',
#    'bapuk',
#    'dan',
#    'selalu',
#    'tidak',
#    'respon',
#    'keluhan',
#    'konsumen']],
#  ['INDOSAT', ['jadi']],
#  ['INDOSAT', ['mantap', 'pake', 'indosat', 'nih']],
#  ['TSEL',
#   ['tp',
#    'katae',
#    'plng',
#    'enak',
#    'telkomsel',
#    'rt',
#    'podo',
#    'ae',
#    'se',
#    'jatuhe',
#    'kabehrt',
#    'lek',
#    'paketan',
#    'iku',
#    'murah',
#    'endi']],
#  ['TSEL', ['membalas', 'baik']],
#  ['TRI',
#   ['apa',
#    'sih',
#    'benefit',
#    'yg',
#    'kita',
#    'terima',
#    'sbg',
#    'pelanggan',
#    'postpaid',
#    'krn',
#    'hampir',
#    'thn',
#    'ga',
#    'dpt',
#    'bonus',
#    'apa']],
#  ['INDOSAT',
#   ['membalas',
#    'mungkin',
#    'sekitar',
#    'tahun',
#    'aku',
#    'pake',
#    'provider',
#    'indosat',
#    'sejauh',
#    'ini',
#    'cukup',
#    'puas']],
#  ['TRI',
#   ['knapa',
#    'sinyal',
#    'gnya',
#    'main',
#    'yah',
#    'informasi',
#    'detail',
#    'mengenai',
#    'aon',
#    'cek',
#    'ke']],
#  ['TSEL', ['em', 'btw', 'ini', 'konek', 'pake', 'ya']],
#  ['TRI',
#   ['woy',
#    'bangsat',
#    'anjing',
#    'ngentot',
#    'babi',
#    'kontol',
#    'memek',
#    'lu',
#    'lelet',
#    'tai',
#    'anjing',
#    'mahal',
#    'sering',
#    'di',
#    'lletin',
#    'lagi',
#    'ahh',
#    'ngentot',
#    'awas',
#    'lu',
#    'ya']],
#  ['XL', ['membalas', 'hai', 'krisnantyo']],
#  ['TRI', ['kukud', 'ja', 'banyak', 'keluhan', 'tp', 'gak', 'di', 'tanggapi']],
#  ['XL',
#   ['slamat',
#    'datang',
#    'di',
#    'manokwari',
#    'sinyal',
#    'xl',
#    'lumayan',
#    'bangetlah',
#    'rasa',
#    'kok',
#    'hehe',
#    'ga',
#    'lost',
#    'sinyal',
#    'kyk',
#    'sebelah',
#    'yuk',
#    'eksplor',
#    'papua',
#    'barat']],
#  ['TRI',
#   ['batang',
#    'jak',
#    'agik',
#    'pelosok',
#    'sinyal',
#    'tri',
#    'mantap',
#    'batang',
#    'jak']],
#  ['TSEL',
#   ['sms',
#    'blast',
#    'telkomsel',
#    'sampah',
#    'banget',
#    'isinya',
#    'udah',
#    'bayar',
#    'pulsa',
#    'tetep',
#    'aja',
#    'di',
#    'blast',
#    'unethical']],
#  ['TRI', ['keluhan', 'gua', 'berharu', 'hari', 'gak', 'di', 'tanggapin']],
#  ['TSEL',
#   ['jaringan', 'bb', 'telkomsel', 'napa', 'ilang', 'mulu', 'lemot', 'cuy']],
#  ['TSEL',
#   ['kaksinyal',
#    'di',
#    'daerah',
#    'saya',
#    'kok',
#    'sekarang',
#    'jelek',
#    'sejak',
#    'ada',
#    'sinyal',
#    'ghp',
#    'ahrus',
#    'di',
#    'lock',
#    'agar',
#    'dapt',
#    'sinyal',
#    'gkalo',
#    'gak',
#    'di',
#    'lock',
#    'cuma',
#    'dpt',
#    'sinyal',
#    'dan',
#    'itu',
#    'lemotbantuannya',
#    'kak']],
#  ['TRI',
#   ['membalas',
#    'nomor',
#    'lama',
#    'juga',
#    'dong',
#    'udah',
#    'pake',
#    'tri',
#    'tahun',
#    'pas',
#    'registrasi',
#    'ulang',
#    'gak',
#    'dapet',
#    'hadiah',
#    'apapun']],
#  ['TRI', ['siang']],
#  ['XL', ['karena', 'pasca', 'bayar', 'xl', 'sudah', 'lambat']],
#  ['TRI',
#   ['goblog',
#    'jaringan',
#    'lu',
#    'udah',
#    'sebulan',
#    'lebih',
#    'ngga',
#    'bener',
#    'jgn',
#    'cm',
#    'ngiklan',
#    'doangpikirin',
#    'konsumen']],
#  ['XL',
#   ['tolong',
#    'sekali',
#    'lagi',
#    'saya',
#    'minta',
#    'tanggung',
#    'jawabnya',
#    'yaa',
#    'saya',
#    'tertarik',
#    'beli']],
#  ['TSEL',
#   ['pada',
#    'heboh',
#    'paket',
#    'bis',
#    'namun',
#    'telkomsel',
#    'tetap',
#    'juaranyamurah',
#    'koq',
#    'njaluk',
#    'enak']],
#  ['INDOSAT',
#   ['ya',
#    'beli',
#    'aja',
#    'perdananya',
#    'murah',
#    'iniaxis',
#    'lumayan',
#    'bagus',
#    'kokasal',
#    'jangan',
#    'kedap',
#    'udara',
#    'ajaheheperminggu',
#    'rb']],
#  ['TSEL',
#   ['lagi',
#    'lagi',
#    'tcash',
#    'telkomsel',
#    'mesin',
#    'edc',
#    'nya',
#    'error',
#    'kedua',
#    'kali',
#    'nya',
#    'di',
#    'centre',
#    'point',
#    'medan',
#    'ckckck',
#    'kecewa',
#    'bngt']],
#  ['TSEL', ['mohon', 'bantuan', 'puk', 'untuk', 'nomor', 'terimakasih']],
#  ['INDOSAT',
#   ['satu',
#    'kata',
#    'telkomsel',
#    'browsing',
#    'cepet',
#    'rt',
#    'indosat',
#    'sialaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaannnnn']],
#  ['TRI',
#   ['membalas',
#    'kemarin',
#    'lusa',
#    'sy',
#    'beli',
#    'paket',
#    'gb',
#    'gb',
#    'gb',
#    'rb',
#    'setelah',
#    'habis',
#    'lalu',
#    'sy',
#    'beli',
#    'yg',
#    'gb']],
#  ['TRI', ['membalas', 'di', 'selamatin', 'doang']],
#  ['XL',
#   ['dear',
#    'kenapa',
#    'jaringanya',
#    'selalu',
#    'gangguan',
#    'jadi',
#    'ga',
#    'berguna',
#    'baru',
#    'beli',
#    'kartu',
#    'perdana',
#    'yang',
#    'gb',
#    'tapi',
#    'gakepake',
#    'sama',
#    'sekali',
#    'gara',
#    'jaringanya',
#    'lemot',
#    'jelekkk',
#    'parahh',
#    'banget',
#    'asli']],
#  ['TSEL',
#   ['sebagai',
#    'konsumen',
#    'saya',
#    'sangat',
#    'kecewa',
#    'dengan',
#    'iklan',
#    'ini',
#    'kemana',
#    'saya',
#    'harus',
#    'mengadu']],
#  ['XL',
#   ['semoga',
#    'xl',
#    'xlalu',
#    'menghadirkan',
#    'pelayanan',
#    'terbaik',
#    'dan',
#    'super',
#    'cepat',
#    'utk',
#    'pelanggan',
#    'setianya',
#    'jaringanxtrasuka']],
#  ['TRI', ['semangat', 'dong']],
#  ['TSEL', ['dear', 'kenapa', 'kalo', 'saya', 'nonton', 'film', 'dari', 'viu']],
#  ['INDOSAT', ['malam', 'nomor', 'saya', 'sudah', 'tidak', 'aktif', 'sejak']],
#  ['TSEL',
#   ['seneng',
#    'banget',
#    'arsenal',
#    'jadi',
#    'ke',
#    'indonesia',
#    '`',
#    'ada',
#    'promo',
#    'khusus',
#    'pelanggan',
#    'telkomsel',
#    'lagi',
#    '`',
#    'jingkrakjingkrak']],
#  ['TSEL', ['sinyal', 'bagus', 'ko', 'tapi', 'lemot', 'yah']],
#  ['XL', ['buat', 'yang', 'senang', 'pelajaran', 'fisika', 'atau', 'kimia']],
#  ['XL',
#   ['xl',
#    'sama',
#    'axis',
#    'itu',
#    'beda',
#    'jauh',
#    'axis',
#    'cm',
#    'rb',
#    'full',
#    'service',
#    'sinyal',
#    'bagus',
#    'sedangkan',
#    'xl',
#    '9rb',
#    'full',
#    'service',
#    'tpi',
#    'sama',
#    'aja',
#    'kyk',
#    'ga',
#    'pake',
#    'paket',
#    'full',
#    'servc']],
#  ['TRI',
#   ['rt',
#    'terima',
#    'kasih',
#    'semua',
#    'yg',
#    'sudah',
#    'kasih',
#    'info',
#    'ttg',
#    'provider',
#    'tri',
#    'kesimpulannya']],
#  ['TRI',
#   ['membalas',
#    'saya',
#    'langganan',
#    'paket',
#    'tri',
#    'gb',
#    'sebulan',
#    'cuma',
#    'ribu']],
#  ['XL',
#   ['membalas',
#    'banyak',
#    'gangguannya',
#    'dah',
#    'gitu',
#    'slow',
#    'respon',
#    'lagi',
#    'hadeeeh',
#    'nyesel',
#    'dah',
#    'ini',
#    'beli',
#    'perdana',
#    'malah',
#    'mahal',
#    'lagi']],
#  ['XL',
#   ['bikin',
#    'boros',
#    'batere',
#    'bro',
#    'rt',
#    'disini',
#    'hspa',
#    'mas',
#    'hihi',
#    'rt',
#    'sinyal',
#    'hsdpa',
#    'xl',
#    'joss',
#    'gandos',
#    'men']],
#  ['TRI', ['tri', 'gaada', 'sinyal', 'mantap', 'yah']],
#  ['INDOSAT', ['membalas', 'itu', 'smartfreen']],
#  ['INDOSAT', ['sore', 'min']],
#  ['TSEL', ['rekan', 'mohon', 'bantuan', 'respon', 'dm', 'tks']],
#  ['INDOSAT', ['sampah', 'indosat', 'minyat', 'we', 'ah', 'aja', 'ke']],
#  ['INDOSAT',
#   ['butuh',
#    'trik',
#    'perpanjang',
#    'masa',
#    'aktif',
#    'indosat',
#    'moso',
#    'tp',
#    'ewuminim',
#    'masa',
#    'aktif',
#    '9',
#    'hari',
#    'nangis',
#    'nangis']],
#  ['XL',
#   ['musti',
#    'banyak',
#    'sabar',
#    'ngadepin',
#    'xl',
#    'ini',
#    'yaa',
#    'udah',
#    'banyak',
#    'keluhan',
#    'dari',
#    'pelanggan',
#    'klen',
#    'tolong',
#    'bagusinlaah',
#    'bodaat']],
#  ['TRI', ['mas', 'sinyal', 'nya', 'kyk', 'tai', 'kucing', 'mas']],
#  ['TRI', ['bangsat', 'nih']],
#  ['INDOSAT', ['streaming', 'putus', 'ni', 'wooeee']],
#  ['XL',
#   ['ceritanya',
#    'tadi',
#    'mau',
#    'nanya',
#    'kenapa',
#    'minggu',
#    'ini',
#    'xl',
#    'ilang',
#    'di',
#    'hp']],
#  ['INDOSAT', ['membalas', 'dah', 'pasrahin', 'aja']],
#  ['XL',
#   ['sinyal',
#    'xl',
#    'dirumah',
#    'gue',
#    'bagus',
#    'deh',
#    'sampe',
#    'pengen',
#    'demo',
#    'saking',
#    'sinyalnya',
#    'bagus']],
#  ['INDOSAT',
#   ['membalas',
#    'rp',
#    'gb',
#    'how',
#    'dare',
#    'are',
#    'you',
#    'btw',
#    'koq',
#    'tau',
#    'aku',
#    'pake',
#    'paket',
#    'rakyat',
#    'jelantah',
#    'hahaha',
#    'hati',
#    'hati',
#    'paket',
#    'yellow',
#    'habis',
#    'kuota',
#    'atau',
#    'habis',
#    'waktu',
#    'pulsa',
#    'reguler',
#    'akan',
#    'dihajar',
#    'habis',
#    'dalam',
#    'satu',
#    'kerdipan',
#    'mata',
#    'papa',
#    'memang',
#    'jahat',
#    'jawab',
#    'indosat',
#    'murah',
#    'mau',
#    'selamat']],
#  ['TRI',
#   ['beberapa', 'orang', 'ngetwit', 'galau', 'biar', 'dapat', 'simpati']],
#  ['TRI',
#   ['haha',
#    'sinyal',
#    'kuat',
#    'ege',
#    'rt',
#    'pea',
#    '_',
#    'rt',
#    'kartu',
#    'kredit']],
#  ['TRI',
#   ['ehh',
#    'bangsat',
#    'perasaan',
#    'gw',
#    'beli',
#    'paket',
#    'kuota',
#    'yg',
#    'reguler',
#    'internet',
#    'knp',
#    'gw',
#    'kudu',
#    'jadi',
#    'pindahin',
#    'mode',
#    'en',
#    'sebaliknya',
#    'terus',
#    'kek']],
#  ['XL',
#   ['lancar',
#    'menterjemahkan',
#    'semua',
#    'jurnal',
#    'berbahasa',
#    'inggris',
#    'dengan',
#    'cepat',
#    'tinggal',
#    'jurnal',
#    'lagi',
#    'thanks',
#    'xl']],
#  ['XL', ['membalas', 'maaf']],
#  ['TRI',
#   ['knp',
#    'signal',
#    'tri',
#    'di',
#    'cikarang',
#    'utara',
#    'bikin',
#    'marahlemottttt',
#    'bgt',
#    'signal',
#    'sering']],
#  ['INDOSAT', ['indosat', 'sinyalnya', 'bikin', 'pengen', 'nangis']],
#  ['XL',
#   ['game',
#    'keren',
#    'yang',
#    'bisa',
#    'kamu',
#    'dapetin',
#    'dengan',
#    'gratis',
#    'adalah',
#    'batman',
#    'arkham',
#    'origins',
#    'pengguna',
#    'android',
#    'pasti',
#    'senang',
#    'banget',
#    'nih',
#    'xlgames']],
#  ['XL',
#   ['dimana', 'saya', 'bisa', 'menyampaikan', 'keluhan', 'terkait', 'xl']],
#  ['XL',
#   ['halo',
#    'mengap',
#    'sinyal',
#    'xl',
#    'di',
#    'tempat',
#    'saya',
#    'jadi',
#    'lemot',
#    'tiba']],
#  ['TSEL',
#   ['sangat',
#    'puas',
#    'dengan',
#    'layanan',
#    'call',
#    'center',
#    'telkomsel',
#    'we',
#    'love',
#    'telkomsel']],
#  ['TRI',
#   ['kok',
#    'semenjak',
#    'aku',
#    'ganti',
#    'im',
#    'kamu',
#    'gak',
#    'pernah',
#    'sms',
#    'aku',
#    'lagi',
#    'kamu',
#    'marah',
#    'ya']],
#  ['INDOSAT',
#   ['membalas',
#    'duh',
#    'mahal',
#    'ya',
#    'indosat',
#    'donk',
#    'murah',
#    'gb',
#    'rb',
#    'hr',
#    'jam',
#    'paket',
#    'yellow']],
#  ['TRI',
#   ['koneksi',
#    'parah',
#    'gk',
#    'ada',
#    'perkembangan',
#    'percuma',
#    'lapor',
#    'kayak',
#    'tai']],
#  ['XL',
#   ['kuat',
#    'dan',
#    'kencang',
#    'rt',
#    'kuat',
#    'po',
#    'kencang',
#    'kan',
#    'pake',
#    'xl']],
#  ['TSEL',
#   ['telkomsel',
#    'xl',
#    'tahik',
#    'banget',
#    'cepet',
#    'abis',
#    'mana',
#    'mahal',
#    'lagi',
#    'pingin',
#    'ganti',
#    'yang',
#    'murah',
#    'sama',
#    'enak',
#    'buat',
#    'paketan',
#    'android',
#    'ada',
#    'saran']],
#  ['TRI',
#   ['ka',
#    'kartu',
#    'sim',
#    'saya',
#    'ke',
#    'blokir',
#    'karna',
#    'abis',
#    'masa',
#    'tenggang']],
#  ['INDOSAT',
#   ['astagfirulloh',
#    'nangis',
#    'gua',
#    'indosat',
#    'dirumah',
#    'gua',
#    'gini',
#    'amat',
#    'sih']],
#  ['TSEL', ['mosok', 'hahahad', 'rt', 'telkomsel', 'jancok']],
#  ['TRI',
#   ['membalas',
#    'tolong',
#    'secepatnya',
#    'keluhan',
#    'pelanggan',
#    'tri',
#    'di',
#    'tanggapi']],
#  ['XL',
#   ['ini',
#    'xl',
#    'lagi',
#    'kenapa',
#    'si',
#    'gak',
#    'jelas',
#    'bgt',
#    'koneksinya',
#    'dari',
#    'tadi',
#    'sampah']],
#  ['INDOSAT',
#   ['mantap',
#    '9',
#    'tahun',
#    'indosat',
#    'ooredoo',
#    'imsemaranginner',
#    'indosatooredoo9smg']],
#  ['INDOSAT',
#   ['ping',
#    'kegedean',
#    'asu',
#    'ngeleg',
#    'mulu',
#    'lemot',
#    'mulu',
#    'kapan',
#    'majunya',
#    'indosat',
#    'malah',
#    'semakin',
#    'blangsak',
#    'aja',
#    'tolo',
#    'dasar']],
#  ['TSEL',
#   ['murah',
#    'tau',
#    'sama',
#    'aja',
#    'na',
#    'rt',
#    'muaaaahal',
#    'rt',
#    'ganti',
#    'telkomsel',
#    'aje',
#    'rt',
#    'enak',
#    'si',
#    'sms',
#    'sama',
#    'telfonnya',
#    'gratis',
#    'tp']],
#  ['TSEL',
#   ['kenapa',
#    'cacat',
#    'banget',
#    'sih',
#    'tiap',
#    'jam',
#    'malem',
#    'selalu',
#    'ubah',
#    'jaringan',
#    'udah',
#    'paketan',
#    'mahal']],
#  ['XL', ['kecewa', 'pake', 'xl']],
#  ['XL',
#   ['saya',
#    'kecewa',
#    'dan',
#    'kesal',
#    'dengan',
#    'jaringan',
#    'xl',
#    'yg',
#    'trouble',
#    'dalam',
#    'minggu',
#    'ini',
#    'terutama',
#    'wilayah',
#    'sumbar',
#    'saya',
#    'kesal',
#    'karena',
#    'tidak',
#    'ada',
#    'pemberitahuan',
#    'trouble',
#    'dan',
#    'lanjutan',
#    'kekesalab',
#    'saya',
#    'ketika',
#    'lgi',
#    'asik',
#    'gaming',
#    'eh',
#    'jaringan',
#    'ilang',
#    'ujung',
#    'saya',
#    'dianggap',
#    'afk']],
#  ['INDOSAT',
#   ['hallo',
#    'kenapa',
#    'indosat',
#    'klo',
#    'sms',
#    'statusnya',
#    'tertunda',
#    'semua',
#    'gak',
#    'bisa',
#    'terima',
#    'sms',
#    'juga',
#    'tolong',
#    'bantuannya']],
#  ['TRI',
#   ['gara',
#    'lu',
#    'quiz',
#    'kuliah',
#    'gw',
#    'jadi',
#    'skip',
#    'jing',
#    'bangsat',
#    'kalah',
#    'esia',
#    'nge',
#    'lagnya',
#    'tolol',
#    'anjing',
#    'bangkrut',
#    'lo',
#    'jing']],
#  ['INDOSAT',
#   ['dear', 'kok', 'sinyal', 'indosat', 'gue', 'suka', 'ilangan', 'gini']],
#  ['INDOSAT',
#   ['membalas',
#    'to',
#    'the',
#    'point',
#    'saja',
#    'pak',
#    'inilah',
#    'sebagian',
#    'rakyat',
#    'indonesia',
#    'itu',
#    'cepat',
#    'lupa']],
#  ['XL',
#   ['males',
#    'kali',
#    'baca',
#    'email',
#    'yg',
#    'signature',
#    'nya',
#    'kek',
#    'gini',
#    'sent',
#    'from',
#    'my',
#    'blackberry',
#    'smartphone',
#    'from',
#    'sinyal',
#    'bagus',
#    'xl']],
#  ['XL',
#   ['membalas',
#    'trnyata',
#    'klo',
#    'vip',
#    'sinyal',
#    'xl',
#    'yg',
#    'jossklo',
#    'timur',
#    'telkomsel',
#    'yg',
#    'buosok']],
#  ['INDOSAT', ['jangkauan', 'di', 'bogor', 'masih', 'terbatas']],
#  ['TSEL',
#   ['membalas',
#    'terima',
#    'kasih',
#    'sudah',
#    'menunggu',
#    'mohon',
#    'kamu',
#    'coba',
#    'kembali',
#    'sekarang',
#    'jika',
#    'masih',
#    'terkendala',
#    'tolong',
#    'kirimkan',
#    'screenshoot',
#    'sms',
#    'nya',
#    'ke',
#    'kami',
#    'nanti',
#    'kami',
#    'akan',
#    'mengecek',
#    'lebih',
#    'lanjut']],
#  ['TRI', ['terima', 'kasih', 'atas', 'bonus', 'mb', 'nya']],
#  ['TRI',
#   ['kalo',
#    'mau',
#    'jadi',
#    'csc',
#    'gimana',
#    'pengen',
#    'ngelayanin',
#    'pengguna',
#    'tri',
#    'dengan',
#    'jadi',
#    'csc',
#    'kalo',
#    'ada',
#    'infonya']],
#  ['XL',
#   ['mau',
#    'ngerasain',
#    'internetan',
#    'cepat',
#    'dan',
#    'stabil',
#    'tapi',
#    'belum',
#    'pake',
#    'xl',
#    'dateng',
#    'ke',
#    'xl',
#    'center',
#    'jabo',
#    'hari',
#    'ini',
#    'xlappreciationday']],
#  ['XL', ['membalas', 'tai', 'xl', 'anjing']],
#  ['INDOSAT', ['ktika', 'sy', 'smp', 'kls', 'dulu']],
#  ['INDOSAT',
#   ['membalas',
#    'tergantung',
#    'lokasi',
#    'gan',
#    'kalo',
#    'sinyal',
#    'indosat',
#    'disana',
#    'bagus',
#    'kecepatan',
#    'lumayan']],
#  ['TSEL',
#   ['enak',
#    'axis',
#    'iki',
#    'lo',
#    'murah',
#    'banter',
#    'hahahahaah',
#    'rt',
#    'oyowahhenak',
#    'ta',
#    'nganggo',
#    'telkomselm',
#    'iki',
#    'yo',
#    'bedes']],
#  ['INDOSAT', ['selamat', 'beristirahat']],
#  ['XL',
#   ['membalas',
#    'provider',
#    'anjing',
#    'xl',
#    'isiny',
#    'cm',
#    'maling',
#    'dan',
#    'penipu',
#    'konsumen',
#    'tai',
#    'xl',
#    'kampret']],
#  ['XL',
#   ['adaw',
#    'rt',
#    'iya',
#    'ya',
#    'seperti',
#    'hati',
#    'ku',
#    'kepada',
#    'mu',
#    'asik',
#    'asik',
#    'joss',
#    'rt',
#    'sinyal',
#    'xl',
#    'lg',
#    'timbul',
#    'tenggelam']],
#  ['INDOSAT', ['internet', 'indosat', 'sampah', 'normal', 'mbps']],
#  ['XL',
#   ['menikmati',
#    'santai',
#    'dengan',
#    'vietnam',
#    'drip',
#    'dan',
#    'sinyal',
#    'kencang',
#    'dari',
#    'xl',
#    'setelah',
#    'seharian',
#    'mengembara']],
#  ['INDOSAT', ['edge', 'nya', 'indosat', 'lumayan', 'bagus', 'di', 'rumah']],
#  ['XL', ['signal', 'speed', 'lebih', 'lambat', 'dari', 'gsm']],
#  ['TRI',
#   ['membalas',
#    'saya',
#    'coba',
#    'registrasi',
#    'kok',
#    'tdk',
#    'bisa',
#    'ya',
#    'pdhl',
#    'memasukan',
#    'no',
#    'nik',
#    'sdh',
#    'benar',
#    'mohon',
#    'dibantu',
#    'secepatnya']],
#  ['XL', ['membalas', 'provider', 'anjing', 'ini']],
#  ['INDOSAT',
#   ['saya',
#    'dpt',
#    'sms',
#    'dari',
#    'indosat',
#    'mengenai',
#    'perubahan',
#    'paket',
#    'yellow',
#    'ttg',
#    'perubahan',
#    'harga',
#    'dan',
#    'benefit',
#    'pulsa',
#    'safe',
#    'saya',
#    'klik',
#    'link',
#    'info',
#    'tidak',
#    'bisa',
#    'mohon',
#    'diinfokan',
#    'lbh',
#    'detil',
#    'terima',
#    'kasih']],
#  ['INDOSAT', ['tidak', 'sia', 'pakai', 'kartu', 'indosatalhamdulillah']],
#  ['INDOSAT', ['sumpah', 'indosat', 'dino', 'iki', 'jancok', 'tenan']],
#  ['TSEL',
#   ['sejauh',
#    'ini',
#    'masih',
#    'sangat',
#    'sangat',
#    'puas',
#    'dengan',
#    'belum',
#    'ada',
#    'masalah',
#    'dan',
#    'lemot',
#    'sama',
#    'sekali']],
#  ['INDOSAT', ['indosat', 'dh', 'lumayan', 'bagus', 'jaringan', 'internetnya']],
#  ['XL', ['membalas', 'woi', 'bangsat']],
#  ['TRI',
#   ['klo',
#    'mau',
#    'cari',
# ...
#  ['TRI',
#   ['membalas',
#    'asli',
#    'min',
#    'tvc',
#    'nya',
#    'banyak',
#    'bgd',
#    'yg',
#    'ngena',
#    'nih',
#    'hahahaha',
#    'mantab',
#    'emg',
#    'sekalinya',
#    'buat',
#    'iklan',
#    'bermutu',
#    'bgd']],
#  ['TSEL',
#   ['asli',
#    'lah',
#    'ini',
#    'kampret',
#    'udah',
#    'harga',
#    'paket',
#    'internet',
#    'makin',
#    'mahal']],
#  ['XL',
#   ['cumaa',
#    'di',
#    'xl',
#    'jaringan',
#    'sinyal',
#    'full',
#    'kuota',
#    'banyak',
#    'tapii',
#    'gabisaa',
#    'internetan',
#    'cumaa',
#    'di',
#    'xl',
#    'kecewa',
#    'beratt',
#    'sumpahh']],
#  ['TRI', ['membalas', 'cukup', 'hayati', 'lelah', 'maas']],
#  ['TRI',
#   ['keluhan',
#    'saya',
#    'kok',
#    'ga',
#    'dijawab',
#    'ya',
#    'dari',
#    'kemarin',
#    'sampe',
#    'skrg']],
#  ['TRI',
#   ['jadi',
#    'ajudan',
#    'beliau',
#    'aja',
#    'pasti',
#    'mudah',
#    'deketinya',
#    'bangkitindonesia']],
#  ['INDOSAT', ['indosat', 'udah', 'lancar', 'ni', 'alhamdulillah']],
#  ['XL',
#   ['bangsat',
#    'benerlah',
#    'ini',
#    'provider',
#    'nguji',
#    'kesabaran',
#    'di',
#    'bulan',
#    'suci',
#    'ramadan']],
#  ['XL',
#   ['membalas',
#    'selamat',
#    'siang',
#    'sis',
#    'saya',
#    'mau',
#    'bertanya',
#    'tentang',
#    'keluhan',
#    'sya',
#    'apa',
#    'sis',
#    'bsa',
#    'membantu',
#    'sya',
#    'jlaskn',
#    'masa',
#    'berlaku',
#    'kartu',
#    'sya']],
#  ['INDOSAT', ['alhamdulillah', 'hujan', 'ready', 'axis', 'gb']],
#  ['XL',
#   ['membalas',
#    'provider',
#    'anjing',
#    'xl',
#    'isiny',
#    'cm',
#    'maling',
#    'dan',
#    'penipu',
#    'konsumen']],
#  ['TRI', ['membalas', 'tai']],
#  ['XL',
#   ['bangsat',
#    'fuck',
#    'minta',
#    'data',
#    'malah',
#    'di',
#    'cuekin',
#    'kuotahilangsendiri']],
#  ['XL', ['membalas', 'provider', 'goblok', 'maling', 'xl', 'tolol']],
#  ['TSEL',
#   ['membalas',
#    'ok',
#    'terima',
#    'kasih',
#    'tolong',
#    'supaya',
#    'di',
#    'daerah',
#    'saya',
#    'ini',
#    'tercover',
#    'juga',
#    'ya']],
#  ['XL',
#   ['halo',
#    'min',
#    'kok',
#    'tweet',
#    'saya',
#    'tidak',
#    'ditanggapi',
#    'min',
#    'internet',
#    'xl',
#    'selalu',
#    'tdk',
#    'bisa',
#    'diakses']],
#  ['TSEL',
#   ['membalas',
#    'gratis',
#    'yo',
#    'wah',
#    'enak',
#    'tenan',
#    'aq',
#    'pake',
#    'telkomsel',
#    'ne',
#    'mahal',
#    'he',
#    'he',
#    'tp',
#    'ad',
#    'trik',
#    'biar',
#    'murah',
#    'he',
#    'he']],
#  ['XL', ['bagus']],
#  ['TSEL',
#   ['udah',
#    'seminggu',
#    'belakangan',
#    'ini',
#    'hallo',
#    'kick',
#    'saya',
#    'ga',
#    'stabil',
#    'tiap',
#    'jam',
#    'keatas']],
#  ['XL',
#   ['membalas',
#    'dan',
#    'lainnya',
#    'provider',
#    'bangsat',
#    'ganti',
#    'kerugian',
#    'konsumen',
#    'anjing',
#    'maling',
#    'jd',
#    'provider',
#    'bangsat',
#    'xl']],
#  ['INDOSAT',
#   ['kembali',
#    'kasih',
#    'bahagia',
#    'itu',
#    'kalo',
#    'balas',
#    'tweet',
#    'lancar',
#    'cepat']],
#  ['TSEL',
#   ['membalas',
#    'seharian',
#    'kemarim',
#    'nyoba',
#    'beli',
#    'gagal',
#    'terus',
#    'ada',
#    'gangguan',
#    'infonya',
#    'kecewa']],
#  ['INDOSAT', ['selamat', 'sore']],
#  ['TRI',
#   ['membalas',
#    'betul',
#    'gak',
#    'three',
#    'mengadakan',
#    'undian',
#    'poin',
#    'care',
#    'mohon',
#    'informasi',
#    'nya']],
#  ['TSEL',
#   ['mbak',
#    'mas',
#    'gimana',
#    'nih',
#    'udah',
#    'hari',
#    'gw',
#    'main',
#    'game',
#    'tapi',
#    'ga',
#    'bisa']],
#  ['INDOSAT',
#   ['photo',
#    'jaringan',
#    'baru',
#    'cepat',
#    'dan',
#    'stabil',
#    'repost',
#    'iwantitnow',
#    'indosat',
#    'im']],
#  ['TSEL',
#   ['lemot',
#    'ya',
#    'lemot',
#    'aja',
#    'rt',
#    'tergantung',
#    'untuk',
#    'paket',
#    'yang',
#    'digunain']],
#  ['TRI',
#   ['makasi',
#    'kaka',
#    'mimin',
#    'rt',
#    'informasi',
#    'lengkap',
#    'paketri',
#    'hello',
#    'masa',
#    'aktif',
#    'panjang',
#    'bisa',
#    'langsung',
#    'klik',
#    'disini',
#    'ya']],
#  ['TSEL', ['seneng', 'pake', 'telkomsel']],
#  ['XL', ['terima', 'kasih']],
#  ['TSEL',
#   ['on',
#    'pake',
#    'telkomsel',
#    'tujuan',
#    'utamanya',
#    'adalah',
#    'biar',
#    'paketan',
#    'tri',
#    'ga',
#    'abis']],
#  ['TRI',
#   ['membalas',
#    'cinta',
#    'seperti',
#    'serangkaian',
#    'huruf',
#    'yg',
#    'membentuk',
#    'satu',
#    'kata',
#    'hingga',
#    'menjadi',
#    'kalimat',
#    'utuh',
#    'yg',
#    'mudah',
#    'dibaca',
#    'ahlicinta']],
#  ['TRI',
#   ['sinyal',
#    'kaya',
#    'tai',
#    'aja',
#    'laguan',
#    'sposorin',
#    'ml',
#    'urusin',
#    'dulu',
#    'sinyal',
#    'lu',
#    'bego',
#    'semenjak',
#    'sponsor',
#    'atau',
#    'bayar',
#    'apa',
#    'aja',
#    'paket',
#    'tri',
#    'jadi',
#    'kontol',
#    'sinyalnya']],
#  ['XL', ['iya', 'sih', 'dirumahku']],
#  ['TRI', ['kemarin', 'eror', 'pacar', 'gue', 'marah', 'min']],
#  ['INDOSAT', ['membalas', 'hi', 'ibu', 'kandou']],
#  ['INDOSAT',
#   ['membalas',
#    'saya',
#    'regist',
#    'pake',
#    'indosat',
#    'ga',
#    'bisa',
#    'bos',
#    'terus',
#    'saya',
#    'regist',
#    'pake',
#    'telkomsel',
#    'wah',
#    'mantap',
#    'terasa']],
#  ['XL',
#   ['membalas',
#    'provider',
#    'bangsat',
#    'xl',
#    'maling',
#    'jadi',
#    'provider',
#    'xl',
#    'goblok']],
#  ['INDOSAT',
#   ['membalas',
#    'baru',
#    'kemarin',
#    'isi',
#    'pulsa',
#    'buset',
#    'ini',
#    'cek',
#    'pulsa',
#    'langsung',
#    'rp',
#    'wkwkwk',
#    'lol',
#    'banget',
#    'sumpah',
#    'baru',
#    'kali',
#    'ini',
#    'ada',
#    'operator',
#    'sebesar',
#    'indosat',
#    'pelayanannya',
#    'maling',
#    'malingggg',
#    'tolong',
#    'cepat',
#    'ditangani']],
#  ['TRI',
#   ['aku', 'tri', 'seperti', 'hubungan', 'pacaran', 'yg', 'udah', 'lama']],
#  ['XL',
#   ['membalas',
#    'lebih',
#    'cape',
#    'liat',
#    'keluhan',
#    'custimer',
#    'di',
#    'sosmed',
#    'dari',
#    'jaman',
#    'dulu',
#    'tapi',
#    'gapindah',
#    'operator',
#    'meng',
#    'hahahaha']],
#  ['XL', ['sinyal', 'ok']],
#  ['TRI', ['telpon', 'murah', 'seharian', 'ke', 'semua', 'operator']],
#  ['TRI',
#   ['makanya', 'pke', 'tri', 'sinyal', 'di', 'jatinangor', 'dak', 'mantap']],
#  ['TSEL', ['oia']],
#  ['TSEL',
#   ['dear',
#    'saya',
#    'baru',
#    'saja',
#    'registrasi',
#    'kartu',
#    'tp',
#    'tulizannya',
#    'nik',
#    'tidk',
#    'ditemukan',
#    'mohon',
#    'bantuan',
#    'nomor',
#    'dan',
#    'id',
#    'di',
#    'dm']],
#  ['TSEL', ['kalau', 'masih', 'gini', 'gimana', 'udah', 'di', 'restart']],
#  ['XL', ['nek', 'liyane', 'yo', 'mbuhhahaha']],
#  ['TSEL',
#   ['waw',
#    'sungguh',
#    'puas',
#    'membaca',
#    'keluhan',
#    'para',
#    'pelanggan',
#    'telkomsel',
#    'di',
#    'sangat',
#    'kecewa',
#    'dgn',
#    'kwalitasnya']],
#  ['INDOSAT', ['membalas', 'aku', 'baru', 'isi', 'pulsa', 'kemarin', 'sore']],
#  ['INDOSAT', ['indosat', 'ngapa', 'si', 'anjing', 'kesel', 'banget']],
#  ['TSEL',
#   ['kok',
#    'lemot',
#    'ya',
#    'apakah',
#    'benar',
#    'dr',
#    'telkomsel',
#    'ini',
#    'perdana',
#    'nya']],
#  ['TSEL', ['butuh', 'telkomsel', 'poin', 'buat', 'jajan', 'murah']],
#  ['INDOSAT', ['kerja', 'sama', 'pt', 'indosat']],
#  ['INDOSAT', ['no', 'signal', 'sudah', 'di', 'restart']],
#  ['XL',
#   ['internetan',
#    'pake',
#    'xl',
#    'rasakan',
#    'jaringan',
#    'hotrod',
#    'internet',
#    'super',
#    'cepat',
#    'stabil',
#    'cek']],
#  ['XL', ['jaringan', 'najis', 'ngebatin', 'ampun']],
#  ['TSEL',
#   ['sinyal',
#    'telkomsel',
#    'lumayan',
#    'cepat',
#    'di',
#    'sekolah',
#    'laskar',
#    'pelangi',
#    'kota',
#    'manggar',
#    'at',
#    'geraihalo',
#    'manggar',
#    'pic']],
#  ['XL', ['udah', 'nyala', 'sekarang', 'lg', 'dibanda', 'aceh']],
#  ['TSEL', ['hai', 'anjing']],
#  ['XL', ['pasti', 'xl', 'rt', 'sinyal', 'kencang']],
#  ['TSEL', ['kecewa', 'doi', 'ko', 'jadi', 'cacat', 'bgt']],
#  ['INDOSAT', ['rt', 'iyah']],
#  ['TSEL', ['duuh', 'jd', 'ngrepotin', 'gini']],
#  ['INDOSAT',
#   ['membalas',
#    'dan',
#    'lainnya',
#    'alhamdulillah',
#    'ternyata',
#    'ada',
#    'yang',
#    'lebih',
#    'bermafaat',
#    'dibanding',
#    'membeli',
#    'indosat']],
#  ['XL',
#   ['kalian',
#    'beneran',
#    'provide',
#    'service',
#    'gak',
#    'sih',
#    'pingin',
#    'nangis',
#    'rasanya']],
#  ['TSEL',
#   ['membalas',
#    'soto',
#    'ayam',
#    'yg',
#    'enak',
#    'soto',
#    'pak',
#    'dalbe',
#    'sebelahnya',
#    'telkomsel',
#    'lamamurah',
#    'pula']],
#  ['TRI',
#   ['emang',
#    'operator',
#    'nya',
#    'ka',
#    'yg',
#    'bafukkkkrt',
#    'ini',
#    'kartu',
#    'gue',
#    'doang',
#    'apa',
#    'emang',
#    'operator',
#    'tri',
#    'yg',
#    'gda',
#    'sinyal',
#    '_',
#    'bapuk']],
#  ['INDOSAT',
#   ['alhamdulillah', 'sinyal', 'indosat', 'sudah', 'normal', 'kembali']],
#  ['TRI', ['hahahhahahhamarehhh']],
#  ['XL',
#   ['min',
#    'xl',
#    'lagi',
#    'gangguan',
#    'kenapa',
#    'koneksi',
#    'internetnya',
#    'lambat',
#    'sekali',
#    'padahal',
#    'sinyal',
#    'bagus',
#    'lte']],
#  ['TRI',
#   ['indosat',
#    'udah',
#    'gabung',
#    'sama',
#    'tri',
#    'ya',
#    'sekarang',
#    'kuota',
#    'doang',
#    'banyak',
#    'sinyal',
#    'lemotnya',
#    'mantap']],
#  ['INDOSAT', ['rt', 'sumpaaaaaah', 'indosat', 'what', 'the', 'hell', 'yah']],
#  ['TRI',
#   ['anjing',
#    'sinyal',
#    'ilang',
#    'menit',
#    'gua',
#    'lagi',
#    'di',
#    'game',
#    'bangsat',
#    'nherrikn',
#    'lah',
#    'gua',
#    'gamer',
#    'kerja',
#    'ngapain',
#    'aja',
#    'kontol']],
#  ['TRI', ['benci', 'jadi', 'cinta']],
#  ['TSEL',
#   ['karena',
#    'atau',
#    'sangat',
#    'cepat',
#    'dan',
#    'kuat',
#    'signalnyaapalagi',
#    'sdg',
#    'nongkrong']],
#  ['XL', ['ada', 'apa', 'dengan', 'masak', 'iya']],
#  ['TRI', ['asik', 'beli', 'perdana', 'rb', 'isi', 'pulsa', 'rb']],
#  ['INDOSAT',
#   ['rt',
#    'aku',
#    'seneng',
#    'bgd',
#    'ungu',
#    'band',
#    'mraih',
#    'menang',
#    'indosat',
#    'award',
#    'kpn',
#    'nih',
#    'hits',
#    'klip',
#    'ke',
#    'mantap',
#    'almbenyamin',
#    'mraih',
#    'indosat',
#    'legen']],
#  ['TRI',
#   ['membalas',
#    'aku',
#    'sih',
#    'isih',
#    'ng',
#    'yk',
#    'nik',
#    'widihh',
#    'mantap',
#    'tak',
#    'kiro',
#    'susah',
#    'sinyal',
#    'nik',
#    'wkwkwk']],
#  ['INDOSAT',
#   ['nah',
#    'kaya',
#    'gini',
#    'kan',
#    'enak',
#    'jadi',
#    'ada',
#    'klarifikasi',
#    'dari',
#    'indosat',
#    'pengguna',
#    'gak',
#    'capek',
#    'ganti',
#    'ganti',
#    'jaringan',
#    'terima',
#    'kasih',
#    'mba',
#    'mila',
#    'semangat',
#    'ya',
#    'kerjanya',
#    'jangan',
#    'jaringan',
#    'aja',
#    'yang',
#    'dipelihara',
#    'hati',
#    'juga',
#    'wuff',
#    'menambahkan']],
#  ['INDOSAT',
#   ['ganti',
#    'aj',
#    'dit',
#    'rt',
#    'pokoknya',
#    'saya',
#    'lagi',
#    'kecewa',
#    'berat',
#    'sm',
#    'indosat',
#    'mkualitas',
#    'sinyal',
#    'hsdpa',
#    'gprs',
#    'nya',
#    'kalah',
#    'sama']],
#  ['INDOSAT',
#   ['membalas',
#    'pulsa',
#    'saya',
#    'berkurang',
#    'ribu',
#    'saat',
#    'ada',
#    'sms',
#    'dari',
#    'ring']],
#  ['INDOSAT',
#   ['min',
#    'tolong',
#    'bantu',
#    'cek',
#    'no',
#    'indosat',
#    'saya',
#    'di',
#    'no',
#    '99']],
#  ['TSEL', ['wei', 'anjing']],
#  ['INDOSAT', ['membalas', 'hai', 'kak']],
#  ['TRI', ['lumayan', 'lapar', 'rt', 'selamat', 'siang']],
#  ['TRI',
#   ['paket',
#    'malam',
#    'gue',
#    'kok',
#    'gak',
#    'aktif',
#    'operator',
#    'kontol',
#    'bangsat',
#    'lu',
#    'semua']],
#  ['TRI',
#   ['ini',
#    'sinyal',
#    'tri',
#    'di',
#    'rumah',
#    'saya',
#    'masih',
#    'lemot',
#    'dan',
#    'tidak',
#    'terjangkau',
#    'jangan',
#    'di',
#    'suruh',
#    'pindahkan',
#    'ke',
#    'hp',
#    'lain',
#    'deh']],
#  ['TRI', ['berngkt', 'krj', 'tpt', 'jm']],
#  ['TRI',
#   ['enaknya',
#    'make',
#    'tri',
#    'nih',
#    'gini',
#    'paket',
#    'murah',
#    'sinyal',
#    'gapake',
#    'pending',
#    'axis',
#    'buat',
#    'di',
#    'hp',
#    'butut',
#    'aja',
#    'buat',
#    'smsan',
#    'wkwkwk']],
#  ['INDOSAT', ['membalas', 'sudah', 'dari', 'pake', 'indosat']],
#  ['TRI', ['min', 'folback']],
#  ['INDOSAT', ['membalas', 'hi', 'kak']],
#  ['INDOSAT', ['sebulan', 'kemudian', 'ke', 'indosat']],
#  ['INDOSAT',
#   ['membalas', 'kirain', 'kartu', 'gua', 'keblokir', 'indosat', 'asu', 'emg']],
#  ['INDOSAT', ['indosat', 'bikin', 'nangis', 'nih', 't______t']],
#  ['INDOSAT',
#   ['kenapa',
#    'sekarang',
#    'indosat',
#    'kuotanya',
#    'juga',
#    'kebagi',
#    'ada',
#    'yg',
#    'midnight',
#    'pula',
#    'jam',
#    'terbang',
#    'paling',
#    'banyak',
#    'kan',
#    'pagi',
#    'malem',
#    'omduh',
#    'cepet',
#    'abis']],
#  ['TSEL',
#   ['membalas',
#    'boleh',
#    'saya',
#    'minta',
#    'bantuan',
#    'terkait',
#    'nomor',
#    'saya']],
#  ['INDOSAT', ['membalas', 'sblm', 'ganti']],
#  ['XL',
#   ['klik',
#    'link',
#    'rt',
#    'gmn',
#    'sih',
#    'caranyart',
#    'alhamdulillah',
#    'sy',
#    'dpt',
#    'paket',
#    'gemini',
#    'xl',
#    'murah',
#    'dari']],
#  ['TRI', ['min']],
#  ['TRI',
#   ['membalas',
#    'tergantung',
#    'sinyal',
#    'di',
#    'rumah',
#    'kamu',
#    'sih',
#    'xl',
#    'lebih',
#    'murah',
#    'tp',
#    'ya',
#    'di',
#    'aku',
#    'xl',
#    'lemot',
#    'parah',
#    'bagusan',
#    'tri']],
#  ['XL', ['di', 'dalem', 'gor', 'uny', 'ini', 'xl', 'ga', 'ada', 'sinyal']],
#  ['TSEL',
#   ['sedang',
#    'kecewa',
#    'sama',
#    'layanan',
#    'bis',
#    'beberapa',
#    'hari',
#    'ini',
#    'kalo',
#    'udah',
#    'di',
#    'atas',
#    'jam',
#    'maghrib',
#    'paket',
#    'bis',
#    'nya',
#    'nggak',
#    'bisa',
#    'dipake',
#    'tumben']],
#  ['XL',
#   ['sinyal',
#    'kuat',
#    'xl',
#    'membuat',
#    'surfing',
#    'terasa',
#    'lebih',
#    'cepat',
#    'dgn',
#    'paket',
#    'balckberry',
#    'dari',
#    'xl',
#    'cek']],
#  ['INDOSAT',
#   ['ini',
#    'firstmedia',
#    'ama',
#    'indosat',
#    'knp',
#    'sih',
#    'anjing',
#    'dari',
#    'siang',
#    'gw',
#    'offline']],
#  ['TSEL',
#   ['saya',
#    'ucapkan',
#    'terimakasih',
#    'kepada',
#    'tim',
#    'grapari',
#    'pgc',
#    'lt',
#    'telesindo',
#    'mall',
#    'kalibata',
#    'yang',
#    'sudah',
#    'mempermudah',
#    'saya',
#    'membuat',
#    'kartu',
#    'saya',
#    'yg',
#    'hilang']],
#  ['TRI', ['sinyal', 'tri', 'lemot']],
#  ['TRI',
#   ['jual',
#    'pulsa',
#    'paket',
#    'internet',
#    'all',
#    'operator',
#    'murah',
#    'bgt',
#    'indosat',
#    'gb',
#    'jam',
#    'hr',
#    'cuma']],
#  ['INDOSAT',
#   ['gileee', 'baru', 'laporan', 'indosat', 'kalo', 'paketan', 'bermasalah']],
#  ['XL',
#   ['yeahhh',
#    'rt',
#    'jiaaah',
#    'disini',
#    'sinyal',
#    'aja',
#    'gak',
#    'nongol',
#    'seberapa',
#    'kencang',
#    'lte',
#    'besutan',
#    'xl',
#    'axiata']],
#  ['TSEL',
#   ['pejuangforward',
#    'guidolin',
#    'puas',
#    'raih',
#    'kemenangan',
#    'magis',
#    'di',
#    'anfield',
#    'francesco',
#    'guidolin',
#    'merasa',
#    'sangat',
#    'cc']],
#  ['TSEL',
#   ['membalas',
#    'jancok',
#    'direkturnya',
#    'busuk',
#    'tukang',
#    'korupsi',
#    'pulsa',
#    'pelangganannya']],
#  ['TRI', ['min']],
#  ['TSEL', ['aku', 'juga', 'pnya', 'trie']],
#  ['XL',
#   ['xl',
#    'itu',
#    'jaringannya',
#    'sangat',
#    'memuaskan',
#    'banget',
#    'bagi',
#    'para',
#    'pengguna',
#    'xl',
#    'xlgmobile']],
#  ['XL', ['sepertinya', 'harus', 'pake', 'xl', 'nih']],
#  ['INDOSAT', ['ga', 'lagi', 'lagi', 'sy', 'pake', 'indosat', 'ya']],
#  ['XL',
#   ['membalas',
#    'hy',
#    'provider',
#    'xl',
#    'bangsat',
#    'kebanyakan',
#    'nipu',
#    'konsumem',
#    'anjing',
#    'pake',
#    'byk',
#    'alesan',
#    'kampret']],
#  ['TSEL',
#   ['masa',
#    'siiy',
#    'gw',
#    'gak',
#    'niy',
#    'rt',
#    'kecewa',
#    'bgt',
#    'dgn',
#    'telkomsel']],
#  ['TSEL',
#   ['membalas',
#    'kita',
#    'tunggu',
#    'kehadiran',
#    'nya',
#    'di',
#    'solotapi',
#    'untuk',
#    'saat',
#    'ini',
#    'sudah',
#    'sangat',
#    'puas',
#    'dengan',
#    'kecepatan',
#    'internet',
#    'yang',
#    'ada']],
#  ['TRI',
#   ['admin',
#    'lelet',
#    'ya',
#    'sekarang',
#    'balas',
#    'cat',
#    'lelet',
#    'dm',
#    'lelet',
#    'kalo',
#    'lumayan',
#    'cepet',
#    'mungkinkah',
#    'micin',
#    'kebanyakan',
#    'pramborsthrowback',
#    'wartegdkieps']],
#  ['TSEL',
#   ['tae',
#    'loe',
#    'telkomsel',
#    'bikin',
#    'gw',
#    'kesel',
#    'aja',
#    'loe',
#    'mau',
#    'loe',
#    'apa',
#    'sih',
#    'tiba',
#    'lost',
#    'koneksi',
#    'jancok',
#    'goblok']],
#  ['XL', ['sinyal', 'full', 'tapi', 'koneksi', 'sangat', 'lambat', 'kecewa']],
#  ['INDOSAT',
#   ['indosat',
#    'ooredoo',
#    'memperkenalkan',
#    'gplus',
#    'untk',
#    'memberikan',
#    'jaringan',
#    'yg',
#    'lbh',
#    'kuat']],
#  ['INDOSAT',
#   ['gila',
#    'ya',
#    'indosat',
#    'ooredoo',
#    'sinyalnya',
#    'jelek',
#    'banget',
#    'mau',
#    'nangis']],
#  ['XL', ['membalas', 'hahaha', 'benar', 'bikin', 'bablas', 'mas']],
#  ...]

# %%
# Stem
ltstem = []
for i in lttoken:
    temp_sentence = []
    for j in i[1]:
        stemmed = stemmer.stem(j)
        temp_sentence.append(stemmed)
    print(temp_sentence)
    ltstem.append(temp_sentence)
ltstem
# Out:
# ['kenapa', 'kartu', 'registrasi', 'nggak', 'bisa', 'pak', 'padahal', 'nomor', 'kk', 'ktp', 'nya', 'sudah', 'benar', 'sampai', 'gagal']
# ['indosat', 'mantap', 'djaja', 'koneksi']
# ['balas', 'mau', 'nang', 'deh', 'rasa', 'pdahl', 'saya', 'percaya', 'betul', 'dengan', 'indosat', 'soal', 'koneksi', 'di', 'wil', 'karimun', 'tp', 'sudah', 'hari', 'koneksi', 'kacau', 'balau']
# ['sinyal', 'indosat', 'asu', 'ari', 'musim', 'hujan']
# ['balas', 'cek', 'dm', 'woi']
# ['ini', 'kenapa', 'di', 'bale', 'endah', 'sinyal', 'xl', 'tiba', 'bagus', 'yah', 'pindah', 'kali', 'yah', 'tower', 'nya', 'ke', 'deket', 'rumah', 'aneh', 'liat', 'hp', 'sendiri']
# ['hotsale', 'gb', 'hanya', 'gratis', 'nelfon', 'aja', 'ga', 'ada', 'gratis', 'sms', 'nya', 'tah', 'min']
# ['balas', 'dan', 'lain', 'hai', 'kak', 'andika']
# ['balas', 'iya', 'min', 'udah', 'bisa', 'kok', 'hihihi', 'tengkyu', 'yaaaa', 'neng', 'banget', 'pake', 'telkomsel', 'sinyal', 'lancaaar']
# ['ribu', 'saya', 'beneran', 'atau', 'bohong', 'saya', 'coba', 'buat', 'internet', 'lngsung', 'tanpa', 'daftar', 'paket', 'internet', 'dan', 'alhamdulillah', 'bisa', 'buat', 'internet', 'trus', 'saya', 'buka', 'halaman', 'indosat', 'baru', 'buka', 'saya', 'dpt', 'sms', 'dari', 'indosat', 'kamu', 'internetan', 'dg', 'tarif', 'perkb']
# ['sinyal', 'kencang', 'xl', 'mantabbbzz']
# ['tolong', 'kasih', 'jelas', 'yg', 'bisa', 'saya', 'terima', 'dong', 'kenapa', 'hari', 'ini', 'sinyal', 'indosat', 'sangat', 'kecewa', 'di', 'daerah', 'mampang', 'depok']
# ['yang', 'lagi', 'mau', 'libur', 'di', 'the', 'jungle', 'bogor', 'indosat', 'super', 'wifi', 'juga', 'ada', 'di', 'sana', 'looh']
# ['balas', 'saya', 'juga', 'cukup', 'heran', 'mengapa', 'speednya', 'bisa', 'naik', 'rumah', 'akan', 'saya', 'ss', 'sisa', 'paket', 'saya']
# ['jikalau', 'masalah', 'sdm', 'yg', 'akibat', 'keluh', 'saya', 'tidak', 'balas']
# ['operator', 'tolong', 'yah', 'sinyal', 'nya', 'jangan', 'jelek', 'terus', 'tiap', 'hari', 'saya', 'kecewa', 'sekali', 'dengan', 'sekarang', 'padahal', 'sdh', 'tahun', 'pakai']
# ['balas', 'mantap', 'jiwa', 'nih', 'min', 'harga', 'paket']
# ['terima', 'kasih', 'kepada', 'sponsor', 'yg', 'sudah', 'dukung', 'acara', 'kita']
# ['sinyal', 'mana', 'cuma', 'padahal', 'paket', 'internet', 'makin', 'mahal', 'makin', 'bobrok', 'aja', 'xl', 'kecewa', 'saiah']
# ['balas', 'woy', 'anjing', 'bukan', 'kota', 'jakarya', 'saja', 'semua', 'kota', 'apa', 'lo', 'gak', 'baca', 'twett', 'guna', 'lain', 'makasar', 'aja', 'uda', 'minggu', 'sial', 'lo', 'anjing', 'kampret']
# ['', 'rt', 'aseek', 'nickminaj', 'kalo', 'hujan', 'dan', 'malam', 'tri', 'pasti', 'lot', 'bangsat']
# ['frontal', 'cuk', 'rt', 'bangsat']
# ['memang', 'baik', 'sakal', 'iye', 'teh', 'telkomsel']
# ['ya', 'ampun']
# ['indosat', 'sinyale', 'koyo', 'ngelec', 'asu']
# ['gimana', 'nich']
# ['haloo', 'bagaimana', 'nasib', 'keluh', 'saya', 'tiket', 'c9', 'apakah', 'masih', 'di', 'tanggap', 'atau', 'di', 'anggap', 'angin', 'lalu', 'sejak', 'januari', 'masih', 'belum', 'selesai', 'cc']
# ['makassar', 'lg', 'seru', 'banget', 'nih', 'guys', 'sore', 'ini']
# ['kecewa', 'berat', 'saiah', 'dengan']
# ['min']
# ['th', 'pakai', 'xl']
# ['bias', 'pake', 'indosat', 'ngecek', 'pulsa', 'salah']
# ['sudah', 'bulan', 'sejak', 'januari', 'keluh', 'saya', 'no', 'tiket', 'c9', 'tidak', 'ada', 'respon', 'dan', 'solusi', 'cc']
# ['sinyal', 'jelek', 'bgt', 'sih']
# ['maju', 'tak', 'gentar', 'bela', 'yang', 'benar']
# ['balas', 'min', 'mau', 'nanya', 'ni', 'knp', 'sim', 'card', 'telkomsel', 'saya', 'tdk', 'bisa', 'buat', 'panggil', 'keluar', 'sedang', 'kemarin', 'bisa', 'sudah', 'dua', 'minggu', 'koit', 'min', 'sdh', 'hasil', 'registrasi', 'pula', 'gimana', 'saran', 'dan', 'tanggap', 'anda', 'wakil', 'telkomsel']
# ['telah', 'telkomsel', 'ini', 'indosat', 'pakai', 'jasa', 'felix', 'kwetiau', 'org', 'hti', 'ormas', 'larang', 'utk', 'isi', 'acara', 'ramadhan', 'emang', 'gak', 'ada', 'kah', 'ulama', 'yg', 'lain', 'mohon', 'klarifikasi', 'utk', 'apa', 'benar', 'flyer', 'yg', 'saya', 'terima', 'ini', 'd']
# ['coba', 'cek', 'ke', 'zhir', 'bukanorangdalemxl']
# ['di', 'tahun', 'anjing', 'tanah', 'ini']
# ['alhamdulillah', 'kartu', 'indosat', 'pintar', 'laris', 'manisbisa', 'free', 'call', 'menit', 'sms', 'ke', 'semua', 'indosat', 'dan', 'data']
# ['sinyal', 'xl', 'kencang', 'badai']
# ['balas', 'saya', 'sedang', 'tanya', 'informasi', 'kuota', 'yg', 'beda', 'antara', 'bima', 'dan', 'web', 'saya', 'pinta', 'jelas']
# ['sinyal', 'tri', 'di', 'area', 'cikarang', 'delta', 'mas', 'dan', 'jababeka', 'hilang', 'sinyal', 'mulai', 'jam', 'tadi', 'mohon', 'baik', 'terima', 'kasih']
# ['sekarang', 'udah', 'jaman', 'lte']
# ['makasih', 'keluh', 'sudah', 'di', 'tangan', 'dengan', 'cepat']
# ['sekarang', 'pake', 'indosat', 'pasca', 'bayar']
# ['ogah', 'rt', 'beralihalah', 'ke', 'xlsinyal', 'kencang', 'dan', 'lari', 'pulsa', 'juga', 'kencang', 'rt', 'indosat', 'kampring']
# ['di', 'buat', 'nang', 'sama', 'jaring', 'indosat', 'gara', 'jaring', 'nya', 'jelek', 'nyangka', 'nya', 'mz', 'dari', 'dia', 'ga', 'di', 'lz', 'hampura', 'sayank']
# ['balas', 'nambahin', 'wacana']
# ['balas', 'tolong', 'baik', 'sinyal', 'di', 'aceh']
# ['', 'keluarga', 'telkomsel', 'memang', 'baik', 'rt', 'kayak', 'aq', 'jg', 'akan', 'kembali', 'ke', 'kartu', 'as', 'qu']
# ['balas', 'saya', 'mau', 'nang', 'kejer', 'rasa', 'mas', 'kalau', 'saya', 'main', 'mobile', 'legend', 'tuh', 'tiba', 'tiba', 'jaring', 'putus', 'tanpa', 'sebab', 'tau', 'gak', 'telkomsel', 'sering', 'banget', 'kayak', 'gin', 'padahal', 'untuk', 'streaming', 'apa', 'itu', 'lancar', 'lancar', 'aja', 'mas', 'saya', 'udah', 'turun', 'credit', 'score', 'mobile', 'legend', 'gara', 'koneksi', 'putus']
# ['kepada', 'para', 'menang', 'kuis', 'bangkitindonesia', 'bisa', 'cek', 'dm', 'nya', 'ya']
# ['mantapsinyal', 'stabil', 'skrg', 'dirumahthx', 'telkomsel']
# ['kualitas', 'sinyal', 'makin', 'hari', 'makin', 'ancur', 'tolong', 'dong', 'baik']
# ['im', 'ne', 'iklan', 'sampah', 'kreatif', 'dikit', 'napa', 'ikut', 'as', 'telkomsel', 'maluuuuuuu']
# ['ready', 'pis', 'rt', 'sudah', 'siap', 'untuk', 'kuis', 'bangkitindonesia', 'tes', 'suara', 'dulu', 'ah']
# ['balas', 'kalo', 'kayak', 'gin', 'gimana', 'coba', 'aktifinnyaaaaa', 'kasih', 'tau', 'dong', 'caranyaaaaaa']
# ['nah', 'ini', 'rt', 'cari', 'tri', 'store', 'dekat', 'di', 'kota', 'kamu', 'klik', 'link', 'ini', 'untuk', 'informasi', 'lengkap', 'yaa']
# ['pake', 'antena', 'pf', 'goceng', 'brad']
# ['balas', 'klo', 'bisa', 'nang']
# ['gw', 'yakin', 'ga', 'bisa', 'baca', 'komen', 'ini', 'lot', 'telkomselproradikalis', 'telkomselproradikalis', 'telkomselproradikalis', 'telkomselproradikalis', 'telkomselproradikalis', 'telkomselproradikalis', 'telkomselproradikalis', 'telkomselproradikalisjoe', 'tambah']
# ['monyeet', 'koneksi', 'sampah']
# ['irsoekarno', 'hatta', 'rt', 'kuis', 'bangkitindonesia', 'tebak', 'tokoh', 'yang', 'ada', 'di', 'gambar', 'ini']
# ['balas', 'anyway']
# ['alam', 'gue', 'sangat', 'mantap', 'pakek', 'indosat']
# ['min', 'saya', 'mau', 'nanya']
# ['kumpul', 'mahadelta', 'dapet', 'rejeki', 'dari', 'indosat', 'lumayan', 'gb', 'free', 'lancar', 'abis', 'terima', 'kasih', 'indosat']
# ['balas', 'baik']
# ['joss', 'makany', 'klo', 'beli', 'no', 'sklian', 'bli', 'sinyal', 'ahhaha', 'rt', 'plis', 'xl', 'jgn', 'balak', 'donk', 'knp', 'skr', 'signal', 'nya', 'ababil', 'sih']
# ['anjing', 'lukalau', 'gk', 'suka', 'mobile', 'legend', 'jangan', 'dilenotin', 'dong', 'sinyal', 'asu', 'aov', 'itu', 'asu', 'kyk', 'telkomsel']
# ['udah', 'senin', 'nih', 'upload', 'foto', 'pas', 'weekend', 'kmrn', 'ayo', 'pakai', 'xl', 'internet', 'super', 'cepat', 'stabil', 'lovepalembang', 'hotrod']
# ['lagu', 'favorit', 'kecewa', 'karna', 'org', 'itu', 'suka', 'bikin', 'hati', 'org', 'kecewa', 'baper', 'bgt', 'lagu', 'konserrossa']
# ['merah', 'sinyal']
# ['nih', 'provider', 'harus', 'banyak', 'ajar', 'sama', 'keluh', 'cepat', 'di', 'tanggap']
# ['apakah', 'ini', 'maju', 'apa', 'indosat', 'makin', 'maju', 'dari', 'kemarin', 'kemarin', 'internetnya', 'cepet', 'terusssss', 'selamat']
# ['cs', 'nya', 'lelet', 'dan', 'lot']
# ['sumpah', 'xl', 'sampah', 'banget', 'sinyal', 'benerin', 'dong', 'jaring', 'jangan', 'cuma', 'berani', 'ngasih', 'promo', 'murah']
# ['indosat', 'sinyal', 'nya', 'palang', 'merah', 'okeee', 'xl', 'lumayan', 'lah', 'ada', 'dikit']
# ['min']
# ['balas', 'terima', 'kasih', 'indosat']
# ['balas', 'memang', 'gitu', 'sinyal', 'xl', 'terkadang', 'kencang', 'tiba', 'lambatsama', 'tempat', 'jga', 'gitutapi', 'jgn', 'ganti', 'kartu', 'semua', 'sama']
# ['99', 'jlphh', 'musofa', 'jln', 'suci', 'dpn', 'sma', 'yas', 'knpa', 'ya', 'skarang', 'sinyal', 'tri', 'edge', 'terus', 'ga', 'pernah', 'di', 'area', 'rumah', 'saya']
# ['sama', 'tolong', 'kenapa', 'ini', 'xl', 'di', 'rumah', 'yang', 'biasa', 'streaming', 'ga', 'buffer', 'ini', 'buka', 'twitter', 'aja', 'gabisa', 'hadeh', 'kile', 'tambah']
# ['balas', 'anjing', 'indosat', 'goblok', 'fakk', 'maen', 'moba', 'aja', 'leg', 'nya', 'minta', 'di', 'tampil', 'kontol']
# ['asu', 'jaringane', 'kek', 'tai', 'percuma', 'pket', 'banyak', 'tp', 'nge', 'lag', 'gbsa', 'ngapain', 'sumpah', 'payah', 'jancuk']
# ['balas', 'dan', 'lain', 'iya', 'nih', 'kontol', 'indosat', 'pulsa', 'gua', 'potong', 'anjing', 'babi']
# ['satelit', 'telkomsel', 'ledak', 'pa', 'gimana', 'hng', 'sehunxlv', 'lvcruise']
# ['pertama', 'kali', 'xl', 'bawa', 'ke', 'luar', 'rumah', 'signal', 'internetnya', 'bagus', 'bye', 'bye', 'indosat', 'cukup', 'lah', 'ya', 'tahan', 'tahun']
# ['balas', 'semua', 'program', 'infrastruktur', 'waris', 'dari', 'pemerintahaan', 'belum', 'kita', 'tunggu', 'yg', 'murni', 'dari', 'jokowi', 'seperti', 'listrik', 'megawatt']
# ['susah', 'sama', 'smpai', 'skrg', 'cuma', 'di', 'tanya']
# ['kecewa', 'sama', 'layan', 'telkomsel']
# ['balas', 'makin', 'lama', 'makin', 'jelek']
# ['balas', 'waktu', 'itu', 'kartu', 'udah', 'hangus', 'karena', 'lupa', 'isi', 'pulsa']
# ['harus', 'lihat', 'kualitas', 'dulu', 'baru', 'naikkin', 'harga']
# ['halo', 'indosat']
# ['balas', 'ini', 'xl', 'knapa', 'sih', 'ganggu', 'mulu', 'signal', 'ada', 'tapi', 'no', 'internet', 'connection', 'sampah']
# ['oke', 'thanks', 'info', 'rt', 'informasi', 'paket', 'sms', 'bisa', 'km', 'cek', 'di']
# ['balas', 'saya', 'tidak', 'pilih', 'semua', 'karena', 'saat', 'ini', 'jaring', 'internet', 'xl', 'mbyarpet', 'alis', 'mati', 'hidup', 'plus', 'lelet', 'sangatsangatsangat', 'kecewa', 'kecewa', 'karena', 'sudah', 'jadi', 'sejak', 'sabtu', 'kemarin']
# ['sudah', 'hampir', 'minggu', 'lebih', 'sinyal', 'daerah', 'ku', 'sangat', 'lambat', 'sekali', 'apakah', 'xl', 'sedang', 'ada', 'ganguguan']
# ['balas', 'saya', 'aku', 'indosat', 'cukup', 'bagus']
# ['promosi', 'awak', 'iya', 'rt', 'pake', 'xl', 'la', 'hahha', 'punya', 'kencang', 'rt', 'udah', 'midnite', 'gin', 'pun', 'sinyal', 'tetep', 'aja', 'kacau']
# ['bayar', 'berapa', 'nis', 'buat', 'ngeboong', 'ekekekke', 'rt', 'makan', 'pakai', 'xl', 'sinyal', 'kencang', 'saat', 'anda', 'ada', 'mana', 'saja', 'yrt']
# ['balas', 'iki', 'nang', 'munggur', 'kok', 'mung', 'oleh', 'sinyal', 'mentok', 'bar', 'paket', 'mahal', 'sinyal', 'busuk']
# ['emang', 'juga', 'telkomsel', 'cacat']
# ['kasih', 'pete', 'bapak', 'nih', 'mimin', 'ulang', 'kuis', 'bangkitindonesia', 'gimana', 'cara', 'deketin', 'anak', 'presiden', 'biar', 'restu']
# ['balas', 'kno', 'dit', 'lama', 'masih', 'indonesia', 'jgn', 'harap', 'lebih', 'sama', 'dunia', 'selular']
# ['sinyal', 'xl', 'di', 'bintaro', 'kurang', 'bagus', 'yaa']
# ['ini', 'jaring', 'kenapa', 'dan', 'ilang', 'cacat', 'banget', 'koneksi']
# ['balas', 'dm', 'gue', 'gimana', 'riza', 'taek']
# ['paket', 'internet', 'indosat', 'bikin', 'nang', 'borosss', 'yawooh']
# ['min']
# ['admin', 'jancok']
# ['sinyal', 'gawat', 'min']
# ['tekad', 'sudah', 'bulat']
# ['apakah', 'ada', 'cara', 'situs', 'no', 'yg', 'bisa', 'akses', 'untuk', 'ketes', 'jaring', 'xl', 'maksud', 'beli', 'mifi']
# ['gak', 'boleh', 'nyebut', 'merk', 'titik', 'rt', 'internetnya', 'telkomsel', 'lemottitik']
# ['balas', 'sudah', 'saya', 'dm', 'cek', 'segera', 'itu', 'no', 'hp', 'saya', 'tolong', 'mati', 'layan', 'prime', 'joy', 'yang', 'saya', 'tidak', 'daftar', 'itu', 'saya', 'tidak', 'terima', 'pulsa', 'saya', 'potong', 'tiap', 'bulan', 'hanya', 'demi', 'benefit', 'prime', 'dari', 'indosat', 'yang', 'sama', 'sekali', 'tidak', 'guna', 'dan', 'tak', 'akan', 'saya', 'guna', 'thanks']
# ['balas', 'gambar', 'aku', 'pake', 'baju', 'perang', 'dengan', 'background', 'kobar', 'api', 'sambil', 'bawa', 'bendera', 'hehe', 'bangkitindonesia']
# ['saya', 'kecewa', 'sama', 'telkomsel', 'ketok', 'palu']
# ['cuaca', 'cerah', 'telah', 'ganti', 'di', 'siang', 'ini', 'angin', 'mulai', 'kencang', 'tanda', 'apa', 'ya', 'sinyal', 'xl', 'tetep', 'lantjar', 'jaya']
# ['saya', 'sangat', 'kecewa', 'jaring', 'internet', 'di', 'daerah', 'saya', 'lemotbuka', 'fb', 'sama', 'vidio', 'fb', 'lemotbuat', 'maen', 'game', 'stabil']
# ['balas', 'yaaa', 'makanyaaa', 'aku', 'sedih']
# ['selamat', 'malam']
# ['dulu', 'rekomen', 'soal', 'internetnya', 'cepet', 'dan', 'lancar']
# ['balas', 'bisa', 'bantu', 'link', 'url', 'informasi', 'sebut']
# ['gmn', 'dong', 'gue', 'mau', 'nang', 'besok', 'tuh', 'gue', 'mau', 'bukber', 'masa', 'gue', 'bukber', 'dengan', 'gaada', 'kuota', 'anjing', 'bangsat', 'lo', 'indosat', 'tolol']
# ['tlg', 'kalo', 'kasih', 'info', 'itu', 'yg', 'jujur', 'biar', 'konsumen', 'ga', 'marah', 'ga', 'kesel']
# ['kecewa', 'dg', 'kualitas', 'indosat', 'kuota', 'masih', 'gban', 'kuota', 'ludes', 'gak', 'jelas']
# ['haha', 'tapi', 'da', 'lelet', 'pake', 'telkomsel', 'engga', 'ah', 'udh', 'enak', 'pake', 'yang', 'ini', 'murah', 'aaaa']
# ['yah', 'hehe', 'pake', 'xl', 'lumayan', 'bagus', 'lho', 'say', 'rt', 'tapi', 'bb', 'aku', 'indosat', 'gabisa', 'ganti', 'ke', 'xlhhe', 'rt']
# ['gimana', 'cara', 'ngilangin', 'ini', 'lama', 'saya', 'beli', 'kartu', 'baru', 'dan', 'langsung', 'hasil', 'registrasi', 'tapi', 'notifikasi', 'ini', 'nongol', 'terus', 'ganggu', 'banget']
# ['balas', 'ga', 'ada', 'kendala', 'kata', 'bener', 'tai', 'ni', 'cs', 'sinyal', 'saya', 'hilang', 'jg', 'bilang', 'ga', 'ada', 'kendala', 'dan', 'cs', 'bales', 'komplain', 'waktu', 'sinyal', 'baik', 'ga', 'punya', 'otak', 'ni', 'cs']
# ['dear']
# ['selamat', 'pagi', 'mohon', 'informasi', 'untuk', 'upgrade', 'kartu', 'jadi', 'lokasi', 'bekas', 'gerai', 'tri', 'ada', 'mana', 'ya']
# ['min', 'hp', 'adik', 'saya', 'hilang']
# ['tolong', 'cek', 'no', 'knp', 'ga', 'ada', 'balas', 'dr', 'indosat', 'ya', 'terima', 'kasih', 'segera', 'tindak', 'lanjut']
# ['dm', 'ga', 'direspon']
# ['lurd', 'cek', 'poin', 'gimana', 'yah']
# ['marah', 'dengan']
# ['baru', 'kali', 'ini', 'saya', 'kecewa', 'sekali', 'dengan', 'layan', 'caroline', 'officer', 'agent', 'name', 'tari', 'saya', 'tanya', 'ttg', 'proses', 'running', 'paket', 'data', 'saya', 'kenapa', 'tdk', 'jalan', 'seperti', 'biasa']
# ['jancuk']
# ['nabungbuatapa', 'buat', 'biaya', 'mengumpulin', 'orang', 'untuk', 'bersih', 'sampah', 'di', 'pantai']
# ['delapan', 'tahun', 'make', 'telkomsel', 'baru', 'kali', 'ini', 'tukar', 'poin']
# ['kenapa', 'ya', 'jaring', 'indosat', 'belakang', 'ini', 'suka', 'hilang', 'sinyal', 'lama', 'lama', 'bisa', 'kecewa', 'saya', 'dan', 'lagi']
# ['balas', 'paling', 'kesel', 'kalo', 'udah', 'lelet', 'dan', 'bilang', 'tidak', 'ada', 'masalah', 'hahahaha', 'tai', 'memang']
# ['sinyal', 'di', 'tmpt', 'saya', 'sering', 'mati', 'udah', 'minggu', 'ini']
# ['balas', 'untung', 'gw', 'ga', 'pernah', 'pakai', 'selain', 'mahal']
# ['balas', 'telkom', '9999', 'dari', 'telkomsel', 'mantap', 'jiwa']
# ['balas', 'indosat', 'juga', 'lagi', 'masalah', 'alhamdulillah', 'nyata', 'provider', 'mahal', 'juga', 'masalah']
# ['jaring', 'indosat', 'lumayan', 'bagus']
# ['telkomsel', 'memang', 'baik']
# ['min', 'saya', 'mau', 'kasih', 'saran', 'nih']
# ['sinyal', 'tri', 'ngebut', 'rt', 'wifi', 'mencret']
# ['maksud', 'nya', 'apa', 'ya', 'ini', 'karena', 'sistem', 'indosat', 'yang', 'trouble', 'atau', 'sengaja', 'tolong', 'kembali', 'pulsa', 'saya', 'terima', 'ka']
# ['balas', 'nich', 'provider', 'bangsat', 'isuny', 'cm', 'maling', 'dan', 'tipu', 'konsumen', 'provider', 'zaman', 'now', 'maling', 'modus', 'provider', 'xl', 'bangsat']
# ['memang', 'macam', 'anjing', 'sinyal']
# ['smart', 'juga', 'set', 'jam', 'download', 'mb', 'lewat', 'bb', 'rt', 'sinyal', 'tri', 'pagi', 'emang', 'mantap', 'jaya']
# ['promo', 'sampe', 'kpn', 'nih', 'blackberry', 'isi', 'voucher', 'blackberry', 'full', 'service', 'minggu', 'bonus', 'voucher', 'yang', 'sama']
# ['balas', 'mungkin', 'udh', 'naik']
# ['gratis', 'kok', 'sms', 'gratis', 'tu', 'pulsa', 'rt', 'pake', 'tri', 'sms', 'sekali', 'gratis', 'terus', 'donk', 'hari']
# ['laek']
# ['kenapa', 'ya', 'nomor', 'prabayar', 'itu', 'ga', 'bisa', 'aktif', 'lagi', 'seperti', 'nomor', 'atau', 'padahal', 'baru', 'lewat', 'hari', 'dari', 'masa', 'tenggangdipaksa', 'pindah', 'ke', 'pascabayarsistem', 'yang', 'jadul', 'atau', 'karena', 'rasa', 'provider', 'paling', 'besar']
# ['luka', 'yang', 'baru', 'pecat', 'maupinjemuang', 'eagkbisa', 'mau', 'ngutang', 'enggak', 'kasih', 'boikotindosat', 'atau', 'nang', 'ilcmembidikhabibrizieq']
# ['rt', 'lurd', 'urgent']
# ['ucweb', 'indosat', 'mantap', 'bisa', 'new', 'tab', 'norak']
# ['hallo', 'indosat', 'yang', 'baik', 'hati']
# ['telkomsel', 'absen', 'pesta', 'rbt']
# ['min']
# ['balas', 'telkomsel', 'murah', 'jg', 'jok', 'rt', 'gedor', 'be', 'rt', 'belum', 'dtng', 'dy', 'rt', 'duku', 'jg', 'enak', 'rt', 'lewat', 'jendelo']
# ['jancok', 'banget', 'ni', 'kartu', 'saya', 'udah', 'maketin', 'paket', 'flash', 'eh', 'tapi', 'pulsa', 'tetep', 'potong']
# ['dunia', 'harus', 'tau', 'kalo', 'skrng', 'di', 'rumah', 'udah', 'ada', 'sinyal', 'indosat', 'alhamdulillah', 'packet', 'yellowku', 'wkwk']
# ['tolong', 'informasi', 'segera', 'saya', 'belum', 'pernah', 'ikut', 'paypro']
# ['sini', 'kok', 'sinyal', 'xl', 'kencang', 'aneh']
# ['sipooo', 'rt', 'oke', 'makasih', 'glo', 'rt', 'theodoregloria', 'lumayan', 'rt', 'eh', 'yang', 'indosat', 'sinyal', 'bagus', 'gak']
# ['better', 'upload', 'service']
# ['buat', 'kaum', 'jomblo']
# ['indosat', 'jan', 'bulsit', 'di', 'paketke', 'kok', 'sik', 'kenggo', 'pulsa', 'pokok', 'paketane', 'wutuh', 'asu', 'asu']
# ['balas', 'yeee', 'terbukaaa', 'terima', 'kasih', 'engkau', 'memang', 'layan', 'baik']
# ['asu', 'tnan', 'seng', 'jupuk', 'hp', 'qw', 'ch', 'lek', 'pnteng', 'mzo', 'nek', 'kne', '9', 'sng', 'qw', 'indosat', 'ilang']
# ['iya']
# ['pakai', 'xl', 'jamin', 'cepat', 'dan', 'sinyal', 'kuat', 'haya', 'iklan', 'hahaha', 'rt', 'bbm', 'masih', 'aja', 'pendingzzzzzzz']
# ['indosat', 'jancok', 'kaya', 'gin', 'masih', 'gak', 'cukup', 'pulsa', 'jancok']
# ['balas', 'tolong', 'beri', 'informasi', 'yg', 'jelas', 'tentang', 'ganggu', 'nya']
# ['balas', 'kemrin', 'waktu', 'ke', 'pantai', 'parangtritis', 'jogja']
# ['balas', 'saya', 'mau', 'regis', 'tapi', 'nik', 'tidak', 'temu', 'gimana', 'tuh', 'min']
# ['tolong', 'ya', 'perhati', 'dengan', 'baik', 'no', 'hp', 'yang', 'masalah', 'adalah', '999']
# ['balas', 'hai', 'kak']
# ['balas', 'terimakasih', 'kami', 'sangat', 'puas']
# ['indosat', 'lg', 'ada', 'masalah', 'ya', 'min', 'nomor', 'saya', 'tidak', 'bisa', 'terima', 'sms', 'masuk', 'dan', 'harus', 'di', 'copot', 'simcardnya', 'dulu', 'baru', 'smsnya', 'masuk', 'tolong', 'di', 'cek']
# ['udah', 'hari', 'masih', 'juga', 'ganggu', 'ini', 'xl', 'ga', 'dengar', 'keluh', 'langgan', 'ya', 'kaya', 'udh', 'banyak', 'yg', 'ngadu', 'tpi', 'kok', 'ga', 'lebih', 'baik', 'udah', 'kali', 'kali', 'reset', 'signal']
# ['hash', 'rt', 'pake', 'xl', 'dongga', 'pernah', 'bs', 'belaajar', 'rt', 'telkomsel', 'jancok', 'hari', 'ini', 'gsm', 'mulu']
# ['balas', 'bnr', 'ngak', 'diperhatiin', 'kualitas', 'isat', 'bb', 'sibuk', 'promo', 'trus', 'tp', 'kualitas', 'sinyal', 'ancurrr', 'kecewa', 'bneran', 'dh', 'layan', 'indosat']
# ['provider', 'bangsat', 'xl', 'isiny', 'cm', 'maling']
# ['ini', 'kenapa', 'koneksi', 'nya', 'tai', 'banget', 'dari', 'siang']
# ['balas', 'masih', 'gaada', 'tindak', 'lanjut', 'udah', 'hari', 'jaring', 'hilang', 'percuma', 'kuota', 'kasih', 'harga', 'murah', 'kalo', 'layan', 'utama', 'kepada', 'keluh', 'konsumen', 'masih', 'kek', 'tai']
# ['baji', 'gau', 'melulu']
# ['hai']
# ['mudah', 'mudah', 'bisa', 'lebih', 'baik', 'dlm', 'layan', 'langgan', 'krn', 'terus', 'terang', 'urus', 'sinyal', 'dan', 'coverage', 'saya', 'sangat', 'puas', 'dg', 'telkomsel']
# ['lumayan', 'bagus', 'wan', 'rt', 'rekomendasi', 'dong', 'jaring', 'indosat', 'khusus', 'im', 'bagus', 'ga', 'sih']
# ['halo', 'indosat', 'ada', 'atur', 'yang', 'cocok', 'gk', 'buat', 'hp', 'advan', 'ic']
# ['pakai', 'telkomsel', 'itu', 'enak', 'yaa', 'gak', 'pernah', 'pending', 'kalau', 'bbman', 'terus', 'kalau', 'telfonan', 'sama', 'smsan', 'murah', 'banget']
# ['ak', 'wes', 'onok', 'telkomsel', 'tp', 'halo', 'ran', 'rt', 'ganti', 'simpati', 'wes', 'rt', 'jancok']
# ['nyalahin', 'customer', 'belum', 'regist', 'padahal', 'udah', 'regis', 'kok', 'sampah', 'ya', 'anda', 'problem', 'ada', 'di', 'anda', 'bagi', 'it', 'anda', 'yang', 'tidak', 'becus']
# ['jaring', 'cacat']
# ['jaring', 'nya', 'cacat', 'payah', 'lah']
# ['thanks', 'xl', 'download', 'apa', 'sangat', 'cepat']
# ['untuk', 'yg', 'sekian', 'kali', 'pulsa', 'saya', 'hilang', 'tiba', 'tiba', 'pulsa', 'tinggal', 'mantap', 'indosat', 'diem', 'diem', 'curi']
# ['dear', 'sampai', 'sekarang', 'belum', 'ada', 'jawab', 'dr', 'keluh', 'saya']
# ['tumben', 'sinyal', 'xl', 'bagus']
# ['mau', 'sampai', 'kapan', 'ganggu', 'sinyal', 'begini', 'minggu', 'tidak', 'bisa', 'pakai', 'buat', 'main', 'mobile', 'legends', 'saya', 'kecewa', 'beneran']
# ['ni', 'laptop', 'koneksi', 'malah', 'dari', 'tethering', 'wifi', 'hape', 'cino', 'pake', 'xl', 'lumayan', 'ngebut', 'juga']
# ['fix', 'ganti', 'kartu', 'sudah', 'capek', 'dengan', 'xl', 'keluh', 'gak', 'tanggap', 'sekali', 'tanggap', 'jawab', 'ngelantur', 'cc']
# ['mau', 'tahu', 'tips', 'agar', 'cod', 'kamu', 'lancar', 'jawab']
# ['tekan', 'pertama', 'ad', 'di', 'kata', 'murah', 'rt', 'indosat', 'dganti', 'opo', 'enak', 'telkomsel']
# ['sampah', 'banget', 'koneksi', 'internet', 'xl', 'ini', 'bah', 'sampah']
# ['tanggap', 'dari', 'cs', 'indosat', 'cukup', 'bagus', 'lah', 'turut', 'saya']
# ['balas', 'owh', 'itu', 'aj', 'ya', 'oh', 'ya', 'makasih', 'ya', 'paket', 'tau', 'nya', 'udh', 'ak', 'pake', 'itu', 'dan', 'ak', 'rasa', 'sangat', 'puas', 'semga', 'pket', 'tau', 'di', 'adakn', 'lg']
# ['tolong', 'baca', 'dm', 'saya', 'saya', 'urgent', 'perlu', 'bantu', 'nomor', 'indosat', 'saya', 'sdh', 'tdk', 'aktif', 'hari', 'hari', 'terima', 'kasih']
# ['sampahudh', 'hari', 'sinyal', 'leleeeeeet']
# ['gak', 'bakal', 'kolaborasi', 'sama', 'nih', 'soal', 'sinyal', 'kalian', 'sama', 'sama', 'bapuk', 'dan', 'selalu', 'tidak', 'respon', 'keluh', 'konsumen']
# ['jadi']
# ['mantap', 'pake', 'indosat', 'nih']
# ['tp', 'katae', 'plng', 'enak', 'telkomsel', 'rt', 'podo', 'ae', 'se', 'jatuhe', 'kabehrt', 'lek', 'paket', 'iku', 'murah', 'endi']
# ['balas', 'baik']
# ['apa', 'sih', 'benefit', 'yg', 'kita', 'terima', 'sbg', 'langgan', 'postpaid', 'krn', 'hampir', 'thn', 'ga', 'dpt', 'bonus', 'apa']
# ['balas', 'mungkin', 'sekitar', 'tahun', 'aku', 'pake', 'provider', 'indosat', 'jauh', 'ini', 'cukup', 'puas']
# ['knapa', 'sinyal', 'gnya', 'main', 'yah', 'informasi', 'detail', 'kena', 'aon', 'cek', 'ke']
# ['em', 'btw', 'ini', 'konek', 'pake', 'ya']
# ['woy', 'bangsat', 'anjing', 'ngentot', 'babi', 'kontol', 'memek', 'lu', 'lelet', 'tai', 'anjing', 'mahal', 'sering', 'di', 'lletin', 'lagi', 'ahh', 'ngentot', 'awas', 'lu', 'ya']
# ['balas', 'hai', 'krisnantyo']
# ['kukud', 'ja', 'banyak', 'keluh', 'tp', 'gak', 'di', 'tanggap']
# ['slamat', 'datang', 'di', 'manokwari', 'sinyal', 'xl', 'lumayan', 'banget', 'rasa', 'kok', 'hehe', 'ga', 'lost', 'sinyal', 'kyk', 'belah', 'yuk', 'eksplor', 'papua', 'barat']
# ['batang', 'jak', 'agik', 'pelosok', 'sinyal', 'tri', 'mantap', 'batang', 'jak']
# ['sms', 'blast', 'telkomsel', 'sampah', 'banget', 'isi', 'udah', 'bayar', 'pulsa', 'tetep', 'aja', 'di', 'blast', 'unethical']
# ['keluh', 'gua', 'haru', 'hari', 'gak', 'di', 'tanggapin']
# ['jaring', 'bb', 'telkomsel', 'napa', 'ilang', 'mulu', 'lot', 'cuy']
# ['kaksinyal', 'di', 'daerah', 'saya', 'kok', 'sekarang', 'jelek', 'sejak', 'ada', 'sinyal', 'ghp', 'ahrus', 'di', 'lock', 'agar', 'dapt', 'sinyal', 'gkalo', 'gak', 'di', 'lock', 'cuma', 'dpt', 'sinyal', 'dan', 'itu', 'lemotbantuannya', 'kak']
# ['balas', 'nomor', 'lama', 'juga', 'dong', 'udah', 'pake', 'tri', 'tahun', 'pas', 'registrasi', 'ulang', 'gak', 'dapet', 'hadiah', 'apa']
# ['siang']
# ['karena', 'pasca', 'bayar', 'xl', 'sudah', 'lambat']
# ['goblog', 'jaring', 'lu', 'udah', 'bulan', 'lebih', 'ngga', 'bener', 'jgn', 'cm', 'ngiklan', 'doangpikirin', 'konsumen']
# ['tolong', 'sekali', 'lagi', 'saya', 'minta', 'tanggung', 'jawab', 'yaa', 'saya', 'tarik', 'beli']
# ['pada', 'heboh', 'paket', 'bis', 'namun', 'telkomsel', 'tetap', 'juaranyamurah', 'koq', 'njaluk', 'enak']
# ['ya', 'beli', 'aja', 'perdana', 'murah', 'iniaxis', 'lumayan', 'bagus', 'kokasal', 'jangan', 'kedap', 'udara', 'ajaheheperminggu', 'rb']
# ['lagi', 'lagi', 'tcash', 'telkomsel', 'mesin', 'edc', 'nya', 'error', 'dua', 'kali', 'nya', 'di', 'centre', 'point', 'medan', 'ckckck', 'kecewa', 'bngt']
# ['mohon', 'bantu', 'puk', 'untuk', 'nomor', 'terimakasih']
# ['satu', 'kata', 'telkomsel', 'browsing', 'cepet', 'rt', 'indosat', 'sialaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaannnnn']
# ['balas', 'kemarin', 'lusa', 'sy', 'beli', 'paket', 'gb', 'gb', 'gb', 'rb', 'telah', 'habis', 'lalu', 'sy', 'beli', 'yg', 'gb']
# ['balas', 'di', 'selamatin', 'doang']
# ['dear', 'kenapa', 'jaringanya', 'selalu', 'ganggu', 'jadi', 'ga', 'guna', 'baru', 'beli', 'kartu', 'perdana', 'yang', 'gb', 'tapi', 'gakepake', 'sama', 'sekali', 'gara', 'jaringanya', 'lot', 'jelekkk', 'parahh', 'banget', 'asli']
# ['bagai', 'konsumen', 'saya', 'sangat', 'kecewa', 'dengan', 'iklan', 'ini', 'mana', 'saya', 'harus', 'adu']
# ['moga', 'xl', 'xlalu', 'hadir', 'layan', 'baik', 'dan', 'super', 'cepat', 'utk', 'langgan', 'setia', 'jaringanxtrasuka']
# ['semangat', 'dong']
# ['dear', 'kenapa', 'kalo', 'saya', 'nonton', 'film', 'dari', 'viu']
# ['malam', 'nomor', 'saya', 'sudah', 'tidak', 'aktif', 'sejak']
# ['neng', 'banget', 'arsenal', 'jadi', 'ke', 'indonesia', '', 'ada', 'promo', 'khusus', 'langgan', 'telkomsel', 'lagi', '', 'jingkrakjingkrak']
# ['sinyal', 'bagus', 'ko', 'tapi', 'lot', 'yah']
# ['buat', 'yang', 'senang', 'ajar', 'fisika', 'atau', 'kimia']
# ['xl', 'sama', 'axis', 'itu', 'beda', 'jauh', 'axis', 'cm', 'rb', 'full', 'service', 'sinyal', 'bagus', 'sedang', 'xl', '9rb', 'full', 'service', 'tpi', 'sama', 'aja', 'kyk', 'ga', 'pake', 'paket', 'full', 'servc']
# ['rt', 'terima', 'kasih', 'semua', 'yg', 'sudah', 'kasih', 'info', 'ttg', 'provider', 'tri', 'simpul']
# ['balas', 'saya', 'langgan', 'paket', 'tri', 'gb', 'bulan', 'cuma', 'ribu']
# ['balas', 'banyak', 'ganggu', 'dah', 'gitu', 'slow', 'respon', 'lagi', 'hadeeeh', 'nyesel', 'dah', 'ini', 'beli', 'perdana', 'malah', 'mahal', 'lagi']
# ['bikin', 'boros', 'batere', 'bro', 'rt', 'sini', 'hspa', 'mas', 'hihi', 'rt', 'sinyal', 'hsdpa', 'xl', 'joss', 'gandos', 'men']
# ['tri', 'gaada', 'sinyal', 'mantap', 'yah']
# ['balas', 'itu', 'smartfreen']
# ['sore', 'min']
# ['rekan', 'mohon', 'bantu', 'respon', 'dm', 'tks']
# ['sampah', 'indosat', 'minyat', 'we', 'ah', 'aja', 'ke']
# ['butuh', 'trik', 'panjang', 'masa', 'aktif', 'indosat', 'moso', 'tp', 'ewuminim', 'masa', 'aktif', '9', 'hari', 'nang', 'nang']
# ['musti', 'banyak', 'sabar', 'ngadepin', 'xl', 'ini', 'yaa', 'udah', 'banyak', 'keluh', 'dari', 'langgan', 'klen', 'tolong', 'bagusinlaah', 'bodaat']
# ['mas', 'sinyal', 'nya', 'kyk', 'tai', 'kucing', 'mas']
# ['bangsat', 'nih']
# ['streaming', 'putus', 'ni', 'wooeee']
# ['cerita', 'tadi', 'mau', 'nanya', 'kenapa', 'minggu', 'ini', 'xl', 'ilang', 'di', 'hp']
# ['balas', 'dah', 'pasrahin', 'aja']
# ['sinyal', 'xl', 'rumah', 'gue', 'bagus', 'deh', 'sampe', 'ken', 'demo', 'saking', 'sinyal', 'bagus']
# ['balas', 'rp', 'gb', 'how', 'dare', 'are', 'you', 'btw', 'koq', 'tau', 'aku', 'pake', 'paket', 'rakyat', 'jelantah', 'hahaha', 'hati', 'hati', 'paket', 'yellow', 'habis', 'kuota', 'atau', 'habis', 'waktu', 'pulsa', 'reguler', 'akan', 'hajar', 'habis', 'dalam', 'satu', 'kerdipan', 'mata', 'papa', 'memang', 'jahat', 'jawab', 'indosat', 'murah', 'mau', 'selamat']
# ['beberapa', 'orang', 'ngetwit', 'galau', 'biar', 'dapat', 'simpati']
# ['haha', 'sinyal', 'kuat', 'ege', 'rt', 'pea', '', 'rt', 'kartu', 'kredit']
# ['ehh', 'bangsat', 'asa', 'gw', 'beli', 'paket', 'kuota', 'yg', 'reguler', 'internet', 'knp', 'gw', 'kudu', 'jadi', 'pindahin', 'mode', 'en', 'balik', 'terus', 'kek']
# ['lancar', 'terjemah', 'semua', 'jurnal', 'bahasa', 'inggris', 'dengan', 'cepat', 'tinggal', 'jurnal', 'lagi', 'thanks', 'xl']
# ['balas', 'maaf']
# ['knp', 'signal', 'tri', 'di', 'cikarang', 'utara', 'bikin', 'marahlemottttt', 'bgt', 'signal', 'sering']
# ['indosat', 'sinyal', 'bikin', 'ken', 'nang']
# ['game', 'keren', 'yang', 'bisa', 'kamu', 'dapetin', 'dengan', 'gratis', 'adalah', 'batman', 'arkham', 'origins', 'guna', 'android', 'pasti', 'senang', 'banget', 'nih', 'xlgames']
# ['mana', 'saya', 'bisa', 'sampai', 'keluh', 'kait', 'xl']
# ['halo', 'mengap', 'sinyal', 'xl', 'di', 'tempat', 'saya', 'jadi', 'lot', 'tiba']
# ['sangat', 'puas', 'dengan', 'layan', 'call', 'center', 'telkomsel', 'we', 'love', 'telkomsel']
# ['kok', 'semenjak', 'aku', 'ganti', 'im', 'kamu', 'gak', 'pernah', 'sms', 'aku', 'lagi', 'kamu', 'marah', 'ya']
# ['balas', 'duh', 'mahal', 'ya', 'indosat', 'donk', 'murah', 'gb', 'rb', 'hr', 'jam', 'paket', 'yellow']
# ['koneksi', 'parah', 'gk', 'ada', 'kembang', 'percuma', 'lapor', 'kayak', 'tai']
# ['kuat', 'dan', 'kencang', 'rt', 'kuat', 'po', 'kencang', 'kan', 'pake', 'xl']
# ['telkomsel', 'xl', 'tahik', 'banget', 'cepet', 'abis', 'mana', 'mahal', 'lagi', 'pingin', 'ganti', 'yang', 'murah', 'sama', 'enak', 'buat', 'paket', 'android', 'ada', 'saran']
# ['ka', 'kartu', 'sim', 'saya', 'ke', 'blokir', 'karna', 'abis', 'masa', 'tenggang']
# ['astagfirulloh', 'nang', 'gua', 'indosat', 'rumah', 'gua', 'gin', 'amat', 'sih']
# ['mosok', 'hahahad', 'rt', 'telkomsel', 'jancok']
# ['balas', 'tolong', 'cepat', 'keluh', 'langgan', 'tri', 'di', 'tanggap']
# ['ini', 'xl', 'lagi', 'kenapa', 'si', 'gak', 'jelas', 'bgt', 'koneksi', 'dari', 'tadi', 'sampah']
# ['mantap', '9', 'tahun', 'indosat', 'ooredoo', 'imsemaranginner', 'indosatooredoo9smg']
# ['ping', 'gede', 'asu', 'ngeleg', 'mulu', 'lot', 'mulu', 'kapan', 'maju', 'indosat', 'malah', 'makin', 'blangsak', 'aja', 'tolo', 'dasar']
# ['murah', 'tau', 'sama', 'aja', 'na', 'rt', 'muaaaahal', 'rt', 'ganti', 'telkomsel', 'aje', 'rt', 'enak', 'si', 'sms', 'sama', 'telfonnya', 'gratis', 'tp']
# ['kenapa', 'cacat', 'banget', 'sih', 'tiap', 'jam', 'malem', 'selalu', 'ubah', 'jaring', 'udah', 'paket', 'mahal']
# ['kecewa', 'pake', 'xl']
# ['saya', 'kecewa', 'dan', 'kesal', 'dengan', 'jaring', 'xl', 'yg', 'trouble', 'dalam', 'minggu', 'ini', 'utama', 'wilayah', 'sumbar', 'saya', 'kesal', 'karena', 'tidak', 'ada', 'pemberitahuan', 'trouble', 'dan', 'lanjut', 'kekesalab', 'saya', 'ketika', 'lgi', 'asik', 'gaming', 'eh', 'jaring', 'ilang', 'ujung', 'saya', 'anggap', 'afk']
# ['hallo', 'kenapa', 'indosat', 'klo', 'sms', 'status', 'tunda', 'semua', 'gak', 'bisa', 'terima', 'sms', 'juga', 'tolong', 'bantu']
# ['gara', 'lu', 'quiz', 'kuliah', 'gw', 'jadi', 'skip', 'jing', 'bangsat', 'kalah', 'esia', 'nge', 'lagnya', 'tolol', 'anjing', 'bangkrut', 'lo', 'jing']
# ['dear', 'kok', 'sinyal', 'indosat', 'gue', 'suka', 'ilangan', 'gin']
# ['balas', 'to', 'the', 'point', 'saja', 'pak', 'ini', 'bagi', 'rakyat', 'indonesia', 'itu', 'cepat', 'lupa']
# ['males', 'kali', 'baca', 'email', 'yg', 'signature', 'nya', 'kek', 'gin', 'sent', 'from', 'my', 'blackberry', 'smartphone', 'from', 'sinyal', 'bagus', 'xl']
# ['balas', 'trnyata', 'klo', 'vip', 'sinyal', 'xl', 'yg', 'jossklo', 'timur', 'telkomsel', 'yg', 'buosok']
# ['jangkau', 'di', 'bogor', 'masih', 'batas']
# ['balas', 'terima', 'kasih', 'sudah', 'tunggu', 'mohon', 'kamu', 'coba', 'kembali', 'sekarang', 'jika', 'masih', 'kendala', 'tolong', 'kirim', 'screenshoot', 'sms', 'nya', 'ke', 'kami', 'nanti', 'kami', 'akan', 'ecek', 'lebih', 'lanjut']
# ['terima', 'kasih', 'atas', 'bonus', 'mb', 'nya']
# ['kalo', 'mau', 'jadi', 'csc', 'gimana', 'ken', 'ngelayanin', 'guna', 'tri', 'dengan', 'jadi', 'csc', 'kalo', 'ada', 'info']
# ['mau', 'ngerasain', 'internetan', 'cepat', 'dan', 'stabil', 'tapi', 'belum', 'pake', 'xl', 'dateng', 'ke', 'xl', 'center', 'jabo', 'hari', 'ini', 'xlappreciationday']
# ['balas', 'tai', 'xl', 'anjing']
# ['ktika', 'sy', 'smp', 'kls', 'dulu']
# ['balas', 'gantung', 'lokasi', 'gan', 'kalo', 'sinyal', 'indosat', 'sana', 'bagus', 'cepat', 'lumayan']
# ['enak', 'axis', 'iki', 'lo', 'murah', 'banter', 'hahahahaah', 'rt', 'oyowahhenak', 'ta', 'nganggo', 'telkomselm', 'iki', 'yo', 'bedes']
# ['selamat', 'istirahat']
# ['balas', 'provider', 'anjing', 'xl', 'isiny', 'cm', 'maling', 'dan', 'tipu', 'konsumen', 'tai', 'xl', 'kampret']
# ['adaw', 'rt', 'iya', 'ya', 'seperti', 'hati', 'ku', 'kepada', 'mu', 'asik', 'asik', 'joss', 'rt', 'sinyal', 'xl', 'lg', 'timbul', 'tenggelam']
# ['internet', 'indosat', 'sampah', 'normal', 'mbps']
# ['nikmat', 'santai', 'dengan', 'vietnam', 'drip', 'dan', 'sinyal', 'kencang', 'dari', 'xl', 'telah', 'hari', 'embara']
# ['edge', 'nya', 'indosat', 'lumayan', 'bagus', 'di', 'rumah']
# ['signal', 'speed', 'lebih', 'lambat', 'dari', 'gsm']
# ['balas', 'saya', 'coba', 'registrasi', 'kok', 'tdk', 'bisa', 'ya', 'pdhl', 'pasu', 'no', 'nik', 'sdh', 'benar', 'mohon', 'bantu', 'cepat']
# ['balas', 'provider', 'anjing', 'ini']
# ['saya', 'dpt', 'sms', 'dari', 'indosat', 'kena', 'ubah', 'paket', 'yellow', 'ttg', 'ubah', 'harga', 'dan', 'benefit', 'pulsa', 'safe', 'saya', 'klik', 'link', 'info', 'tidak', 'bisa', 'mohon', 'info', 'lbh', 'detil', 'terima', 'kasih']
# ['tidak', 'sia', 'pakai', 'kartu', 'indosatalhamdulillah']
